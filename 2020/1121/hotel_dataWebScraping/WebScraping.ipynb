# %% [markdown]
# # 파이썬을 활용하여 웹스크래핑 하기

# %% [markdown]
# > ### Beautiful Soup를 이용하여 네이버 호텔 웹스크래핑

# %%
# !pip install requests

# %% [markdown]
# ## userAgent 확인하는방법
#
# - 참고블로그: https://blog.hangyeong.com/1009
#
# - F12 > Console > navigator.userAgent

# %% [markdown]
# ## 웹스크래핑 차단방지방법
#
# - 참고블로그: https://advenoh.tistory.com/3

# %% [markdown]
# ## python 데이터크롤링
#
# - 참고블로그
#     - https://victorydntmd.tistory.com/245
#     - https://m.blog.naver.com/21ahn/221329219163

# %% [markdown]
# ## selenium을 활용한 동적웹 크롤링
#
# - selenium
# - beautifulSoup
#
#
# - driver 요구사항
#     - https://beomi.github.io/2017/02/27/HowToMakeWebCrawler-With-Selenium/
#     - https://chromedriver.chromium.org/downloads
#
#
# - 현재 사용하고 있는 크롬드라이버 정보
#     - driver version: 버전 87.0.4280.66(공식 빌드) (64비트)
#
#
# - 크롬드라이버로 버튼클릭등 자동제어
#     - [참고블로그 1](https://medium.com/@nsh235482/python-selenium%EC%9C%BC%EB%A1%9C-%EC%9B%B9%EC%82%AC%EC%9D%B4%ED%8A%B8-%ED%81%AC%EB%A1%A4%EB%A7%81%ED%95%98%EA%B8%B0-2-%EC%9B%B9-%EC%82%AC%EC%9D%B4%ED%8A%B8-%EC%A0%9C%EC%96%B4%ED%95%B4%EB%B3%B4%EA%B8%B0-1ffc5e05179d)
#     - [참고블로그 2](https://book.coalastudy.com/data-crawling/week-6/stage-4)
#     - [참고블로그 3](https://sacko.tistory.com/15)
#     - [스크래핑-창없는 크롬으로 크롤링하기](https://beomi.github.io/2017/09/28/HowToMakeWebCrawler-Headless-Chrome/)

# %% [markdown]
# > ## 네이버호텔 샘플

# %%
from bs4 import BeautifulSoup
from selenium import webdriver

driver = webdriver.Chrome('./chromedriver_win32/chromedriver.exe')
url='https://hotel.naver.com/hotels/list?destination=place:Seoul&destination_kor=%EC%84%9C%EC%9A%B8'

driver.get(url)
req= driver.page_source
soup= BeautifulSoup(req, 'html.parser')
soup
# Out:
# <html class="no-js" lang="ko"><!--<![endif]--><head><style type="text/css">@charset "UTF-8";[ng\:cloak],[ng-cloak],[data-ng-cloak],[x-ng-cloak],.ng-cloak,.x-ng-cloak,.ng-hide{display:none !important;}ng\:form{display:block;}.ng-animate-block-transitions{transition:0s all!important;-webkit-transition:0s all!important;}.ng-hide-add-active,.ng-hide-remove{display:block!important;}</style>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <base href="/hotels/"/>
# <title>네이버 호텔</title>
# <meta content="" name="description"/>
# <meta content="width=device-width" name="viewport"/>
# <meta content="9Z8Atb6svl4pPoH-8RY2N3G1VgUb1vsBC9AsDhaOEMo" name="google-site-verification"/>
# <link href="assets/images/favicon/ios_57.png" rel="apple-touch-icon" sizes="57x57"/>
# <link href="assets/images/favicon/ios_66.png" rel="apple-touch-icon" sizes="66x66"/>
# <link href="assets/images/favicon/ios_72.png" rel="apple-touch-icon" sizes="72x72"/>
# ...

# %% [markdown]
# ## 호텔이름
#
# - 호텔이름: strong.hotel_name_ko

# %%
hotel_names= soup.select('strong.hotel_name_ko')
hotel_names
# Out:
# [<strong class="hotel_name_ko ng-binding" ng-bind="result.transliteratedName ? result.transliteratedName : result.name">신라스테이 광화문</strong>,
#  <strong class="hotel_name_ko ng-binding" ng-bind="result.transliteratedName ? result.transliteratedName : result.name">나인트리 프리미어 호텔 인사동</strong>,
#  <strong class="hotel_name_ko ng-binding" ng-bind="result.transliteratedName ? result.transliteratedName : result.name">신라스테이 역삼</strong>,
#  <strong class="hotel_name_ko ng-binding" ng-bind="result.transliteratedName ? result.transliteratedName : result.name">신라스테이 서대문</strong>,
#  <strong class="hotel_name_ko ng-binding" ng-bind="result.transliteratedName ? result.transliteratedName : result.name">글래드 강남 코엑스센터</strong>,
#  <strong class="hotel_name_ko ng-binding" ng-bind="result.transliteratedName ? result.transliteratedName : result.name">글래드 마포</strong>,
#  <strong class="hotel_name_ko ng-binding" ng-bind="result.transliteratedName ? result.transliteratedName : result.name">롯데시티호텔 명동</strong>,
# ...

# %%
hotel_names= []
for name in soup.select('strong.hotel_name_ko'):
    hotel_names.append(name.text)
hotel_names
# Out:
# ['신라스테이 광화문',
#  '나인트리 프리미어 호텔 인사동',
#  '신라스테이 역삼',
#  '신라스테이 서대문',
#  '글래드 강남 코엑스센터',
#  '글래드 마포',
#  '롯데시티호텔 명동',
#  '신라스테이 삼성',
#  '신라스테이 서초',
#  '글래드 여의도',
#  '나인트리 프리미어 호텔 명동 2',
#  '롯데시티호텔 구로',
#  'L7 강남 바이 롯데',
#  '신라스테이 마포',
#  '오라카이 청계산 호텔',
#  '쉐라톤 서울 디큐브시티 호텔',
#  '롯데 호텔 월드',
#  'PJ 호텔 명동 (피제이 호텔)',
#  '오라카이 대학로 호텔',
#  '시그니엘 서울']

# %% [markdown]
# <br>
#
# ## 호텔등급
#
# - 호텔등급: span.grade

# %%
hotel_grade=soup.select('span.grade')
hotel_grade
# Out:
# [<span class="grade ng-binding" ng-hide="result.starRating==0">3성급</span>,
#  <span class="grade ng-binding" ng-hide="result.starRating==0">4성급</span>,
#  <span class="grade ng-binding" ng-hide="result.starRating==0">3성급</span>,
#  <span class="grade ng-binding" ng-hide="result.starRating==0">3성급</span>,
#  <span class="grade ng-binding" ng-hide="result.starRating==0">3성급</span>,
#  <span class="grade ng-binding" ng-hide="result.starRating==0">4성급</span>,
#  <span class="grade ng-binding" ng-hide="result.starRating==0">4성급</span>,
#  <span class="grade ng-binding" ng-hide="result.starRating==0">3성급</span>,
#  <span class="grade ng-binding" ng-hide="result.starRating==0">3성급</span>,
#  <span class="grade ng-binding" ng-hide="result.starRating==0">4성급</span>,
#  <span class="grade ng-binding" ng-hide="result.starRating==0">4성급</span>,
#  <span class="grade ng-binding" ng-hide="result.starRating==0">3성급</span>,
# ...

# %%
hotel_grades=[]
for grade in soup.select('span.grade'):
    hotel_grades.append(int(grade.text[0]))
hotel_grades
# Out:
# [3, 4, 3, 3, 3, 4, 4, 3, 3, 4, 4, 3, 4, 3, 4, 5, 5, 4, 4, 5]

# %% [markdown]
# <br>
#
# ## 호텔 1박 최저가

# %%
hotel_low_prices=soup.select('em.ng-binding')
prices=[]
for price_string in hotel_low_prices:
    prices.append(int(price_string.text.replace(',','')))
    
prices
# Out:
# [65288,
#  60143,
#  77220,
#  54906,
#  78877,
#  65497,
#  55632,
#  82453,
#  65653,
#  70992,
#  49254,
#  51950,
#  67163,
#  63391,
#  68585,
#  98598,
#  153099,
#  48312,
#  57867,
#  353724]

# %% [markdown]
# <BR><BR>
#
#
# ## URL로 접근하기 좋게하기
#
# map을 이용하여, 키값에 해당하는 호텔url을 참고하기

# %%
localsInfo={
    '서울':'https://hotel.naver.com/hotels/list?destination=place:Seoul',
    '부산':'https://hotel.naver.com/hotels/list?destination=place:Busan_Province',
    '속초':'https://hotel.naver.com/hotels/list?destination=place:Sokcho',
    '경주':'https://hotel.naver.com/hotels/list?destination=place:Gyeongju',
    '강릉':'https://hotel.naver.com/hotels/list?destination=place:Gangneung',
    '여수':'https://hotel.naver.com/hotels/list?destination=place:Yeosu',
    '수원':'https://hotel.naver.com/hotels/list?destination=place:Suwon',
    '제주':'https://hotel.naver.com/hotels/list?destination=place:Jeju_Province',
    '인천':'https://hotel.naver.com/hotels/list?destination=place:Incheon_Metropolitan_City',
    '대구':'https://hotel.naver.com/hotels/list?destination=place:Daegu_Metropolitan_City',
    '전주':'https://hotel.naver.com/hotels/list?destination=place:Jeonju',
    '광주':'https://hotel.naver.com/hotels/list?destination=place:Gwangju_Metropolitan_City',
    '울산':'https://hotel.naver.com/hotels/list?destination=place:Ulsan_Metropolitan_City',
    '평창':'https://hotel.naver.com/hotels/list?destination=place:Pyeongchang',
    '군산':'https://hotel.naver.com/hotels/list?destination=place:Gunsan',
    '양양':'https://hotel.naver.com/hotels/list?destination=place:Yangyang',
    '춘천':'https://hotel.naver.com/hotels/list?destination=place:Chuncheon',
    '대전':'https://hotel.naver.com/hotels/list?destination=place:Daejeon_Metropolitan_City',
    '천안':'https://hotel.naver.com/hotels/list?destination=place:Cheonan',
    '세종':'https://hotel.naver.com/hotels/list?destination=place:Sejong',
    '청주':'https://hotel.naver.com/hotels/list?destination=place:Cheongju'
}

# %%
localsInfo.keys()
# Out:
# dict_keys(['서울', '부산', '속초', '경주', '강릉', '여수', '수원', '제주', '인천', '대구', '전주', '광주', '울산', '평창', '군산', '양양', '춘천', '대전', '천안', '세종', '청주'])

# %%
for key in localsInfo.keys():
    print(localsInfo[key])
# Out:
# https://hotel.naver.com/hotels/list?destination=place:Seoul
# https://hotel.naver.com/hotels/list?destination=place:Busan_Province
# https://hotel.naver.com/hotels/list?destination=place:Sokcho
# https://hotel.naver.com/hotels/list?destination=place:Gyeongju
# https://hotel.naver.com/hotels/list?destination=place:Gangneung
# https://hotel.naver.com/hotels/list?destination=place:Yeosu
# https://hotel.naver.com/hotels/list?destination=place:Suwon
# https://hotel.naver.com/hotels/list?destination=place:Jeju_Province
# https://hotel.naver.com/hotels/list?destination=place:Incheon_Metropolitan_City
# https://hotel.naver.com/hotels/list?destination=place:Daegu_Metropolitan_City
# https://hotel.naver.com/hotels/list?destination=place:Jeonju
# https://hotel.naver.com/hotels/list?destination=place:Gwangju_Metropolitan_City
# https://hotel.naver.com/hotels/list?destination=place:Ulsan_Metropolitan_City
# https://hotel.naver.com/hotels/list?destination=place:Pyeongchang
# ...

# %% [markdown]
# <br><br>
#
# ### 호텔 상세페이지로 이동하기 위한 id값을 구하기

# %%
from bs4 import BeautifulSoup
from selenium import webdriver
import os

driver = webdriver.Chrome('./chromedriver_win32/chromedriver.exe')
url=localsInfo['서울']

driver.get(url)
req= driver.page_source
soup= BeautifulSoup(req, 'html.parser')

driver.implicitly_wait(3)
# 호텔 서울의 디테일페이지에 들어가기위한 키값을 구하고 닫는다.
detail_keys=soup.select('ul.lst_hotel > li.ng-scope')
driver.close()

# %%
detail_keys
# Out:
# [<li class="ng-scope" id="hotel:Shilla_Stay_Gwanghwamun" ng-class="loading ? 'dimmed' : ''" ng-if="result.isWithinBoundary" ng-repeat="result in hotelList.results"><div class="hotel_info"><div class="img_wrap" ng-click="searchHotel($index, result.key)"><img alt="이미지 준비중" class="ng-hide" height="134" ng-hide="result.images[0].small" src="/hotels/assets/images/bg_noimg_138x138.gif" width="134"/><img alt="" class="" height="134" ng-show="result.images[0].small" ng-src="https://search.pstatic.net/common/?src=https://media.datahc.com/HP516302652.jpg&amp;type=f134_134" src="https://search.pstatic.net/common/?src=https://media.datahc.com/HP516302652.jpg&amp;type=f134_134" width="134"/><span class="btn_view_more" href="javascript:;" ng-init="imageMore=''" ng-mouseenter="imageMore='active'" ng-mouseleave="imageMore=''" ng-show="result.images.length &gt; 1"><span class="sp_hotel ic"></span><span class="count"></span></span></div><!-- ngIf: result.taAwardType == 'tc' && result.taAwardYear --><!
# ...

# %%
len(detail_keys)
# Out:
# 20

# %%
detail_keys=[ key['id'] for key in detail_keys]
detail_keys
# Out:
# ['hotel:Shilla_Stay_Gwanghwamun',
#  'hotel:Nine_Tree_Premier_Hotel_Insadong',
#  'hotel:Shilla_Stay_Yeoksam',
#  'hotel:Shilla_Stay_Seodaemun',
#  'hotel:GLAD_Gangnam_COEX_Center',
#  'hotel:Glad_Mapo',
#  'hotel:LOTTE_City_Hotel_Myeongdong',
#  'hotel:Shilla_Stay_Samsung',
#  'hotel:Shilla_Stay_Seocho',
#  'hotel:Glad_Yeouido',
#  'hotel:Nine_Tree_Premier_Hotel_Myeongdong_II',
#  'hotel:LOTTE_City_Hotel_Guro',
#  'hotel:L7_Gangnam_by_LOTTE',
#  'hotel:Shilla_Stay_Mapo',
#  'hotel:Orakai_Cheonggyesan_Hotel',
#  'hotel:Sheraton_Seoul_D_Cube_City_Hotel',
#  'hotel:Lotte_Hotel_World',
#  'hotel:Hotel_PJ_Myeongdong',
#  'hotel:Orakai_Daehakro_Hotel',
#  'hotel:Signiel_Seoul']

# %% [markdown]
# <br><br>
#
# ## 전국호텔 4200개의 호텔 데이터 키값을 구한다.
#
# - 리스트페이지에서 키값을 구한다.
# - 키값에 해당하는 페이지에 접속한다.
# - 신나게 크롤링을 한다 ^^
#
#
# - 다음 이동버튼 xpath: `/html/body/div/div/div[1]/div[2]/div[6]/div[2]/a[2]`
#
#
# - 상세페이지 이동 xpath 예: `//*[@id="hotel:Koreana_Hotel"]/a[2]`
# - 상세페이지 이동 xpath 예: `//*[@id="hotel:Tria_Hotel"]/a[2]`
# - 상세페이지 이동 xpath 일반화: `//*[@id="호텔키값"]/a[2]`
#
# - 상세페이지 url로 이동 예: `https://hotel.naver.com/hotels/item?hotelId=hotel:Koreana_Hotel`
#
# - 상세페이지 url로 이동 일반화: `https://hotel.naver.com/hotels/item?hotelId=호텔키값`

# %%
# location: 지역

local_url={
    '서울':'https://hotel.naver.com/hotels/list?destination=place:Seoul',
    '부산':'https://hotel.naver.com/hotels/list?destination=place:Busan_Province',
    '속초':'https://hotel.naver.com/hotels/list?destination=place:Sokcho',
    '경주':'https://hotel.naver.com/hotels/list?destination=place:Gyeongju',
    '강릉':'https://hotel.naver.com/hotels/list?destination=place:Gangneung',
    '여수':'https://hotel.naver.com/hotels/list?destination=place:Yeosu',
    '수원':'https://hotel.naver.com/hotels/list?destination=place:Suwon',
    '제주':'https://hotel.naver.com/hotels/list?destination=place:Jeju_Province',
    '인천':'https://hotel.naver.com/hotels/list?destination=place:Incheon_Metropolitan_City',
    '대구':'https://hotel.naver.com/hotels/list?destination=place:Daegu_Metropolitan_City',
    '전주':'https://hotel.naver.com/hotels/list?destination=place:Jeonju',
    '광주':'https://hotel.naver.com/hotels/list?destination=place:Gwangju_Metropolitan_City',
    '울산':'https://hotel.naver.com/hotels/list?destination=place:Ulsan_Metropolitan_City',
    '평창':'https://hotel.naver.com/hotels/list?destination=place:Pyeongchang',
    '군산':'https://hotel.naver.com/hotels/list?destination=place:Gunsan',
    '양양':'https://hotel.naver.com/hotels/list?destination=place:Yangyang',
    '춘천':'https://hotel.naver.com/hotels/list?destination=place:Chuncheon',
    '대전':'https://hotel.naver.com/hotels/list?destination=place:Daejeon_Metropolitan_City',
    '천안':'https://hotel.naver.com/hotels/list?destination=place:Cheonan',
    '세종':'https://hotel.naver.com/hotels/list?destination=place:Sejong',
    '청주':'https://hotel.naver.com/hotels/list?destination=place:Cheongju'
}

def get_hotel_data(url):
    #driverOpen
    driver= webdriver.Chrome('./chromedriver_win32/chromedriver.exe')
    driver.get(url)
    req= driver.page_source
    soup=BeautifulSoup(req,'html.parser')
    
    result=[]
    
    # 다음버튼 누를수있는 횟수 총 10번
    for _ in range(10,0,-1):
        driver.implicitly_wait(5) #5초 대기
        detail_keys=soup.select('ul.lst_hotel > li.ng-scope')
        result.extend([ key['id'] for key in detail_keys])
        
        #다음버튼을 누른다.
        driver.find_element_by_xpath('/html/body/div/div/div[1]/div[2]/div[6]/div[2]/a[2]').click() 
    
    #창을 닫는다.
    driver.close()
    return result
        

        
hotel_keys=[]
for local in local_url.keys():
    hotel_keys.extend(get_hotel_data(local_url[local]))

# %%
hotel_keys
# Out:
# ['hotel:Shilla_Stay_Gwanghwamun',
#  'hotel:Nine_Tree_Premier_Hotel_Insadong',
#  'hotel:Shilla_Stay_Yeoksam',
#  'hotel:Shilla_Stay_Seodaemun',
#  'hotel:GLAD_Gangnam_COEX_Center',
#  'hotel:Glad_Mapo',
#  'hotel:LOTTE_City_Hotel_Myeongdong',
#  'hotel:Shilla_Stay_Samsung',
#  'hotel:Shilla_Stay_Seocho',
#  'hotel:Glad_Yeouido',
#  'hotel:Nine_Tree_Premier_Hotel_Myeongdong_II',
#  'hotel:LOTTE_City_Hotel_Guro',
#  'hotel:L7_Gangnam_by_LOTTE',
#  'hotel:Shilla_Stay_Mapo',
#  'hotel:Orakai_Cheonggyesan_Hotel',
#  'hotel:Sheraton_Seoul_D_Cube_City_Hotel',
#  'hotel:Lotte_Hotel_World',
#  'hotel:Hotel_PJ_Myeongdong',
#  'hotel:Orakai_Daehakro_Hotel',
#  'hotel:Signiel_Seoul',
#  'hotel:Shilla_Stay_Gwanghwamun',
#  'hotel:Nine_Tree_Premier_Hotel_Insadong',
#  'hotel:Shilla_Stay_Yeoksam',
#  'hotel:Shilla_Stay_Seodaemun',
#  'hotel:GLAD_Gangnam_COEX_Center',
#  'hotel:Glad_Mapo',
#  'hotel:LOTTE_City_Hotel_Myeongdong',
#  'hotel:Shilla_Stay_Samsung',
#  'hotel:Shilla_Stay_Seocho',
# ...

# %%
len(hotel_keys)
# Out:
# 4200

# %% [markdown]
# <br><br>
#
# ## 1개의 상세데이터를 이용하여 호텔데이터를 구한다.
#
#
# - 호텔디테일 페이지
# : `https://hotel.naver.com/hotels/item?hotelId=(호텔키값)&checkin=2021-11-22&checkout=2021-11-23&rooms=2`
#
# <br>
#
# - 방정보 예약버튼
# - 예약확인 버튼 xpath: `/html/body/div/div/div[1]/div[2]/div[2]/div[2]/a[1]`
#
# - 더보기버튼: `/html/body/div/div/div[1]/div[2]/div[2]/div[4]/a`
#
# <BR><BR>
#
# - HOTEL 테이블에 삽입할 데이터 정보
#     - 크롤링으로 구해야되는 필수데이터
#         - BO_TITLE: 호텔이름
#         - BO_CONTENT:호텔소개내용
#
#         - 호텔주소
#         - 호텔등급
#         - 호텔옵션(arrayList)
#         - 호텔썸네일이미지(필수/ 아직 안함. => Attachment에서 bo_no를 불러와야됨.)
#         - 호텔디테일이미지(선택/ 아직 안함. => Attachment에서 bo_no를 불러와야됨.)
#
# <BR>
#
#    - 크롤링에서는 구해야되는 데이터는 아니지만, 필수데이터
#         - BO_NO (호텔번호) : SEQ_BO_NO.NEXTVAL
#         - CA_CODE (카테고리넘버): 5
#         - MEMBER_ID: admin
#         - REGDATE: SYSDATE
#         - BO_COUNT: DEFAULT
#         - HOTEL_REVIEW_SCORE: DEFAULT
#         - HOTEL_OPEN_TIME: DEFAULT
#         - HOTEL_CLOSE_TIME: DEFAULT
#         - CHECK_IN: DEFAULT
#         - CHECK_OUT: DEFAULT
#
# <BR>
#
# - ROOM 테이블에 삽입할 데이터 정보
#     - 크롤링으로 구해야되는 필수 데이터
#         - ROOM_TYPE: 방종류
#         - ROOM_NAME: 방이름
#         - PRICE_PER_DAY: 1박당 이용가격
#
#     - 크롤링에서는 구해야되는 데이터는 아니지만 필수데이터
#         - BO_NO: SEQ_BO_NO.CURRVAL
#         - ROOM_NO: SEQ_ROOM_NO.NEXTVAL

# %%
from bs4 import BeautifulSoup
from selenium import webdriver

driver = webdriver.Chrome('./chromedriver_win32/chromedriver.exe')

# 호텔디테일 페이지 url
url='https://hotel.naver.com/hotels/item?hotelId='+hotel_keys[0]+'&checkin=2021-03-12&checkout=2021-03-13&rooms=2'

driver.get(url)
driver.implicitly_wait(1) #예약페이지 로드 1초 대기
req= driver.page_source
soup= BeautifulSoup(req, 'html.parser')
soup
# Out:
# <html class="no-js" lang="ko"><!--<![endif]--><head><style type="text/css">@charset "UTF-8";[ng\:cloak],[ng-cloak],[data-ng-cloak],[x-ng-cloak],.ng-cloak,.x-ng-cloak,.ng-hide{display:none !important;}ng\:form{display:block;}.ng-animate-block-transitions{transition:0s all!important;-webkit-transition:0s all!important;}.ng-hide-add-active,.ng-hide-remove{display:block!important;}</style>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <base href="/hotels/"/>
# <title>네이버 호텔</title>
# <meta content="" name="description"/>
# <meta content="width=device-width" name="viewport"/>
# <meta content="9Z8Atb6svl4pPoH-8RY2N3G1VgUb1vsBC9AsDhaOEMo" name="google-site-verification"/>
# <link href="assets/images/favicon/ios_57.png" rel="apple-touch-icon" sizes="57x57"/>
# <link href="assets/images/favicon/ios_66.png" rel="apple-touch-icon" sizes="66x66"/>
# <link href="assets/images/favicon/ios_72.png" rel="apple-touch-icon" sizes="72x72"/>
# ...

# %%
#호텔이름
hotel_name= soup.select_one('strong.hotel_name')
hotel_name.text
# Out:
# '신라스테이 광화문'

# %%
#호텔등급

hotel_rank=soup.select_one('div.info_wrap span.grade')
int(hotel_rank.text[0])
# Out:
# 3

# %%
#호텔주소
hotel_addr=[ addr.strip() for addr in soup.select_one('p.addr').text.split(',')]
hotel_addr
# Out:
# ['삼봉로 71', '종로구', '서울', '대한민국']

# %%
#호텔소개
#더보기 버튼을 누른다.
#driver.find_element_by_xpath('/html/body/div/div/div[1]/div[2]/div[2]/div[4]/a').click()
driver.find_element_by_class_name('more').click()

hotel_content= soup.select_one('body > div > div > div.container.ng-scope > div.content > div.hotel_info_area > div.desc_wrap.ng-scope > p.txt')
hotel_content.text
# Out:
# '신라스테이 광화문 - <3성급:한국관광공사 인증> - 신라스테이 광화문은 5호선 광화문역 2번 출구에서 도보로 5분 거리에 있습니다. 가까운 도보 거리에 시청, 대사관, 서울 파이낸스 센터 등이 있어 비즈니스 여행객에게 편리한 위치를 자랑합니다. 뿐만 아니라 서울 4대 고궁, 북촌한옥마을과 명동까지 차로 약 10분이면 가실 수 있어 관광객분들께도 최적의 위치를 자랑합니다.'

# %%
hotel_local_name= hotel_addr[-2]
hotel_addr= hotel_addr[0]

localCode={
    '강원도':1,
    '경기도':2,
    '경상남도':3,
    '경남':3,
    '경상북도':4,
    '경북':4,
    '광주':5,
    '광주광역시':5,
    '대구':6,
    '대전':7,
    '부산':8,
    '부산광역시':8,
    '서울':9,
    '서울특별시':9,
    '세종':10,
    '세종특별시':10,
    '세종특별자치시':10,
    '인천':11,
    '인천광역시':11,
    '울산':12,
    '울산광역시':12,
    '전라남도':13,
    '전남':13,
    '전라북도':14,
    '전북':14,
    '제주도':15,
    '제주':15,
    '제주특별자치도':15,
    '충청남도':16,
    '충남':16,
    '충청북도':17,
    '충북':17
}

print('지역번호: ',localCode[hotel_local_name])
print('주소: ',hotel_addr)
# Out:
# 지역번호:  9
# 주소:  삼봉로 71

# %%
hotel_option= [ option.text for option in soup.select('i.feature')]
hotel_option
# Out:
# ['무료 와이파이',
#  '와이파이',
#  '고속 인터넷',
#  '무료 주차 가능',
#  '주차장',
#  '24시간 리셉션',
#  '외국어 구사 직원',
#  '장애인 편의 시설',
#  '드라이클리닝',
#  '세탁 서비스',
#  '모닝콜 서비스',
#  '장애인 주차 시설',
#  '피트니스센터',
#  '상점',
#  '연회장',
#  '기념품 가게',
#  '레스토랑',
#  '바/라운지',
#  '비즈니스 센터',
#  '회의실',
#  '컨퍼런스룸',
#  '화상 회의',
#  '복사기',
#  '데스크',
#  '엘리베이터',
#  '연회 시설',
#  '전시 공간',
#  '금연실',
#  '에어컨',
#  '헤어드라이어',
#  '커피/차 메이커',
#  '냉장고',
#  '케이블/위성 TV',
#  '개인 욕실',
#  '안전 금고',
#  'TV',
#  '목욕 가운',
#  '스위트룸',
#  '비데']

# %% [markdown]
# ## driver.close() vs driver.quit()
#
# - https://daeunginfo.blogspot.com/2019/06/python-selenium-close-quit.html
#
# - driver.close() 는 메모리누수가 발생할 수 있다.
# - driver.quit() 은 세션을 안전하게 종료한다.

# %%
driver.quit()

# %%
from bs4 import BeautifulSoup
from selenium import webdriver

driver = webdriver.Chrome('./chromedriver_win32/chromedriver.exe')

# 호텔디테일 페이지 url
url='https://hotel.naver.com/hotels/item?hotelId='+hotel_keys[0]+'&checkin=2021-03-12&checkout=2021-03-13&rooms=2'

driver.get(url)
req= driver.page_source
soup= BeautifulSoup(req, 'html.parser')
driver.implicitly_wait(1) #예약페이지 로드 1초 대기

#호텔이름
hotel_name= soup.select_one('div.info_wrap.type_fix > strong.hotel_name')
print(hotel_name.text)

#호텔등급
hotel_rank=soup.select_one('div.hotel_info_area > div.info_wrap.type_fix > span.grade')
print(hotel_rank.text)

#호텔주소
hotel_addr=soup.select_one('div.hotel_info_area > div.info_wrap.type_fix> div.row> p.addr')
print(hotel_addr)

driver.find_element_by_class_name('more').click()
hotel_content= soup.select_one('div.desc_wrap.ng-scope > p.txt.ng-binding')
print(hotel_content.text)


driver.quit()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-253-1f41700673e7> in <module>
#      14 #호텔이름
#      15 hotel_name= soup.select_one('div.hotel_info_area >  div.info_wrap.type_fix > strong.hotel_name')
# ---> 16 print(hotel_name.text)
#      17
#      18 #호텔등급
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
from bs4 import BeautifulSoup
from selenium import webdriver

driver = webdriver.Chrome('./chromedriver_win32/chromedriver.exe')

# 호텔디테일 페이지 url
url='https://hotel.naver.com/hotels/item?hotelId='+hotel_keys[0]+'&checkin=2021-03-12&checkout=2021-03-13&rooms=2'

driver.get(url)
time.sleep(1) #정보를 받아올때까지 기다린다.

soup= BeautifulSoup(driver.page_source, 'html.parser')

hotel_name=soup.select_one('strong.hotel_name')
print(hotel_name)

driver.quit()
# Out:
# <strong class="hotel_name ng-binding">신라스테이 광화문</strong>

# %%
from bs4 import BeautifulSoup
from selenium import webdriver

driver = webdriver.Chrome('./chromedriver_win32/chromedriver.exe')

# 호텔디테일 페이지 url
url='https://hotel.naver.com/hotels/item?hotelId='+hotel_keys[0]+'&checkin=2021-03-12&checkout=2021-03-13&rooms=2'

driver.get(url)
req= driver.page_source
soup= BeautifulSoup(req, 'html.parser')
driver.implicitly_wait(1) #예약페이지 로드 1초 대기

#호텔등급
hotel_rank=soup.select_one('span.grade')
print(hotel_rank.text)

driver.quit()
# Out:
# 3성급

# %%
from bs4 import BeautifulSoup
from selenium import webdriver
import time

driver = webdriver.Chrome('./chromedriver_win32/chromedriver.exe')

# 호텔디테일 페이지 url
url='https://hotel.naver.com/hotels/item?hotelId='+hotel_keys[0]+'&checkin=2021-03-12&checkout=2021-03-13&rooms=2'

driver.get(url)
time.sleep(1) #예약페이지 로드 1초 대기
req= driver.page_source
soup= BeautifulSoup(req, 'html.parser')


#호텔주소
hotel_addr=soup.select_one('p.addr')
print(hotel_addr)

driver.quit()
# Out:
# <p class="addr ng-binding ng-scope" ng-if="hotel.address &amp;&amp; hotel.place.fullName">삼봉로 71, 종로구, 서울, 대한민국<!-- ngIf: hotel.isRyokan --></p>

# %%
from bs4 import BeautifulSoup
from selenium import webdriver

driver = webdriver.Chrome('./chromedriver_win32/chromedriver.exe')

# 호텔디테일 페이지 url
url='https://hotel.naver.com/hotels/item?hotelId='+hotel_keys[0]+'&checkin=2021-03-12&checkout=2021-03-13&rooms=2'

driver.get(url)
req= driver.page_source
soup= BeautifulSoup(req, 'html.parser')
driver.implicitly_wait(1) #예약페이지 로드 1초 대기

driver.find_element_by_class_name('more').click()
hotel_content= soup.select_one('div.desc_wrap.ng-scope > p.txt.ng-binding')
print(hotel_content.text)


driver.quit()
# Out:
# 신라스테이 광화문 - <3성급:한국관광공사 인증> - 신라스테이 광화문은 5호선 광화문역 2번 출구에서 도보로 5분 거리에 있습니다. 가까운 도보 거리에 시청, 대사관, 서울 파이낸스 센터 등이 있어 비즈니스 여행객에게 편리한 위치를 자랑합니다. 뿐만 아니라 서울 4대 고궁, 북촌한옥마을과 명동까지 차로 약 10분이면 가실 수 있어 관광객분들께도 최적의 위치를 자랑합니다.

# %%
from bs4 import BeautifulSoup
from selenium import webdriver
import time

driver = webdriver.Chrome('./chromedriver_win32/chromedriver.exe')

# 호텔디테일 페이지 url
url='https://hotel.naver.com/hotels/item?hotelId='+hotel_keys[0]+'&checkin=2021-03-12&checkout=2021-03-13&rooms=2'

driver.get(url)
time.sleep(1) # 1초대기

req= driver.page_source
soup= BeautifulSoup(req, 'html.parser')


#호텔이름
hotel_name= soup.select_one('strong.hotel_name').text
print(hotel_name)

#호텔등급
hotel_rank=soup.select_one('span.grade').text
print(hotel_rank)

#호텔주소
hotel_addr=soup.select_one('p.addr').text
print(hotel_addr)

time.sleep(1)

driver.find_element_by_class_name('more').click()
time.sleep(1)

hotel_content= soup.select_one('div.desc_wrap.ng-scope > p.txt.ng-binding').text
print(hotel_content)


driver.quit()
# Out:
# 신라스테이 광화문
# 3성급
# 삼봉로 71, 종로구, 서울, 대한민국
# 신라스테이 광화문 - <3성급:한국관광공사 인증> - 신라스테이 광화문은 5호선 광화문역 2번 출구에서 도보로 5분 거리에 있습니다. 가까운 도보 거리에 시청, 대사관, 서울 파이낸스 센터 등이 있어 비즈니스 여행객에게 편리한 위치를 자랑합니다. 뿐만 아니라 서울 4대 고궁, 북촌한옥마을과 명동까지 차로 약 10분이면 가실 수 있어 관광객분들께도 최적의 위치를 자랑합니다.

# %% [markdown]
# ## 4200개 호텔데이터중에서 시설정보들을 모은다.

# %%
# !pip install tqdm

# %%
from bs4 import BeautifulSoup
from selenium import webdriver
import time

options= webdriver.ChromeOptions()
options.add_argument('headless')
options.add_argument('disable-gpu')

# %%
global local, hotels

localCode={
    '강원도':1,
    '경기도':2,
    '경상남도':3,
    '경남':3,
    '경상북도':4,
    '경북':4,
    '광주':5,
    '광주광역시':5,
    '대구':6,
    '대전':7,
    '부산':8,
    '부산광역시':8,
    '서울':9,
    '서울특별시':9,
    '세종':10,
    '세종특별시':10,
    '세종특별자치시':10,
    '인천':11,
    '인천광역시':11,
    '울산':12,
    '울산광역시':12,
    '전라남도':13,
    '전남':13,
    '전라북도':14,
    '전북':14,
    '제주도':15,
    '제주':15,
    '제주특별자치도':15,
    '충청남도':16,
    '충남':16,
    '충청북도':17,
    '충북':17
}

# %%
from bs4 import BeautifulSoup
from selenium import webdriver

import getHotelKeys
import time


global local, hotels

localCode = {
    '강원도': 1,
    '경기도': 2,
    '경상남도': 3,
    '경남': 3,
    '경상북도': 4,
    '경북': 4,
    '광주': 5,
    '광주광역시': 5,
    '대구': 6,
    '대전': 7,
    '부산': 8,
    '부산광역시': 8,
    '서울': 9,
    '서울특별시': 9,
    '세종': 10,
    '세종특별시': 10,
    '세종특별자치시': 10,
    '인천': 11,
    '인천광역시': 11,
    '울산': 12,
    '울산광역시': 12,
    '전라남도': 13,
    '전남': 13,
    '전라북도': 14,
    '전북': 14,
    '제주도': 15,
    '제주': 15,
    '제주특별자치도': 15,
    '충청남도': 16,
    '충남': 16,
    '충청북도': 17,
    '충북': 17
}


def get_hotel_info(key):
    one_hotel_info = {}

    options = webdriver.ChromeOptions()
    #options.add_argument('headless')
    options.add_argument('disable-gpu')
    options.add_argument("user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.66 Safari/537.36")
    driver = webdriver.Chrome('./chromedriver_win32/chromedriver.exe', options=options)
    
    # 호텔디테일 페이지 url
    url = 'https://hotel.naver.com/hotels/item?hotelId='+key
    driver.get(url)
    time.sleep(1) #페이지 로드까지 1초 대기
    
    req = driver.page_source
    soup = BeautifulSoup(req, 'html.parser')
    
    

    # 호텔이름
    hotel_name = soup.select_one('div.info_wrap > strong.hotel_name').text
    one_hotel_info['BO_TITLE'] = hotel_name

    # 호텔등급
    hotel_rank = soup.find('span', class_='grade').text
    if hotel_rank in ['1성급', '2성급', '3성급', '4성급', '5성급']:
        one_hotel_info['HOTEL_RANK']=int(hotel_rank[0])
    else:
        one_hotel_info['HOTEL_RANK']=None
        
   
    # 호텔주소
    hotel_addr_list=
    one_hotel_info['HOTEL_ADDRESS']=
    
    # 호텔소개
    driver.find_element_by_class_name('more').click()  # 더보기 버튼을 누른다.
    time.sleep(1)  # 예약페이지 로드 1초 대기
    
    hotel_content = soup.select_one('div.desc_wrap > p.txt')
    one_hotel_info['BO_CONTENT'] = hotel_content.text

    # 호텔옵션
    hotel_options = [option.text for option in soup.select('i.feature')]
    one_hotel_info['HOTEL_REAL_OPTIONS'] = hotel_options
    
    driver.quit()
    
    return one_hotel_info

# %%
get_hotel_info(hotel_keys[0])
# Out:
# {'BO_TITLE': '신라스테이 광화문',
#  'HOTEL_RANK': 3,
#  'HOTEL_ADDRESS': '삼봉로 71, 종로구, 서울, 대한민국',
#  'BO_CONTENT': '신라스테이 광화문 - <3성급:한국관광공사 인증> - 신라스테이 광화문은 5호선 광화문역 2번 출구에서 도보로 5분 거리에 있습니다. 가까운 도보 거리에 시청, 대사관, 서울 파이낸스 센터 등이 있어 비즈니스 여행객에게 편리한 위치를 자랑합니다. 뿐만 아니라 서울 4대 고궁, 북촌한옥마을과 명동까지 차로 약 10분이면 가실 수 있어 관광객분들께도 최적의 위치를 자랑합니다.',
#  'HOTEL_REAL_OPTIONS': ['무료 와이파이',
#   '와이파이',
#   '고속 인터넷',
#   '무료 주차 가능',
#   '주차장',
#   '24시간 리셉션',
#   '외국어 구사 직원',
#   '장애인 편의 시설',
#   '드라이클리닝',
#   '세탁 서비스',
#   '모닝콜 서비스',
#   '장애인 주차 시설',
#   '피트니스센터',
#   '상점',
#   '연회장',
#   '기념품 가게',
#   '레스토랑',
#   '바/라운지',
#   '비즈니스 센터',
#   '회의실',
#   '컨퍼런스룸',
#   '화상 회의',
#   '복사기',
#   '데스크',
#   '엘리베이터',
#   '연회 시설',
#   '전시 공간',
#   '금연실',
#   '에어컨',
#   '헤어드라이어',
#   '커피/차 메이커',
#   '냉장고',
#   '케이블/위성 TV',
#   '개인 욕실',
#   '안전 금고',
#   'TV',
#   '목욕 가운',
#   '스위트룸',
#   '비데']}

# %%
for key in tqdm_notebook( hotel_keys[:6]):
    result=get_hotel_info(key)
    print(result)
    hotels.append(result)
# Out:
# ...
# {'BO_TITLE': '신라스테이 광화문', 'HOTEL_RANK': 3, 'HOTEL_ADDRESS': '삼봉로 71, 종로구, 서울, 대한민국', 'BO_CONTENT': '신라스테이 광화문 - <3성급:한국관광공사 인증> - 신라스테이 광화문은 5호선 광화문역 2번 출구에서 도보로 5분 거리에 있습니다. 가까운 도보 거리에 시청, 대사관, 서울 파이낸스 센터 등이 있어 비즈니스 여행객에게 편리한 위치를 자랑합니다. 뿐만 아니라 서울 4대 고궁, 북촌한옥마을과 명동까지 차로 약 10분이면 가실 수 있어 관광객분들께도 최적의 위치를 자랑합니다.', 'HOTEL_REAL_OPTIONS': ['무료 와이파이', '와이파이', '고속 인터넷', '무료 주차 가능', '주차장', '24시간 리셉션', '외국어 구사 직원', '장애인 편의 시설', '드라이클리닝', '세탁 서비스', '모닝콜 서비스', '장애인 주차 시설', '피트니스센터', '상점', '연회장', '기념품 가게', '레스토랑', '바/라운지', '비즈니스 센터', '회의실', '컨퍼런스룸', '화상 회의', '복사기', '데스크', '엘리베이터', '연회 시설', '전시 공간', '금연실', '에어컨', '헤어드라이어', '커피/차 메이커', '냉장고', '케이블/위성 TV', '개인 욕실', '안전 금고', 'TV', '목욕 가운', '스위트룸', '비데']}
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-249-27dbf141910c> in <module>
#       1 for key in tqdm_notebook( hotel_keys[:6]):
# ----> 2     result=get_hotel_info(key)
# ...

# %%
hotels
# Out:
# [{'BO_TITLE': '신라스테이 광화문',
#   'HOTEL_RANK': 4,
#   'HOTEL_ADDRESS': '삼봉로 71',
#   'HOTEL_LOCAL_CODE': 9,
#   'HOTEL_CONTENT': '신라스테이 광화문 - <3성급:한국관광공사 인증> - 신라스테이 광화문은 5호선 광화문역 2번 출구에서 도보로 5분 거리에 있습니다. 가까운 도보 거리에 시청, 대사관, 서울 파이낸스 센터 등이 있어 비즈니스 여행객에게 편리한 위치를 자랑합니다. 뿐만 아니라 서울 4대 고궁, 북촌한옥마을과 명동까지 차로 약 10분이면 가실 수 있어 관광객분들께도 최적의 위치를 자랑합니다.',
#   'HOTEL_REAL_OPTION': ['무료 와이파이',
#    '와이파이',
#    '고속 인터넷',
#    '무료 주차 가능',
#    '주차장',
#    '24시간 리셉션',
#    '외국어 구사 직원',
#    '장애인 편의 시설',
#    '드라이클리닝',
#    '세탁 서비스',
#    '모닝콜 서비스',
#    '장애인 주차 시설',
#    '피트니스센터',
#    '상점',
#    '연회장',
#    '기념품 가게',
#    '레스토랑',
#    '바/라운지',
#    '비즈니스 센터',
#    '회의실',
#    '컨퍼런스룸',
#    '화상 회의',
#    '복사기',
#    '데스크',
#    '엘리베이터',
#    '연회 시설',
#    '전시 공간',
#    '금연실',
#    '에어컨',
#    '헤어드라이어',
#    '커피/차 메이커',
#    '냉장고',
#    '케이블/위성 TV',
#    '개인 욕실',
#    '안전 금고',
#    'TV',
#    '목욕 가운',
#    '스위트룸',
#    '비데']},
#  {'BO_TITLE': '나인트리 프리미어 호텔 인사동',
#   'HOTEL_RANK': 3,
# ...

# %%
len(hotels)
# Out:
# 290

# %%
import copy

# %%
hotel_tmp=copy.deepcopy(hotels)
len(hotel_tmp)
# Out:
# 290

# %%
hotel_tmp
# Out:
# [{'BO_TITLE': '신라스테이 광화문',
#   'HOTEL_RANK': 4,
#   'HOTEL_ADDRESS': '삼봉로 71',
#   'HOTEL_LOCAL_CODE': 9,
#   'HOTEL_CONTENT': '신라스테이 광화문 - <3성급:한국관광공사 인증> - 신라스테이 광화문은 5호선 광화문역 2번 출구에서 도보로 5분 거리에 있습니다. 가까운 도보 거리에 시청, 대사관, 서울 파이낸스 센터 등이 있어 비즈니스 여행객에게 편리한 위치를 자랑합니다. 뿐만 아니라 서울 4대 고궁, 북촌한옥마을과 명동까지 차로 약 10분이면 가실 수 있어 관광객분들께도 최적의 위치를 자랑합니다.',
#   'HOTEL_REAL_OPTION': ['무료 와이파이',
#    '와이파이',
#    '고속 인터넷',
#    '무료 주차 가능',
#    '주차장',
#    '24시간 리셉션',
#    '외국어 구사 직원',
#    '장애인 편의 시설',
#    '드라이클리닝',
#    '세탁 서비스',
#    '모닝콜 서비스',
#    '장애인 주차 시설',
#    '피트니스센터',
#    '상점',
#    '연회장',
#    '기념품 가게',
#    '레스토랑',
#    '바/라운지',
#    '비즈니스 센터',
#    '회의실',
#    '컨퍼런스룸',
#    '화상 회의',
#    '복사기',
#    '데스크',
#    '엘리베이터',
#    '연회 시설',
#    '전시 공간',
#    '금연실',
#    '에어컨',
#    '헤어드라이어',
#    '커피/차 메이커',
#    '냉장고',
#    '케이블/위성 TV',
#    '개인 욕실',
#    '안전 금고',
#    'TV',
#    '목욕 가운',
#    '스위트룸',
#    '비데']},
#  {'BO_TITLE': '나인트리 프리미어 호텔 인사동',
#   'HOTEL_RANK': 3,
# ...

# %%
all_hotel_options=[]

for hotel_key in tqdm_notebook(hotel_keys):
    driver = webdriver.Chrome('./chromedriver_win32/chromedriver.exe')
    url='https://hotel.naver.com/hotels/item?hotelId='+hotel_key+'&rooms=2'
    driver.get(url)
    req=driver.page_source
    soup=BeautifulSoup(req,'html.parser')
    
    all_hotel_options.extend(option.text for option in soup.select('i.feature'))
    driver.implicitly_wait(1)
    driver.close()

    
set(all_hotel_options) #중복을 배제함.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-60-34e5324c27fd> in <module>
#       2
#       3 for hotel_key in hotel_keys:
# ----> 4     driver = webdriver.Chrome('./chromedriver_win32/chromedriver.exe')
#       5     url='https://hotel.naver.com/hotels/item?hotelId='+hotel_key+'&rooms=2'
# ...

# %%
from tqdm import tqdm_notebook

# %%
hotel_keys[93]
# Out:
# 'hotel:Shilla_Stay_Mapo'

# %%
#호텔옵션
options={
    '와이파이':False,
    '조식': False,
    '레스토랑': False,
    '세탁': False,
    '24시간 리셉션': False,
    '수하물 보관': False,
    '수영장': False,
    '피트니스': False,
    '스파 & 사우나': False,
    '미용실': False,
    '카페': False,
    '비즈니스 시설': False,
    '주차': False,
    '공항셔틀': False,
    '장애인 편의시설': False,
    '바 & 라운지': False,
    '주방': False,
    '아이돌봄 서비스': False,
    '룸서비스': False,
    '애완동물 동반': False
}

optionList={
    '와이파이':['와이파이', '무료 와이파이', '고속인터넷'],
    '조식': [],
    '레스토랑': [],
    '세탁': [],
    '24시간 리셉션': [],
    '수하물 보관': [],
    '수영장': [],
    '피트니스': [],
    '스파 & 사우나': [],
    '미용실': [],
    '카페': [],
    '비즈니스 시설': [],
    '주차': [],
    '공항셔틀': [],
    '장애인 편의시설': [],
    '바 & 라운지': [],
    '주방': [],
    '아이돌봄 서비스': [],
    '룸서비스': [],
    '애완동물 동반': []
}
