# %% [markdown]
# # hotel key 데이터 구하기

# %%
from bs4 import BeautifulSoup
from selenium import webdriver
from tqdm import tqdm_notebook
import time

global options
options = webdriver.ChromeOptions()
options.add_argument('headless')
options.add_argument('window-size=1920x1080')
options.add_argument('disable-gpu')
options.add_argument("user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.66 Safari/537.36")

# %%
# location: 지역

local_url={
    '서울':'https://hotel.naver.com/hotels/list?destination=place:Seoul',
    '부산':'https://hotel.naver.com/hotels/list?destination=place:Busan_Province',
    '속초':'https://hotel.naver.com/hotels/list?destination=place:Sokcho',
    '경주':'https://hotel.naver.com/hotels/list?destination=place:Gyeongju',
    '강릉':'https://hotel.naver.com/hotels/list?destination=place:Gangneung',
    '여수':'https://hotel.naver.com/hotels/list?destination=place:Yeosu',
    '수원':'https://hotel.naver.com/hotels/list?destination=place:Suwon',
    '제주':'https://hotel.naver.com/hotels/list?destination=place:Jeju_Province',
    '인천':'https://hotel.naver.com/hotels/list?destination=place:Incheon_Metropolitan_City',
    '대구':'https://hotel.naver.com/hotels/list?destination=place:Daegu_Metropolitan_City',
    '전주':'https://hotel.naver.com/hotels/list?destination=place:Jeonju',
    '광주':'https://hotel.naver.com/hotels/list?destination=place:Gwangju_Metropolitan_City',
    '울산':'https://hotel.naver.com/hotels/list?destination=place:Ulsan_Metropolitan_City',
    '평창':'https://hotel.naver.com/hotels/list?destination=place:Pyeongchang',
    '군산':'https://hotel.naver.com/hotels/list?destination=place:Gunsan',
    '양양':'https://hotel.naver.com/hotels/list?destination=place:Yangyang',
    '춘천':'https://hotel.naver.com/hotels/list?destination=place:Chuncheon',
    '대전':'https://hotel.naver.com/hotels/list?destination=place:Daejeon_Metropolitan_City',
    '천안':'https://hotel.naver.com/hotels/list?destination=place:Cheonan',
    '세종':'https://hotel.naver.com/hotels/list?destination=place:Sejong',
    '청주':'https://hotel.naver.com/hotels/list?destination=place:Cheongju'
}

def get_hotel_data(url):
    #driverOpen
    driver= webdriver.Chrome('chromedriver.exe', options=options)
    driver.get(url)
    req= driver.page_source
    soup=BeautifulSoup(req,'html.parser')
    
    result=[]

    driver.implicitly_wait(5) #5초 대기
    detail_keys=soup.select('ul.lst_hotel > li.ng-scope')
    result.extend([ key['id'] for key in detail_keys])

    #다음버튼을 누른다.
    driver.find_element_by_xpath('/html/body/div/div/div[1]/div[2]/div[6]/div[2]/a[2]').click() 

    #창을 닫는다.
    driver.quit()
    return result
        

hotel_keys=[]
for local in tqdm_notebook(local_url.keys()):
    hotel_keys.extend(get_hotel_data(local_url[local]))
# Out:
# HBox(children=(IntProgress(value=0, max=21), HTML(value='')))

# %%
hotel_keys
# Out:
# ['hotel:Shilla_Stay_Gwanghwamun',
#  'hotel:Nine_Tree_Premier_Hotel_Insadong',
#  'hotel:Shilla_Stay_Yeoksam',
#  'hotel:Shilla_Stay_Seodaemun',
#  'hotel:GLAD_Gangnam_COEX_Center',
#  'hotel:Glad_Mapo',
#  'hotel:LOTTE_City_Hotel_Myeongdong',
#  'hotel:Shilla_Stay_Samsung',
#  'hotel:Shilla_Stay_Seocho',
#  'hotel:Glad_Yeouido',
#  'hotel:Nine_Tree_Premier_Hotel_Myeongdong_II',
#  'hotel:LOTTE_City_Hotel_Guro',
#  'hotel:L7_Gangnam_by_LOTTE',
#  'hotel:Shilla_Stay_Mapo',
#  'hotel:Orakai_Cheonggyesan_Hotel',
#  'hotel:Sheraton_Seoul_D_Cube_City_Hotel',
#  'hotel:Lotte_Hotel_World',
#  'hotel:Hotel_PJ_Myeongdong',
#  'hotel:Orakai_Daehakro_Hotel',
#  'hotel:Signiel_Seoul',
#  'hotel:Shilla_Stay_Haeundae',
#  'hotel:Paradise_Hotel_Busan',
#  'hotel:Lavalse_Hotel',
#  'hotel:Ramada_Encore_by_Wyndham_Busan_Haeundae',
#  'hotel:Grand_Josun_Busan',
#  'hotel:Hilton_Busan',
#  'hotel:Haeundae_Centum_Hotel',
#  'hotel:Park_Hyatt_Busan',
#  'hotel:Lavi_De_Atlan_Hotel',
#  'hotel:Signiel_Busan',
#  'hotel:Best_Western_Plus_Busan_Songdo',
#  'hotel:Best_Western_Haeundae_Hotel',
#  'hotel:Centum_Premier_Hotel',
#  'hotel:The_Westin_Chosun_Busan',
#  'hotel:Hotel_Nongshim',
#  'hotel:Crown_Harbour_Hotel_Busan',
#  'hotel:Haeundae_Seacloud_Hotel_Residence',
#  'hotel:Arban_Hotel',
#  'hotel:Felix_Hotel_by_STX',
#  'hotel:Marianne_Hotel_Busan',
#  'hotel:Ramada_Sokcho_Hotel',
#  'hotel:Sea_Cruise_Hotel',
#  'hotel:Lotte_Resort_Sokcho',
#  'hotel:The_Class_300_Condo',
#  'hotel:Marinabay_Sokcho',
#  'hotel:Kensington_Hotel_Seorak',
#  'hotel:Sunrise_Hotel_Sokcho',
#  'hotel:Hotel_Maremons',
#  'hotel:Pampas_Resort',
#  'hotel:The_Blue_Mark_Hotel_Sokcho',
#  'hotel:HanwhaResort_Seorak_Sorano',
#  'hotel:Fine_Resort_Sulak',
#  'hotel:Del_Pino_Golf_Resort',
#  'hotel:IPark_Condominium',
#  'hotel:Goodmorning_Family_Hotel_Sokcho',
#  'hotel:Hyundai_Soo_Resort_Sokcho',
#  'hotel:Kumho_Seorak_Resort',
#  'hotel:World_State_Residence_Hotel',
#  'hotel:With_U_Hotel_Guesthouse',
#  'hotel:Family_House_Sokcho',
#  'hotel:Lahan_Select_Gyeongju',
#  'hotel:Commodore_Hotel_Gyeongju',
#  'hotel:Kensington_Resort_Gyeongju',
#  'hotel:Hilton_Gyeongju',
#  'hotel:Ramada_Hotel_Resort_Gyeongju',
#  'hotel:The_K_Hotel_Gyeongju',
#  'hotel:Gyeongju_Tourist_Hotel_GG',
#  'hotel:Gyeongju_Kolon_Hotel',
#  'hotel:Benikea_Swiss_Rosen_Hotel',
#  'hotel:Rivertain_Hotel_Gyeongju',
#  'hotel:Mini_Hotel_141',
#  'hotel:Arisu_Gyeongju',
#  'hotel:Sono_Belle_Gyeongju',
#  'hotel:The_Suites_Hotel_Gyeongju',
#  'hotel:Sugar_Hotel_Gyeongju',
#  'hotel:Sungho_Resort',
#  'hotel:Gaya_Mini_Hotel',
#  'hotel:Hotel_Valentine_Gyeongju',
#  'hotel:Another_World_Pension',
#  'hotel:Princess_Pension',
#  'hotel:Skybay_Hotel_Gyeongpo',
#  'hotel:St_Johns_Hotel',
#  'hotel:Sun_Cruise_Resort_and_Yacht',
#  'hotel:Tops_10_Gangneung_Hotel',
#  'hotel:Gangneung_City_Hotel',
#  'hotel:Seabay_Hotel_Gangneung',
#  'hotel:Gangneung_Tourist_Hotel',
#  'hotel:Hotel_Cube_Gangneung',
#  'hotel:Hotel_Avvio',
#  'hotel:Hotel_Bombom',
#  'hotel:SEAMARQ_Hotel',
#  'hotel:Winners_Hotel',
#  'hotel:Gyeongpodae_The_Hotel_Business',
#  'hotel:Hotel_November',
#  'hotel:Benikea_Hotel_Mountain_and_Sea_Jumunjin_Resort',
#  'hotel:The_HongC_Hotel_Gangneung',
#  'hotel:Grey_Hotel_Gangneung',
#  'hotel:Hong_C_Hotel_Gangneung_Station',
#  'hotel:Gangneung_Good_Camping_Pension',
#  'hotel:Gangneung_Sea_Sky_Hotel',
#  'hotel:Yeosu_UTOP_MARINA_Hotel_Resort',
#  'hotel:Yeosu_Venezia_Hotel_Resort',
#  'hotel:Ramada_Plaza_Yeosu',
#  'hotel:Sono_Calm_Yeosu',
#  'hotel:Hidden_Bay_Hotel_Yeosu',
#  'hotel:The_Hotel_Soo',
#  'hotel:Hotel_JCS_Yeosu',
#  'hotel:Hotel_Haven_Yeosu',
#  'hotel:Hotel_The_One_Yeosu',
#  'hotel:Ocean_Hill_Hotel_Yeosu',
#  'hotel:DARAKHYU_Yeosu_Capsule_Hotel_by_WALKERHILL',
#  'hotel:La_Terrace_Cove_Suite',
#  'hotel:Matthieu_Hotel_Yeosu',
#  'hotel:Benikea_Hotel_Yeosu',
#  'hotel:BBeach_Tourist_Hotel',
#  'hotel:The_Ocean_Hotel_Yeosu',
#  'hotel:K_Grand_Hostel_Yeosu',
#  'hotel:Sugar_Brium',
#  'hotel:Narsha_Hotel',
#  'hotel:Shell_Stone_Yeosu_Business_Hotel',
#  'hotel:Ramada_Plaza_Suwon_Hotel',
#  'hotel:Holiday_Inn_Express_Suwon_Ingye',
#  'hotel:Courtyard_by_Marriott_Suwon',
#  'hotel:Vella_Suite_Hotel',
#  'hotel:Novotel_Ambassador_Suwon',
#  'hotel:Landmark_Hotel_Suwon',
#  'hotel:Hotel_Arte_Suwon',
#  'hotel:Symphony_Hotel_Suwon',
#  'hotel:Reborn_Suwon_Silkroad_Hotel',
#  'hotel:Hotel_Gaden',
#  'hotel:Korea_Hotel_Suwon',
#  'hotel:Alex_72_Hotel',
#  'hotel:Suwon_Dono_Hotel',
#  'hotel:Suwon_Reve_Hotel',
#  'hotel:I_Y_Hotel',
#  'hotel:Value_Hotel_Worldwide_Suwon',
#  'hotel:Benikea_New_Suwon_Tourist_Hotel',
#  'hotel:MS_Hotel_Suwon',
#  'hotel:Amour_Hotel_suwon',
#  'hotel:Ibis_Ambassador_Suwon',
#  'hotel:Shinhwa_Jeju_Shinhwa_World_Hotels_Resorts',
#  'hotel:Landing_Jeju_Shinhwa_World_HotelsResorts',
#  'hotel:Maison_Glad_Jeju',
#  'hotel:Hotel_Nanta_Jeju',
#  'hotel:The_Shilla_Jeju',
#  'hotel:Marriott_Jeju_Shinhwa_World_Hotels_Resorts',
#  'hotel:Hotel_Grand_Rbie_Seogwipo_Ocean',
#  'hotel:Ramada_Jeju_City_Hotel',
#  'hotel:Lotte_Hotel_Jeju',
#  'hotel:Shilla_Stay_Jeju',
#  'hotel:Ramada_Plaza_Jeju_Hotel',
#  'hotel:LOTTE_City_Hotel_Jeju',
#  'hotel:Hotel_Whistle_Lark',
#  'hotel:Best_Western_Jeju_Hotel',
#  'hotel:Somerset_Jeju_Shinhwa_World',
#  'hotel:The_Qube_Resort_Jeju',
#  'hotel:Hidden_Cliff_Hotel_Nature',
#  'hotel:Haevichi_Hotel_Resort_Jeju',
#  'hotel:Utop_Ubless_Hotel',
#  'hotel:First70_Hotel',
#  'hotel:Paradise_City',
#  'hotel:Nest_Hotel_Incheon',
#  'hotel:Songdo_Central_Park_Hotel',
#  'hotel:Orakai_Songdo_Park_Hotel',
#  'hotel:Sheraton_Grand_Incheon_Hotel',
#  'hotel:Golden_Tulip_Incheon_Airport_Hotel_Suites',
#  'hotel:Oakwood_Premier_Incheon',
#  'hotel:Best_Western_Harbor_Park_Hotel_Incheon',
#  'hotel:Ramada_Songdo_Hotel',
#  'hotel:Holiday_Inn_Incheon_Songdo',
#  'hotel:Riviera_Verium_Hotel',
#  'hotel:Hotel_Skypark_Incheon_Songdo',
#  'hotel:Ramada_Incheon',
#  'hotel:Grand_Hyatt_Incheon',
#  'hotel:Western_Grace_Hotel',
#  'hotel:Toyoko_Inn_Incheon_Bupyeong',
#  'hotel:Days_Hotels_Suites_by_Wyndham_Incheon_Airport',
#  'hotel:Central_Plaza_Hotel_Incheon',
#  'hotel:Benikea_Wolmido_The_Bliss_Hotel',
#  'hotel:Howard_Johnson_by_Wyndham_Incheon_Airport',
#  'hotel:Toyoko_inn_Daegu_Dongseongro',
#  'hotel:Hotel_Inter_Burgo_Exco',
#  'hotel:Eldis_Regent_Hotel',
#  'hotel:Rivertain_Hotel',
#  'hotel:Hotel_Inter_Burgo_Daegu_Main_Building',
#  'hotel:Daegu_Grand_Hotel',
#  'hotel:Hotel_Laonzena',
#  'hotel:Hotel_Ariana_Daegu',
#  'hotel:February_Hotel_Dongseongro',
#  'hotel:Hotel_Susung',
#  'hotel:Hotel_Yeogiatte_Daegu_Station',
#  'hotel:Hotel_Noblestay',
#  'hotel:Queen_Vell_Hotel',
#  'hotel:Forest_701_Hotel',
#  'hotel:Hotel_Elysia',
#  'hotel:Hotel_Instar',
#  'hotel:Daegu_Hilltop_Hotel',
#  'hotel:Hotel_Encore',
#  'hotel:Hotel_Savoy_Daegu',
#  'hotel:Hotel_Insomnia',
#  'hotel:Lahan_Hotel_Jeonju',
#  'hotel:RAMADA_Jeonju',
#  'hotel:Roni_Tourist_Hotel',
#  'hotel:Best_Western_PLUS_Jeonju_Hotel',
#  'hotel:N_Bridge_Hotel_Jeonju',
#  'hotel:The_Classic_Hotel_Jeonju',
#  'hotel:Jeonju_Lime_Hotel',
#  'hotel:Jeonju_Tourist_Hotel',
#  'hotel:Royal_room_of_King',
#  'hotel:Hotel_Davin',
#  'hotel:Pungnam_Tourist_Hotel',
#  'hotel:Yihua_Hotel_Jeonju',
#  'hotel:Jazz_Around_Hotel',
#  'hotel:JS_Hotel',
#  'hotel:Grandhillstone_Hotel',
#  'hotel:Hotel_SoL_Jeonju',
#  'hotel:Benikea_Jeonju_Hansung_Hotel',
#  'hotel:Jeonju_Yeonghwa_Hotel',
#  'hotel:Hotel_Barahan',
#  'hotel:Sarangnamoo_Hanok_Guesthouse',
#  'hotel:UTOP_Boutique_Hotel_Residence',
#  'hotel:Holiday_Inn_Gwangju',
#  'hotel:Ramada_Plaza_Gwangju',
#  'hotel:Gwangju_Madrid_Hotel',
#  'hotel:Gwangju_Aura_Hotel',
#  'hotel:Hotel_The_Spot',
#  'hotel:Hotel_B_Gwangju',
#  'hotel:Ballantine_Hotel_Gwangju',
#  'hotel:ACC_Design_Hotel',
#  'hotel:Firenze_Tourist_Hotel',
#  'hotel:Top_Cloud_Hotel_Gwangju',
#  'hotel:Bentley_Hotel_Gwangju',
#  'hotel:Duzon_Hotel',
#  'hotel:Hotel_Stay_53',
#  'hotel:Noble_Stay_Hotel',
#  'hotel:Biennale_Hotel',
#  'hotel:Hotel_The_May_Gwangju',
#  'hotel:Venture_Business_Hotel',
#  'hotel:A_C_C_Business_Hotel',
#  'hotel:Hotel_Our_Youth',
#  'hotel:Shilla_Stay_Ulsan',
#  'hotel:Hotel_Riverside_Ulsan',
#  'hotel:LOTTE_City_Hotel_Ulsan',
#  'hotel:Ulsan_City_Hotel',
#  'hotel:Staz_Hotel_Ulsan',
#  'hotel:Lotte_Hotel_Ulsan',
#  'hotel:Hotel_Hyundai_Ulsan_by_Lahan',
#  'hotel:Toyoko_Inn_Hotel_Ulsan_Samsan_dong',
#  'hotel:Hotel_Yeoubi',
#  'hotel:Hotel_Daoom',
#  'hotel:Mercure_Ambassador_Ulsan',
#  'hotel:Brown_Dot_Hotel_Ulsan_Sincheon',
#  'hotel:Residence_Hotel_Blue_Ocean_View',
#  'hotel:H_Hotel_Ulsan',
#  'hotel:Brown_Dot_Hotel_Ulsan_Jangsaengpo',
#  'hotel:Brown_Dot_Hotel_Ulsan_Samsan',
#  'hotel:Hotel_Frenchcode_Ulsan',
#  'hotel:Haeya_Boutique_Hotel',
#  'hotel:Ulsan_Baenaegol_Paradise_Pension',
#  'hotel:Ulsan_Ganjeolgot_view_Pension',
#  'hotel:Ramada_Hotel_Suites_by_Wyndham_Gangwon_Pyeongchang',
#  'hotel:Kensington_Hotel_Pyeongchang',
#  'hotel:Phoenix_Pyeongchang_Resort',
#  'hotel:The_White_Hotel_Pyeongchang',
#  'hotel:Intercontinental_Alpensia_Pyeongchang_Resort',
#  'hotel:Phoenix_Pyeongchang_Hotel',
#  'hotel:Holiday_Inn_Resort_Alpensia_Pyeongchang',
#  'hotel:AM_Hotel',
#  'hotel:Holiday_Inn_Suites_Alpensia_Pyeongchang_Suites',
#  'hotel:Korea_Palace',
#  'hotel:Dragon_Valley_Hotel',
#  'hotel:Hotel_the_maru',
#  'hotel:Elf_Spa_Resort_Hotel',
#  'hotel:HanwhaResort_Pyeongchang',
#  'hotel:Polaris_700_101Dong',
#  'hotel:Pyeongchang_I_Want_Resort',
#  'hotel:Yongpyong_Resort_Tower_Condo',
#  'hotel:Yongpyong_Resort_Villa_Condo',
#  'hotel:The_Story_Residence',
#  'hotel:White_Cabin_Pension',
#  'hotel:Ramada_Gunsan_Hotel',
#  'hotel:Avon_Hotel_Gunsan',
#  'hotel:Best_Western_Hotel_Gunsan',
#  'hotel:Hotel_Oscar_Suite',
#  'hotel:Benikea_Ariul_Hotel',
#  'hotel:Chakan_Hotel',
#  'hotel:Alice_Hotel_Gunsan',
#  'hotel:Ritz_Plaza_Hotel_Gunsan',
#  'hotel:Motel_Rings',
#  'hotel:Sunrise_Hill_Tourist_Hotel',
#  'hotel:Q_Motel_Gunsan',
#  'hotel:Gunsan_little_Prince_Hotel',
#  'hotel:Paradise_Hotel_Gunsan',
#  'hotel:Gunsan_JNK_Classic_Hotel_Gold',
#  'hotel:Hwadam_Inn',
#  'hotel:Gunsan_Yeomirang_Guesthouse',
#  'hotel:Gunsan_Seunghaville_Guesthouse',
#  'hotel:Tower_Palace_Tourist_Hotel',
#  'hotel:Gunsan_JNK_Classic_Hotel_Gray',
#  'hotel:Gunsan_Western_Hotel',
#  'hotel:Naksan_Beach_Hotel',
#  'hotel:Dignity_Hotel_Yangyang',
#  'hotel:Sol_Beach_Yangyang',
#  'hotel:EL_Hotel',
#  'hotel:Yangyang_International_Airport_Hotel',
#  'hotel:Osaek_Greenyard_Hotel',
#  'hotel:The_N_Resort_Hotel_Spa_YangYang',
#  'hotel:Two_Y_Hotel',
#  'hotel:La_Famille_Yangyang',
#  'hotel:Sea_Stay',
#  'hotel:The_Suites_Hotel_Naksan',
#  'hotel:Zio_Resort',
#  'hotel:Benikea_Hotel_Mountain_Ocean_Yangyang',
#  'hotel:Il_Mare_Pension',
#  'hotel:Nacksan_Oceanvalley_Resort',
#  'hotel:38_Marin_Resort',
#  'hotel:Seolrem_9',
#  'hotel:Sulhwa_Motel_and_Pension',
#  'hotel:Yangyang_Sweet_Pension',
#  'hotel:Naksan_Crova_Condotel',
#  'hotel:The_Venezia_Suite_Hotel',
#  'hotel:Heyy_Chuncheon',
#  'hotel:KTG_Sangsangmadang_Chuncheon_Stay',
#  'hotel:Club_Inner_Hotel_Resort',
#  'hotel:Benikea_Chuncheon_Bears_Hotel',
#  'hotel:Elysian_Gangchon_Resort_Chuncheon',
#  'hotel:1962business_Hotel',
#  'hotel:Sejong_Hotel_Chunchon',
#  'hotel:Love_and_story_pension',
#  'hotel:Gangchon_Beautiful_Pension',
#  'hotel:Chuncheon_Hotel_Gongjicheon',
#  'hotel:Chuncheon_hotel_bentley',
#  'hotel:Chuncheon_Bom_Stay',
#  'hotel:Hotel_Riversidecozy',
#  'hotel:Chuncheon_Central_Hotel',
#  'hotel:Gyerim_Motel',
#  'hotel:Lerocherrouge_Hotel',
#  'hotel:Florian_Pension',
#  'hotel:Grand_Motel_Chuncheon',
#  'hotel:Vivaldi_Motel',
#  'hotel:LOTTE_City_Hotel_Daejeon',
#  'hotel:Ramada_by_Wyndham_Daejeon',
#  'hotel:Yousung_Hotel',
#  'hotel:Toyoko_Inn_Daejeon_Government_Complex',
#  'hotel:Hotel_Graytone_Dunsan',
#  'hotel:Hotel_Interciti',
#  'hotel:Benikea_Technovalley_Hotel',
#  'hotel:Boutique_Hotel_Lacky',
#  'hotel:Hotel_Sunshine_Daejeon',
#  'hotel:Good_Morning_Residence_Hue',
#  'hotel:Benikea_Hotel_Daelim',
#  'hotel:Daejeon_Namoo_Hotel',
#  'hotel:Residence_Hotel_Line',
#  'hotel:Hotel_ICC',
#  'hotel:Hotel_Stendhal',
#  'hotel:Hotel_Skypark_Daejeon_1',
#  'hotel:SNabom_Hotel',
#  'hotel:The_Empress_Hotel_Daejeon',
#  'hotel:Daejeon_Ean_Residence_Hotel',
#  'hotel:Laon_Convention',
#  'hotel:Shilla_Stay_Cheonan',
#  'hotel:ON_City_Hotel',
#  'hotel:Sono_Belle_Cheonan',
#  'hotel:The_Mains_Hotel',
#  'hotel:Brown_Dot_Hotel_Cheonan_Dongnam',
#  'hotel:Cheonan_K2_Hotel',
#  'hotel:Cheonan_Metro_Tourist_Hotel',
#  'hotel:Hotel_T_Point',
#  'hotel:Class_Hotel_Cheonan',
#  'hotel:Cheonan_Vue_Hotel',
#  'hotel:Hotel_Bobos_Cheonan',
#  'hotel:Brown_Dot_Hotel_Cheonan',
#  'hotel:Hotel_Vole_Cheonan',
#  'hotel:ON_Smart_Hotel',
#  'hotel:Zaza_Hotel_Cheonan',
#  'hotel:Shourin_Hotel',
#  'hotel:Urbanstay',
#  'hotel:Cheonan_City_Hotel',
#  'hotel:Cheonan_Business_Hotel',
#  'hotel:E_Cheonan_Hotel',
#  'hotel:Sejong_Feel_Drive_in',
#  'hotel:Sejong_Rodem_Hill_Pension',
#  'hotel:Sejong_Royal',
#  'hotel:Mok_Hyang_Jae_Pension',
#  'hotel:Feel_Love_Drive_in_Motel',
#  'hotel:Sejoong_City_Osong_Hotel',
#  'hotel:H_Hotel_Sejong_City',
#  'hotel:Hotel_Lacky_Cheongju',
#  'hotel:Hotel_Museo',
#  'hotel:The_Mark_Hotel_Cheongju',
#  'hotel:Sono_Belle_Cheonan',
#  'hotel:Ink_Hotel_Gongju',
#  'hotel:Cheongju_Maryjane_Hotel',
#  'hotel:Mini_Hotel_Cheongju',
#  'hotel:Business_Y_Hotel',
#  'hotel:Gongju_Ein_Haus_2',
#  'hotel:Hotel_Gongju',
#  'hotel:Nibelungen_Hotel',
#  'hotel:Hotel_Maru',
#  'hotel:Cheongju_Manhattan',
#  'hotel:Sejoong_City_Osong_Hotel',
#  'hotel:Grand_Plaza_Cheongju',
#  'hotel:Hotel_Lacky_Cheongju',
#  'hotel:Hotel_Museo',
#  'hotel:H_Hotel_Sejong_City',
#  'hotel:The_Mark_Hotel_Cheongju',
#  'hotel:Cheongju_Namoo_Hotel',
#  'hotel:J_One_Hotel',
#  'hotel:Cheongju_Maryjane_Hotel',
#  'hotel:Mini_Hotel_Cheongju',
#  'hotel:Business_Y_Hotel',
#  'hotel:HOTEL_YaJa_WestGate',
#  'hotel:Sejong_Spatel',
#  'hotel:Nibelungen_Hotel',
#  'hotel:Cheongju_Brown_Dot_Hotel',
#  'hotel:Cheongju_Manhattan',
#  'hotel:Cheongju_Geumgwansup_Byeoljang_Pension',
#  'hotel:Cheongju_LuCe_Hotel',
#  'hotel:Xian_Hotel',
#  'hotel:Hotel_Born_Cheongju']

# %%
len(hotel_keys)
# Out:
# 420

# %% [markdown]
# # hotel 데이터 구하기

# %%
from bs4 import BeautifulSoup
from selenium import webdriver

import getHotelKeys
import time


global local, hotels

localCode = {
    '강원도': 1,
    '경기도': 2,
    '경상남도': 3,
    '경남': 3,
    '경상북도': 4,
    '경북': 4,
    '광주': 5,
    '광주광역시': 5,
    '대구': 6,
    '대전': 7,
    '부산': 8,
    '부산광역시': 8,
    '서울': 9,
    '서울특별시': 9,
    '세종': 10,
    '세종특별시': 10,
    '세종특별자치시': 10,
    '인천': 11,
    '인천광역시': 11,
    '울산': 12,
    '울산광역시': 12,
    '전라남도': 13,
    '전남': 13,
    '전라북도': 14,
    '전북': 14,
    '제주도': 15,
    '제주': 15,
    '제주특별자치도': 15,
    '충청남도': 16,
    '충남': 16,
    '충청북도': 17,
    '충북': 17
}

    

def get_hotel_info(key):
    try:
        one_hotel_info = {}

        driver = webdriver.Chrome('chromedriver.exe', options=options)

        # 호텔디테일 페이지 url
        url = 'https://hotel.naver.com/hotels/item?hotelId='+key
        driver.get(url)
        time.sleep(1) #페이지 로드까지 1초 대기

        req = driver.page_source
        soup = BeautifulSoup(req, 'html.parser')

        # 호텔이름
        hotel_name = soup.select_one('div.info_wrap > strong.hotel_name').text
        one_hotel_info['BO_TITLE'] = hotel_name

        # 호텔등급
        hotel_rank = soup.find('span', class_='grade').text
        if hotel_rank in ['1성급', '2성급', '3성급', '4성급', '5성급']:
            one_hotel_info['HOTEL_RANK']=int(hotel_rank[0])
        else:
            one_hotel_info['HOTEL_RANK']=None

        # 호텔주소
        hotel_addr_list= [addr for addr in soup.select_one('p.addr').text.split(', ')]
        one_hotel_info['HOTEL_ADDRESS']=hotel_addr_list[0]
        one_hotel_info['HOTEL_LOCAL_CODE']=localCode[hotel_addr_list[-2]]

        # 호텔소개
        driver.find_element_by_class_name('more').click()  # 더보기 버튼을 누른다.
        time.sleep(1)  # 예약페이지 로드 1초 대기

        hotel_content = soup.select_one('div.desc_wrap.ng-scope > p.txt.ng-binding')
        one_hotel_info['BO_CONTENT'] = hotel_content.text

        # 호텔옵션
        hotel_options = [option.text for option in soup.select('i.feature')]
        one_hotel_info['HOTEL_REAL_OPTIONS'] = hotel_options

        driver.quit()
        return one_hotel_info
    except Exception:
        driver.quit()
        pass

# %%
hotels=[]
for key in tqdm_notebook( hotel_keys):
    hotels.append(get_hotel_info(key))
# Out:
# HBox(children=(IntProgress(value=0, max=420), HTML(value='')))

# %%
hotels
# Out:
# [{'BO_TITLE': '신라스테이 광화문',
#   'HOTEL_RANK': 3,
#   'HOTEL_ADDRESS': '삼봉로 71',
#   'HOTEL_LOCAL_CODE': 9,
#   'BO_CONTENT': '신라스테이 광화문 - <3성급:한국관광공사 인증> - 신라스테이 광화문은 5호선 광화문역 2번 출구에서 도보로 5분 거리에 있습니다. 가까운 도보 거리에 시청, 대사관, 서울 파이낸스 센터 등이 있어 비즈니스 여행객에게 편리한 위치를 자랑합니다. 뿐만 아니라 서울 4대 고궁, 북촌한옥마을과 명동까지 차로 약 10분이면 가실 수 있어 관광객분들께도 최적의 위치를 자랑합니다.',
#   'HOTEL_REAL_OPTIONS': ['무료 와이파이',
#    '와이파이',
#    '고속 인터넷',
#    '무료 주차 가능',
#    '주차장',
#    '24시간 리셉션',
#    '외국어 구사 직원',
#    '장애인 편의 시설',
#    '드라이클리닝',
#    '세탁 서비스',
#    '모닝콜 서비스',
#    '장애인 주차 시설',
#    '피트니스센터',
#    '상점',
#    '연회장',
#    '기념품 가게',
#    '레스토랑',
#    '바/라운지',
#    '비즈니스 센터',
#    '회의실',
#    '컨퍼런스룸',
#    '화상 회의',
#    '복사기',
#    '데스크',
#    '엘리베이터',
#    '연회 시설',
#    '전시 공간',
#    '금연실',
#    '에어컨',
#    '헤어드라이어',
#    '커피/차 메이커',
#    '냉장고',
#    '케이블/위성 TV',
#    '개인 욕실',
#    '안전 금고',
#    'TV',
#    '목욕 가운',
#    '스위트룸',
#    '비데']},
#  {'BO_TITLE': '나인트리 프리미어 호텔 인사동',
#   'HOTEL_RANK': 4,
#   'HOTEL_ADDRESS': '인사동길 49',
#   'HOTEL_LOCAL_CODE': 9,
#   'BO_CONTENT': '나인트리 프리미어 호텔 인사동은 3호선 안국역 6번출구에서 걸어서 약 2분, 1호선 종각역 3-1번 출구에서 걸어서 약 8분 거리에 있습니다. 김포공항에서는 차로 약 50분가량 떨어져 있습니다. 주변 관광지인 국립고궁박물관과 경복궁은 도보 약 15분 이내에 갈 수 있습니다. 또한, 쇼핑 명소인 명동 거리가 차로 약 7분가량 소요되는 등 주요 관광지가 인접해 이동이 편리합니다. ',
#   'HOTEL_REAL_OPTIONS': ['무료 와이파이',
#    '와이파이',
#    '공항 셔틀 제공',
#    '무료 주차 가능',
#    '주차장',
#    '24시간 리셉션',
#    '룸 서비스',
#    '컨시어지',
#    '외국어 구사 직원',
#    '장애인 편의 시설',
#    '물품보관소',
#    '환전',
#    '장애인 주차 시설',
#    '피트니스센터',
#    '레스토랑',
#    '카페',
#    '비즈니스 센터',
#    '회의실',
#    '데스크',
#    '엘리베이터',
#    '셀프 세탁실',
#    '금연실',
#    '에어컨',
#    '헤어드라이어',
#    '커피/차 메이커',
#    '냉장고',
#    '케이블/위성 TV',
#    '안전 금고',
#    'TV',
#    '목욕 가운',
#    '비데',
#    '항알레르기 객실']},
#  {'BO_TITLE': '신라스테이 역삼',
#   'HOTEL_RANK': 3,
#   'HOTEL_ADDRESS': '언주로 517',
#   'HOTEL_LOCAL_CODE': 9,
#   'BO_CONTENT': '신라스테이 역삼 - <3성급:한국관광공사 인증> - 신라스테이 역삼은 2호선 역삼역과 선릉역에서 도보 10분 거리에 있습니다. 역삼역에서 단 한 정거장이면 강남으로 가실 수 있고, 선릉역에서 한 정거장이면 코엑스 몰까지 가실 수 있습니다. 걸어서 10분이면 테헤란로까지 가실 수 있고, 자동차로 10분이면 압구정 로데오거리, 가로수길 등을 가실 수 있습니다.',
#   'HOTEL_REAL_OPTIONS': ['무료 와이파이',
#    '와이파이',
#    '주차장',
#    '24시간 리셉션',
#    '컨시어지',
#    '외국어 구사 직원',
#    '드라이클리닝',
#    '세탁 서비스',
#    '모닝콜 서비스',
#    '물품보관소',
#    '환전',
#    '피트니스센터',
#    '바/라운지',
#    '카페',
#    '비즈니스 센터',
#    '회의실',
#    '복사기',
#    '데스크',
#    '엘리베이터',
#    '금연실',
#    '에어컨',
#    '헤어드라이어',
#    '커피/차 메이커',
#    '냉장고',
#    '케이블/위성 TV',
#    '안전 금고',
#    'TV',
#    '목욕 가운',
#    '샤워']},
#  {'BO_TITLE': '신라스테이 서대문',
#   'HOTEL_RANK': 5,
#   'HOTEL_ADDRESS': '충정로 76',
#   'HOTEL_LOCAL_CODE': 9,
#   'BO_CONTENT': '신라스테이 서대문 - <3성급:한국관광공사 인증> - 신라 스테이 서대문은 5호선 서대문역 7, 8번 출구 바로 앞에 있습니다. 차로 10분 거리에 시청, 서울 파이낸스 센터 등이 있어 비즈니스 여행객에게 편리한 위치를 자랑합니다. 뿐만 아니라 명동, 롯데백화점 본점, 남대문 등도 차로 10분 거리에 있어 쇼핑을 즐기시기에 편리한 위치를 자랑합니다.',
#   'HOTEL_REAL_OPTIONS': ['무료 와이파이',
#    '와이파이',
#    '주차장',
#    '발렛 파킹',
#    '24시간 리셉션',
#    '컨시어지',
#    '외국어 구사 직원',
#    '세탁 서비스',
#    '물품보관소',
#    '환전',
#    '피트니스센터',
#    '레스토랑',
#    '비즈니스 센터',
#    '회의실',
#    '데스크',
#    '엘리베이터',
#    '금연실',
#    '에어컨',
#    '헤어드라이어',
#    '커피/차 메이커',
#    '냉장고',
#    '케이블/위성 TV',
#    '개인 욕실',
#    '안전 금고',
#    'TV',
#    '목욕 가운',
#    '스위트룸',
#    '비데']},
#  {'BO_TITLE': '글래드 강남 코엑스센터',
#   'HOTEL_RANK': 3,
#   'HOTEL_ADDRESS': '테헤란로 610',
#   'HOTEL_LOCAL_CODE': 9,
#   'BO_CONTENT': '글래드 강남 코엑스센터 - <3성급:한국관광공사 인증> - 글래드 강남 코엑스센터는 지하철 2호선 삼성역 1번 출구에서 도보로 단 1분 거리에 위치해 있습니다. 주변 관광지로는 코엑스몰과 무역센터가 도보로 10분 거리에 있습니다. 또한 압구정 로데오거리까지는 차로 15분이면 가실 수 있으며, 신사동 가로수길까지는 차로 약 20분이 소요됩니다.',
#   'HOTEL_REAL_OPTIONS': ['무료 와이파이',
#    '와이파이',
#    '주차장',
#    '24시간 리셉션',
#    '컨시어지',
#    '외국어 구사 직원',
#    '모닝콜 서비스',
#    '물품보관소',
#    '환전',
#    '피트니스센터',
#    '레스토랑',
#    '카페',
#    '비즈니스 센터',
#    '회의실',
#    '엘리베이터',
#    '셀프 세탁실',
#    '에어컨',
#    '안전 금고']},
#  {'BO_TITLE': '글래드 마포',
#   'HOTEL_RANK': 4,
#   'HOTEL_ADDRESS': '마포대로 92',
#   'HOTEL_LOCAL_CODE': 9,
#   'BO_CONTENT': '글래드 마포- <4성급:한국관광공사 인증> -군더더기 없는 실용성과 내 집 같은 편안함을 추구하는 글래드 마포는 종로, 명동, 홍대 같은 서울의 주요 관광지까지 차로 약 20분 거리에 위치해 있습니다. 또한 역세권에 위치하여 교통 역시 매우 편리합니다. 5호선과 6호선 공덕역 8번 출구, 경의 중앙선과 공항철도가 지나는 공덕역 9번 출구에서 도보로 1분이면 호텔에 오실 수 있습니다. 또한 지하철 5호선 마포역 3번 출구에서는 도보로 약 9분, 김포 공항에서는 차로 약 45분, 인천 공항에서는 약 60분 정도 소요됩니다.',
#   'HOTEL_REAL_OPTIONS': ['무료 와이파이',
#    '와이파이',
#    '공항 셔틀 제공',
#    '24시간 리셉션',
#    '외국어 구사 직원',
#    '모닝콜 서비스',
#    '물품보관소',
#    '환전',
#    '피트니스센터',
#    '레스토랑',
#    '카페',
#    '비즈니스 센터',
#    '회의실',
#    '엘리베이터',
#    '현금지급기',
#    '금연실',
#    '에어컨',
#    '헤어드라이어',
#    '커피/차 메이커',
#    '냉장고',
#    '케이블/위성 TV',
#    '개인 욕실',
#    '안전 금고',
#    'TV',
#    '목욕 가운',
#    '스위트룸',
#    '비데']},
#  {'BO_TITLE': '롯데시티호텔 명동',
#   'HOTEL_RANK': 4,
#   'HOTEL_ADDRESS': '삼일대로 362',
#   'HOTEL_LOCAL_CODE': 9,
#   'BO_CONTENT': '롯데시티호텔 명동 - <4성급:한국관광공사 인증> - 롯데시티호텔 명동은 명동과 청계천 사이에 위치하고 있어 뛰어난 입지 조건을 자랑합니다. 도보 단 3분 거리에 을지로3가역 1번 출구가 위치해 있습니다. 가까운 거리에 롯데 백화점, 영플라자, 명동이 있어 쇼핑을 즐기시기에 편리합니다.',
#   'HOTEL_REAL_OPTIONS': ['무료 와이파이',
#    '와이파이',
#    '무료 주차 가능',
#    '주차장',
#    '24시간 리셉션',
#    '외국어 구사 직원',
#    '장애인 편의 시설',
#    '드라이클리닝',
#    '세탁 서비스',
#    '물품보관소',
#    '환전',
#    '장애인 주차 시설',
#    '피트니스센터',
#    '상점',
#    '레스토랑',
#    '카페',
#    '비즈니스 센터',
#    '회의실',
#    '복사기',
#    '데스크',
#    '엘리베이터',
#    '현금지급기',
#    '호텔 내 상점',
#    '금연실',
#    '에어컨',
#    '개인 욕실',
#    '안전 금고',
#    '스위트룸']},
#  {'BO_TITLE': '신라스테이 삼성',
#   'HOTEL_RANK': 3,
#   'HOTEL_ADDRESS': '영동대로 506',
#   'HOTEL_LOCAL_CODE': 9,
#   'BO_CONTENT': '신라스테이 삼성 - <3성급:한국관광공사 인증> - 신라스테이 삼성은 2호선 삼성역 7번 출구에서 걸어서 약 5분, 도심공항터미널에서 걸어서 약 10분 거리에 있습니다. 또한, 스타필드 코엑스몰, 현대백화점 등이 도보 거리에 있어 쇼핑을 즐기기 쉽고, 잠실 롯데타워, 한강공원까지 차로 약 15분, 강남역까지 차로 약 30분이면 갈 수 있어 관광을 즐기기도 좋습니다. 그뿐만 아니라, 무역센터 등이 자리한 테헤란로에 위치해 비즈니스 고객들이 편리하게 머무실 수 있습니다.',
#   'HOTEL_REAL_OPTIONS': ['무료 와이파이',
#    '와이파이',
#    '고속 인터넷',
#    '주차장',
#    '24시간 리셉션',
#    '컨시어지',
#    '외국어 구사 직원',
#    '물품보관소',
#    '환전',
#    '피트니스센터',
#    '레스토랑',
#    '바/라운지',
#    '비즈니스 센터',
#    '회의실',
#    '데스크',
#    '엘리베이터',
#    '셀프 세탁실',
#    '금연실',
#    '에어컨',
#    '헤어드라이어',
#    '커피/차 메이커',
#    '냉장고',
#    '케이블/위성 TV',
#    '개인 욕실',
#    '안전 금고',
#    'TV',
#    '목욕 가운',
#    '스위트룸',
#    '비데']},
#  {'BO_TITLE': '신라스테이 서초',
#   'HOTEL_RANK': 4,
#   'HOTEL_ADDRESS': '효령로 427',
#   'HOTEL_LOCAL_CODE': 9,
#   'BO_CONTENT': '2017년 오픈한 신라스테이 서초는 강남역 5번 출구에서 걸어서 약 10분 거리에 있고, 인천국제공항으로 갈 수 있는 도심공항터미널까지 차로 약 15분 소요됩니다. 전시와 공연을 즐길 수 있는 예술의 전당이 차로 약 10분, 명품샵이 즐비한 압구정 로데오 거리는 차로 약 20분 거리에 있습니다. ',
#   'HOTEL_REAL_OPTIONS': ['무료 와이파이',
#    '와이파이',
#    '주차장',
#    '24시간 리셉션',
#    '컨시어지',
#    '외국어 구사 직원',
#    '장애인 편의 시설',
#    '모닝콜 서비스',
#    '투어 데스크',
#    '장애인 주차 시설',
#    '피트니스센터',
#    '레스토랑',
#    '데스크',
#    '엘리베이터',
#    '현금지급기',
#    '금연실',
#    '에어컨',
#    '헤어드라이어',
#    '커피/차 메이커',
#    '냉장고',
#    '케이블/위성 TV',
#    '개인 욕실',
#    '안전 금고',
#    'TV',
#    '목욕 가운',
#    '스위트룸']},
#  {'BO_TITLE': '글래드 여의도',
#   'HOTEL_RANK': 4,
#   'HOTEL_ADDRESS': '의사당대로 16',
#   'HOTEL_LOCAL_CODE': 9,
#   'BO_CONTENT': '글래드 호텔 여의도 - <4성급:한국관광공사 인증> - KBS 방송국 바로 옆에 있는 글래드 호텔 여의도는 9호선 국회의사당역 4번 출구에서 도보 1분 거리에 있습니다. 여의도 공원은 도보로 5분 거리에 있으며 걸어서 15분이면 IFC 몰에 도착하실 수 있습니다. 차로 15분이면 63빌딩과 한강 유람선 선착장에 도착하실 수 있습니다.',
#   'HOTEL_REAL_OPTIONS': ['무료 와이파이',
#    '와이파이',
#    '무료 주차 가능',
#    '주차장',
#    '24시간 리셉션',
#    '룸 서비스',
#    '컨시어지',
#    '외국어 구사 직원',
#    '드라이클리닝',
#    '세탁 서비스',
#    '물품보관소',
#    '환전',
#    '피트니스센터',
#    '레스토랑',
#    '비즈니스 센터',
#    '회의실',
#    '컨퍼런스룸',
#    '복사기',
#    '데스크',
#    '엘리베이터',
#    '현금지급기',
#    '금연실',
#    '에어컨',
#    '미니 바',
#    '헤어드라이어',
#    '커피/차 메이커',
#    '냉장고',
#    '케이블/위성 TV',
#    '개인 욕실',
#    '안전 금고',
#    'TV',
#    '목욕 가운',
#    '샤워',
#    '스위트룸',
#    '비데',
#    '항알레르기 객실']},
#  {'BO_TITLE': '나인트리 프리미어 호텔 명동 2',
#   'HOTEL_RANK': 4,
#   'HOTEL_ADDRESS': '마른내로 28',
#   'HOTEL_LOCAL_CODE': 9,
#   'BO_CONTENT': '나인트리 프리미어 호텔 명동 2 - <4성급:한국관광공사 인증> -  서울 중심지에 자리한 이 호텔은 남산골한옥마을에서 가까운 거리에 있습니다. 그 밖에도 내부 어디에서든 무료로 인터넷에 접속하실 수 있습니다. ',
#   'HOTEL_REAL_OPTIONS': ['무료 와이파이',
#    '와이파이',
#    '공항 셔틀 제공',
#    '24시간 리셉션',
#    '컨시어지',
#    '외국어 구사 직원',
#    '장애인 편의 시설',
#    '드라이클리닝',
#    '세탁 서비스',
#    '모닝콜 서비스',
#    '환전',
#    '예매 서비스',
#    '장애인 주차 시설',
#    '피트니스센터',
#    '상점',
#    '레스토랑',
#    '카페',
#    '비즈니스 센터',
#    '회의실',
#    '컨퍼런스룸',
#    '복사기',
#    '데스크',
#    '엘리베이터',
#    '셀프 세탁실',
#    '별도 흡연 구역',
#    '아이스 머신',
#    '호텔 내 상점',
#    '금연실',
#    '에어컨',
#    '헤어드라이어',
#    '개인 욕실',
#    '안전 금고',
#    'TV',
#    '스위트룸']},
#  {'BO_TITLE': '롯데시티호텔 구로',
#   'HOTEL_RANK': 5,
#   'HOTEL_ADDRESS': '디지털로 300',
#   'HOTEL_LOCAL_CODE': 9,
#   'BO_CONTENT': '롯데시티호텔 구로 - <3성급:한국관광공사 인증> - 롯데시티호텔 구로는 국내 IT 벤처 기업이 모여있는 구로 디지털밸리 내에 자리하고 있으며 2호선 구로디지털단지역 3번 출구에서 도보 9분 거리에 있습니다. 도보 20분 거리에는 현대 아울렛 가산점, 마리오 아울렛 등이 모여 있으며 차로 25분이면 IFC 몰, 63 빌딩 등이 있는 여의도까지 가실 수 있습니다.',
#   'HOTEL_REAL_OPTIONS': ['무료 와이파이',
#    '와이파이',
#    '공항 셔틀 제공',
#    '무료 주차 가능',
#    '주차장',
#    '24시간 리셉션',
#    '컨시어지',
#    '외국어 구사 직원',
#    '장애인 편의 시설',
#    '모닝콜 서비스',
#    '물품보관소',
#    '장애인 주차 시설',
#    '피트니스센터',
#    '연회장',
#    '레스토랑',
#    '비즈니스 센터',
#    '회의실',
#    '컨퍼런스룸',
#    '데스크',
#    '엘리베이터',
#    '셀프 세탁실',
#    '현금지급기',
#    '연회 시설',
#    '에어컨',
#    '헤어드라이어',
#    '커피/차 메이커',
#    '냉장고',
#    '케이블/위성 TV',
#    '안전 금고',
#    'TV',
#    '목욕 가운',
#    '비데']},
#  {'BO_TITLE': 'L7 강남 바이 롯데',
#   'HOTEL_RANK': 4,
#   'HOTEL_ADDRESS': '테헤란로 415',
#   'HOTEL_LOCAL_CODE': 9,
#   'BO_CONTENT': 'L7 강남 바이 롯데 -<4성급:한국관광공사 인증> -L7 강남 바이 롯데는 지하철 2호선 선릉역 10번 출구에서 도보 단 5분 거리에 위치해 있습니다. 세계문화유산으로 등록된 선릉과정릉은 도보 단 3분 거리에 있으며, 도보 20분, 차로 5분이면 코엑스몰까지 가실 수 있습니다. 또한, 신사동 가로수길은 차로 약 15분 거리에 있습니다.',
#   'HOTEL_REAL_OPTIONS': ['무료 와이파이',
#    '와이파이',
#    '고속 인터넷',
#    '무료 주차 가능',
#    '주차장',
#    '24시간 리셉션',
#    '컨시어지',
#    '외국어 구사 직원',
#    '장애인 편의 시설',
#    '모닝콜 서비스',
#    '환전',
#    '장애인 주차 시설',
#    '피트니스센터',
#    '스파/웰니스 센터',
#    '정원',
#    '레스토랑',
#    '비즈니스 센터',
#    '회의실',
#    '컨퍼런스룸',
#    '데스크',
#    '엘리베이터',
#    '셀프 세탁실',
#    '아이스 머신',
#    '금연실',
#    '에어컨',
#    '헤어드라이어',
#    '냉장고',
#    '안전 금고',
#    'TV',
#    '목욕 가운',
#    '비데']},
#  {'BO_TITLE': '신라스테이 마포',
#   'HOTEL_RANK': 3,
#   'HOTEL_ADDRESS': '마포대로 83',
#   'HOTEL_LOCAL_CODE': 9,
#   'BO_CONTENT': '신라 스테이 마포 - <3성급:한국관광공사 인증> - 신라스테이 마포는 5, 6호선, 중앙선, 공항철도를 이용하실 수 있는 공덕역 1번 출구에서 도보 2분 거리에 있습니다. 차로 10분 거리에 여의도 IFC, 국회의사당, 금융사 등이 있어 비즈니스 여행객에게 편리한 위치를 자랑합니다. 또한, 차로 15분이면 홍대 거리와 63빌딩까지 가실 수 있습니다.',
#   'HOTEL_REAL_OPTIONS': ['무료 와이파이',
#    '와이파이',
#    '무료 주차 가능',
#    '주차장',
#    '24시간 리셉션',
#    '룸 서비스',
#    '컨시어지',
#    '외국어 구사 직원',
#    '장애인 편의 시설',
#    '드라이클리닝',
#    '세탁 서비스',
#    '물품보관소',
#    '환전',
#    '장애인 주차 시설',
#    '피트니스센터',
#    '레스토랑',
#    '비즈니스 센터',
#    '복사기',
#    '데스크',
#    '엘리베이터',
#    '현금지급기',
#    '별도 흡연 구역',
#    '아이스 머신',
#    '전시 공간',
#    '금연실',
#    '에어컨',
#    '헤어드라이어',
#    '커피/차 메이커',
#    '냉장고',
#    '케이블/위성 TV',
#    '개인 욕실',
#    '안전 금고',
#    'TV',
#    '목욕 가운',
#    '스위트룸',
#    '비데']},
#  {'BO_TITLE': '오라카이 청계산 호텔',
#   'HOTEL_RANK': 3,
#   'HOTEL_ADDRESS': '청계산로9길 1-7',
#   'HOTEL_LOCAL_CODE': 9,
#   'BO_CONTENT': '오라카이 청계산 호텔 - <4성급:한국관광공사 인증> - 청계산 자락의 맑은 공기, 오라카이 청계산 호텔의 경우 서울의 중심부에 자리해 있습니다. 호텔에서 조금만 걸어가시면 청계산에 오르실 수 있으며, 양재 시민의 숲은 차로 약 10분 거리, 과천 서울대공원은 약 20분 거리에 있습니다. 신분당선 청계산입구역 1번 출구에서 나오시면 바로 호텔에 오실 수 있으며 서울남부터미널에서는 차로 20분, 김포 국제공항에서는 약 55분, 인천 국제공항에서는 약 70분이 소요됩니다. ',
#   'HOTEL_REAL_OPTIONS': ['무료 와이파이',
#    '와이파이',
#    '무료 주차 가능',
#    '주차장',
#    '24시간 리셉션',
#    '외국어 구사 직원',
#    '모닝콜 서비스',
#    '수영장',
#    '피트니스센터',
#    '사우나',
#    '레스토랑',
#    '카페',
#    '비즈니스 센터',
#    '금연실',
#    '에어컨',
#    '헤어드라이어',
#    '냉장고',
#    '케이블/위성 TV',
#    '개인 욕실',
#    'TV',
#    '목욕 가운',
#    '샤워',
#    '스위트룸',
#    '비데']},
#  {'BO_TITLE': '쉐라톤 서울 디큐브시티 호텔',
#   'HOTEL_RANK': 3,
#   'HOTEL_ADDRESS': '경인로 662',
#   'HOTEL_LOCAL_CODE': 9,
#   'BO_CONTENT': '쉐라톤 서울 디큐브시티 호텔 - <5성급:한국관광공사 인증> - 쉐라톤 서울 디큐브 시티 호텔은 1, 2호선 신도림역 5번 출구에서 도보로 단 5분 거리에 있습니다. 호텔에서 아주 가까이에 현대백화점 디큐브시티점, 테크노마트 신도림점, 홈플러스 신도림점 등이 있어 편리하게 이용하실 수 있습니다. 차로 15분이면 영등포 타임스퀘어몰까지 가실 수 있습니다. ',
#   'HOTEL_REAL_OPTIONS': ['무료 와이파이',
#    '와이파이',
#    '무료 주차 가능',
#    '주차장',
#    '24시간 리셉션',
#    '룸 서비스',
#    '컨시어지',
#    '외국어 구사 직원',
#    '드라이클리닝',
#    '세탁 서비스',
#    '물품보관소',
#    '이그제큐티브 플로어',
#    '환전',
#    '익스프레스 체크인/아웃',
#    '수영장',
#    '피트니스센터',
#    '스파/웰니스 센터',
#    '마사지 샵',
#    '마사지',
#    '사우나',
#    '레스토랑',
#    '바/라운지',
#    '카페',
#    '비즈니스 센터',
#    '회의실',
#    '복사기',
#    '데스크',
#    '엘리베이터',
#    '현금지급기',
#    '별도 흡연 구역',
#    '금연실',
#    '에어컨',
#    '미니 바',
#    '헤어드라이어',
#    '커피/차 메이커',
#    '냉장고',
#    '케이블/위성 TV',
#    '욕조',
#    '안전 금고',
#    'TV',
#    '목욕 가운']},
#  {'BO_TITLE': '롯데 호텔 월드',
#   'HOTEL_RANK': 5,
#   'HOTEL_ADDRESS': '올림픽로 240',
#   'HOTEL_LOCAL_CODE': 9,
#   'BO_CONTENT': '롯데 호텔 월드 - <5성급:한국관광공사 인증> - 리조트형 비즈니스 호텔인 롯데 호텔 월드는 세계 최대 규모의 실내 놀이공원인 롯데월드 어드벤쳐와 롯데월드몰과 바로 연결되어 있습니다. 또한, 석촌호수가 도보로 5분 거리에 있으며 지하철 2, 8호선 잠실역까지는 지하통로를 통해 도보로 3분이 거리에 있습니다. ',
#   'HOTEL_REAL_OPTIONS': ['무료 와이파이',
#    '와이파이',
#    '공항 셔틀 제공',
#    '무료 주차 가능',
#    '주차장',
#    '발렛 파킹',
#    '24시간 리셉션',
#    '룸 서비스',
#    '외국어 구사 직원',
#    '드라이클리닝',
#    '세탁 서비스',
#    '모닝콜 서비스',
#    '물품보관소',
#    '이그제큐티브 플로어',
#    '환전',
#    '투어 데스크',
#    '운반 서비스',
#    '예매 서비스',
#    '익스프레스 체크인/아웃',
#    '구두 광택 서비스',
#    '수영장',
#    '어린이 수영장',
#    '피트니스센터',
#    '스파/웰니스 센터',
#    '골프 코스',
#    '상점',
#    '사우나',
#    '기념품 가게',
#    '미니 골프코스',
#    '레스토랑',
#    '바/라운지',
#    '카페',
#    '비즈니스 센터',
#    '회의실',
#    '컨퍼런스룸',
#    '복사기',
#    '데스크',
#    '엘리베이터',
#    '현금지급기',
#    '호텔 내 상점',
#    '금연실',
#    '에어컨',
#    '미니 바',
#    '헤어드라이어',
#    '커피/차 메이커',
#    '냉장고',
#    '케이블/위성 TV',
#    '안전 금고',
#    'TV',
#    '비데']},
#  {'BO_TITLE': 'PJ 호텔 명동 (피제이 호텔)',
#   'HOTEL_RANK': 4,
#   'HOTEL_ADDRESS': '마른내로 71',
#   'HOTEL_LOCAL_CODE': 9,
#   'BO_CONTENT': 'PJ 호텔 명동 (피제이 호텔)- <4성급:한국관광공사 인증> - PJ 호텔 명동 (피제이 호텔)은 2, 5호선 을지로 4가역 10번 출구와 3, 4호선 충무로역 8번 출구에서 약 400m 거리에 있습니다. 차로 5-10분 거리에 남산타워, 남대문 시장, 명동 등이 있고 명동과 동대문 등 주요 관광지로 운행하는 셔틀 버스가 15분마다 있습니다.',
#   'HOTEL_REAL_OPTIONS': ['무료 와이파이',
#    '와이파이',
#    '고속 인터넷',
#    '무료 주차 가능',
#    '주차장',
#    '24시간 리셉션',
#    '룸 서비스',
#    '컨시어지',
#    '외국어 구사 직원',
#    '드라이클리닝',
#    '세탁 서비스',
#    '모닝콜 서비스',
#    '물품보관소',
#    '이그제큐티브 플로어',
#    '환전',
#    '투어 데스크',
#    '익스프레스 체크인/아웃',
#    '피트니스센터',
#    '레스토랑',
#    '카페',
#    '비즈니스 센터',
#    '회의실',
#    '컨퍼런스룸',
#    '복사기',
#    '데스크',
#    '엘리베이터',
#    '셀프 세탁실',
#    '현금지급기',
#    '별도 흡연 구역',
#    '에어컨',
#    '헤어드라이어',
#    '커피/차 메이커',
#    '냉장고',
#    '케이블/위성 TV',
#    '안전 금고',
#    'TV',
#    '샤워']},
#  {'BO_TITLE': '오라카이 대학로 호텔',
#   'HOTEL_RANK': 4,
#   'HOTEL_ADDRESS': '율곡로 180',
#   'HOTEL_LOCAL_CODE': 9,
#   'BO_CONTENT': '오라카이 대학로 호텔은 동대문 역사문화공원에서 차로 약 8분 이내에 있습니다. 주변 명소에는 한국의 대표적인 고궁인 창경궁이 차로 약 5분, 경복궁이 차로 약 10분 걸립니다. 남산 타워는 차로 약 14분 걸립니다.',
#   'HOTEL_REAL_OPTIONS': ['무료 와이파이',
#    '와이파이',
#    '고속 인터넷',
#    '무료 주차 가능',
#    '주차장',
#    '24시간 리셉션',
#    '외국어 구사 직원',
#    '장애인 편의 시설',
#    '모닝콜 서비스',
#    '물품보관소',
#    '환전',
#    '장애인 주차 시설',
#    '피트니스센터',
#    '스파/웰니스 센터',
#    '사우나',
#    '레스토랑',
#    '카페',
#    '비즈니스 센터',
#    '회의실',
#    '엘리베이터',
#    '셀프 세탁실',
#    '현금지급기',
#    '별도 흡연 구역',
#    '금연실',
#    '에어컨',
#    '헤어드라이어',
#    '냉장고',
#    '안전 금고',
#    'TV',
#    '목욕 가운']},
#  {'BO_TITLE': '시그니엘 서울',
#   'HOTEL_RANK': 5,
#   'HOTEL_ADDRESS': '올림픽로 300 롯데월드타워 76-101층',
#   'HOTEL_LOCAL_CODE': 9,
#   'BO_CONTENT': '시그니엘 서울 - <5성급:한국관광공사 인증> - 시그니엘 서울은 지하철 2, 8호선 잠실역 1번 출구에서 도보로 약 5분이면 도착하는 편리한 위치를 자랑합니다. 주변 관광명소로는 산책을 즐기기에 좋은 도심 속 쉼터인 석촌 호수가 걸어서 약 10분 거리에 있으며 롯데월드타워&롯데월드몰이 도보로 5분 거리에 자리해 있습니다. 또한, 롯데월드까지 걸어서 10분이면 도착합니다. ',
#   'HOTEL_REAL_OPTIONS': ['무료 와이파이',
#    '와이파이',
#    '공항 셔틀 제공',
#    '무료 주차 가능',
#    '주차장',
#    '발렛 파킹',
#    '24시간 리셉션',
#    '룸 서비스',
#    '컨시어지',
#    '외국어 구사 직원',
#    '장애인 편의 시설',
#    '드라이클리닝',
#    '세탁 서비스',
#    '모닝콜 서비스',
#    '물품보관소',
#    '환전',
#    '운반 서비스',
#    '구두 광택 서비스',
#    '장애인 주차 시설',
#    '수영장',
#    '실내 수영장',
#    '피트니스센터',
#    '스파/웰니스 센터',
#    '마사지 샵',
#    '마사지',
#    '사우나',
#    '연회장',
#    '바디 트리트먼트',
#    '페이셜 트리트먼트',
#    '레스토랑',
#    '바/라운지',
#    '카페',
#    '비즈니스 센터',
#    '회의실',
#    '컨퍼런스룸',
#    '복사기',
#    '데스크',
#    '엘리베이터',
#    '연회 시설',
#    '에어컨',
#    '미니 바',
#    '헤어드라이어',
#    '케이블/위성 TV',
#    '안전 금고',
#    'TV',
#    '목욕 가운',
#    '비데']},
#  {'BO_TITLE': '신라스테이 해운대',
#   'HOTEL_RANK': 5,
#   'HOTEL_ADDRESS': '해운대로570번길 46',
#   'HOTEL_LOCAL_CODE': 8,
#   'BO_CONTENT': '신라스테이 해운대 - <4성급:한국관광공사 인증> - 해운대 전망을 자랑하는 루프탑 바가 있는 신라 스테이 해운대는 부산 2호선 해운대역 5번 또는 7번에서 도보 6분 거리에 있으며 KTX 부산역까지는 차로 25분이 소요됩니다. 주변 관광지로는 해운대 해수욕장이 도보 5분, 해동 용궁사가 차로 25분, 누리마루와 광안대교가 차로 각 15분 거리에 있습니다. 또한, 신세계 백화점 센텀시티점과 롯데백화점이 차로 약 10분 거리에 있어 쇼핑을 즐기기에도 좋습니다.',
#   'HOTEL_REAL_OPTIONS': ['무료 와이파이',
#    '와이파이',
#    '무료 주차 가능',
#    '주차장',
#    '24시간 리셉션',
#    '컨시어지',
#    '수영장',
#    '피트니스센터',
#    '스파/웰니스 센터',
#    '자쿠지',
#    '사우나',
#    '연회장',
#    '레스토랑',
#    '바/라운지',
#    '풀사이드 바',
#    '비즈니스 센터',
#    '회의실',
#    '컨퍼런스룸',
#    '셀프 세탁실',
#    '연회 시설',
#    '에어컨',
#    '헤어드라이어',
#    '냉장고',
#    '케이블/위성 TV',
#    '욕조',
#    '안전 금고',
#    'TV',
#    '목욕 가운',
#    '샤워',
#    '비데']},
#  {'BO_TITLE': '파라다이스 호텔 부산',
#   'HOTEL_RANK': 5,
#   'HOTEL_ADDRESS': '해운대해변로 296',
#   'HOTEL_LOCAL_CODE': 8,
#   'BO_CONTENT': '파라다이스 호텔 부산 - <5성급:한국관광공사 인증> - 해운대 조망의 파라다이스 호텔 부산은 해운대 해수욕장 바로 앞에 있습니다. 지하철 이용 시, 부산 2호선 해운대역 3번 출구에서 도보로 약 10분 걸립니다. 주변 명소인 누리마루APEC하우스는 차로 약 5분 거리에 있습니다. 또한, 해동 용궁사까지는 차로 약 20분이 소요됩니다.',
#   'HOTEL_REAL_OPTIONS': ['무료 와이파이',
#    '와이파이',
#    '고속 인터넷',
#    '공항 셔틀 제공',
#    '무료 주차 가능',
#    '주차장',
#    '발렛 파킹',
#    '24시간 리셉션',
#    '룸 서비스',
#    '컨시어지',
#    '외국어 구사 직원',
#    '장애인 편의 시설',
#    '드라이클리닝',
#    '세탁 서비스',
#    '모닝콜 서비스',
#    '물품보관소',
#    '이그제큐티브 플로어',
#    '환전',
#    '익스프레스 체크인/아웃',
#    '구두 광택 서비스',
#    '장애인 주차 시설',
#    '유아용 식탁 의자',
#    '수영장',
#    '어린이 수영장',
#    '피트니스센터',
#    '스파/웰니스 센터',
#    '마사지 샵',
#    '마사지',
#    '키즈 클럽',
#    '골프 코스',
#    '카지노',
#    '상점',
#    '연회장',
#    '다트판',
#    '놀이터',
#    '살롱',
#    '정원',
#    '레스토랑',
#    '바/라운지',
#    '펍',
#    '비즈니스 센터',
#    '회의실',
#    '복사기',
#    '데스크',
#    '엘리베이터',
#    '셀프 세탁실',
#    '현금지급기',
#    '별도 흡연 구역',
#    '호텔 내 상점',
#    '연회 시설',
#    '게임 시설',
#    '금연실',
#    '에어컨',
#    '헤어드라이어',
#    '커피/차 메이커',
#    '냉장고',
#    '케이블/위성 TV',
#    '개인 욕실',
#    '안전 금고',
#    'TV',
#    '목욕 가운',
#    '샤워',
#    '스위트룸',
#    '비데']},
#  {'BO_TITLE': '라발스 호텔 부산',
#   'HOTEL_RANK': 4,
#   'HOTEL_ADDRESS': '봉래나루로 82',
#   'HOTEL_LOCAL_CODE': 8,
#   'BO_CONTENT': '라발스호텔은 2호선 남포역 6번 및 8번 출구에서 차로 약 3분, 경부선 KTX 부산역에서 차로 약 10분가량 떨어져 있습니다. 또한 김해 국제공항에서 차로 약 40분 거리에 위치해 있습니다. 주변 관광지로는 광안리 해수욕장이 차로 약 20분, 벡스코가 차로 약 25분, 동백공원이 차로 약 30분, 해운대 해수욕장이 차로 약 35분가량 정도 소요됩니다.',
#   'HOTEL_REAL_OPTIONS': ['무료 와이파이',
#    '와이파이',
#    '무료 주차 가능',
#    '주차장',
#    '24시간 리셉션',
#    '외국어 구사 직원',
#    '모닝콜 서비스',
#    '물품보관소',
#    '피트니스센터',
#    '스파/웰니스 센터',
#    '상점',
#    '사우나',
#    '연회장',
#    '기념품 가게',
#    '레스토랑',
#    '카페',
#    '비즈니스 센터',
#    '회의실',
#    '컨퍼런스룸',
#    '복사기',
#    '엘리베이터',
#    '셀프 세탁실',
#    '현금지급기',
#    '호텔 내 상점',
#    '연회 시설',
#    '에어컨',
#    '헤어드라이어',
#    '커피/차 메이커',
#    '안전 금고',
#    'TV',
#    '목욕 가운',
#    '샤워',
#    '비데']},
#  {'BO_TITLE': '라마다 앙코르 바이 윈덤 부산 해운대',
#   'HOTEL_RANK': 4,
#   'HOTEL_ADDRESS': '구남로 9',
#   'HOTEL_LOCAL_CODE': 8,
#   'BO_CONTENT': '라마다 앙코르 바이 윈덤 부산 해운대는 2017년 7월에 신축 오픈하였으며 부산 지하철 2호선 해운대역 3번 출구에서 도보 1분 거리에 있습니다. 뿐만 아니라, 해운대 해수욕장과 부산 아쿠아리움에서 도보로 단 5분 거리에 있으며 달맞이길과 센텀시티까지는 차로 10분이 소요됩니다.',
#   'HOTEL_REAL_OPTIONS': ['무료 와이파이',
#    '와이파이',
#    '무료 주차 가능',
#    '주차장',
#    '24시간 리셉션',
#    '외국어 구사 직원',
#    '장애인 편의 시설',
#    '모닝콜 서비스',
#    '물품보관소',
#    '장애인 주차 시설',
#    '피트니스센터',
#    '레스토랑',
#    '카페',
#    '비즈니스 센터',
#    '회의실',
#    '복사기',
#    '데스크',
#    '엘리베이터',
#    '셀프 세탁실',
#    '별도 흡연 구역',
#    '아이스 머신',
#    '금연실',
#    '에어컨',
#    '헤어드라이어',
#    '냉장고',
#    '안전 금고',
#    '목욕 가운',
#    '비데']},
#  {'BO_TITLE': '그랜드 조선 부산',
#   'HOTEL_RANK': 5,
#   'HOTEL_ADDRESS': '해운대해변로 292',
#   'HOTEL_LOCAL_CODE': 8,
#   'BO_CONTENT': '그랜드 조선 부산은 해운대 해수욕장 바로 앞에 위치하고 있으며, 부산 지하철 2호선 해운대역 3번 출구에서 도보 5분 거리에 있습니다. 주변 명소인 SEA LIFE 부산 아쿠아리움은 도보 1분, 누리마루APEC하우스는 차로 약 5분 거리에 있습니다. 지하철로 세 정거장 거리에는 신세계 백화점 센텀시티점이 있습니다. ',
#   'HOTEL_REAL_OPTIONS': ['무료 와이파이',
#    '와이파이',
#    '주차장',
#    '발렛 파킹',
#    '24시간 리셉션',
#    '룸 서비스',
#    '장애인 편의 시설',
#    '드라이클리닝',
#    '세탁 서비스',
#    '모닝콜 서비스',
#    '환전',
#    '장애인 주차 시설',
#    '수영장',
#    '어린이 수영장',
#    '피트니스센터',
#    '스파/웰니스 센터',
#    '사우나',
#    '연회장',
#    '레스토랑',
#    '비즈니스 센터',
#    '회의실',
#    '컨퍼런스룸',
#    '복사기',
#    '엘리베이터',
#    '셀프 세탁실',
#    '별도 흡연 구역',
#    '연회 시설',
#    '금연실',
#    '에어컨',
#    '미니 바',
#    '헤어드라이어',
#    '커피/차 메이커',
#    '개인 욕실',
#    '안전 금고',
#    '목욕 가운',
#    '스위트룸']},
#  {'BO_TITLE': '아난티 힐튼',
#   'HOTEL_RANK': 2,
#   'HOTEL_ADDRESS': '기장읍 기장해안로 268-32',
#   'HOTEL_LOCAL_CODE': 8,
#   'BO_CONTENT': '아난티 힐튼- <5성급:한국관광공사 인증> - 부산의 아름다운 해변을 품은 기장에 위치한 아난티 힐튼에서는 “도심 속 완벽한 휴식처”라는 차별화된 컨셉과 규모, 서비스를 자랑합니다. 아난티 힐튼은 부산 KTX역에서 차로 35분, 김해국제공항에서 차로 1시간 거리에 있습니다. 뿐만 아니라, 해동용궁사까지 차로 5분, 해운대까지 차로 20분 거리에 있으며 센텀시티와 신세계 프리미엄 아울렛까지 차로 20분이면 가실 수 있어 관광과 쇼핑을 즐기기에도 편리합니다.',
#   'HOTEL_REAL_OPTIONS': ['와이파이',
#    '무료 주차 가능',
#    '주차장',
#    '발렛 파킹',
#    '24시간 리셉션',
#    '룸 서비스',
#    '컨시어지',
#    '장애인 편의 시설',
#    '드라이클리닝',
#    '세탁 서비스',
#    '모닝콜 서비스',
#    '물품보관소',
#    '이그제큐티브 플로어',
#    '환전',
#    '투어 데스크',
#    '익스프레스 체크인/아웃',
#    '장애인 주차 시설',
#    '수영장',
#    '실내 수영장',
#    '어린이 수영장',
#    '실외 풀',
#    '마사지 샵',
#    '마사지',
#    '상점',
#    '사우나',
#    '연회장',
#    '해양 스포츠',
#    '레스토랑',
#    '카페',
#    '비즈니스 센터',
#    '컨퍼런스룸',
#    '엘리베이터',
#    '셀프 세탁실',
#    '현금지급기',
#    '호텔 내 상점',
#    '연회 시설',
#    '에어컨',
#    '미니 바',
#    '헤어드라이어',
#    '커피/차 메이커',
#    '냉장고',
#    '케이블/위성 TV',
#    '욕조',
#    '안전 금고',
#    'TV',
#    '목욕 가운',
#    '샤워']},
#  None,
#  {'BO_TITLE': '파크 하얏트 부산',
#   'HOTEL_RANK': 5,
#   'HOTEL_ADDRESS': '마린시티1로 51',
#   'HOTEL_LOCAL_CODE': 8,
#   'BO_CONTENT': '파크 하얏트 부산 - <5성급:한국관광공사 인증> - 돛 모양을 형상화한 외관이 인상적인 파크 하얏트 부산은 부산 요트 경기장 바로 옆에 자리하고 있습니다. 부산 지하철 동백역 3번 출구에서 약 1km 거리에 있습니다. 해운대 해수욕장과 SEA LIFE 부산아쿠아리움운 지하철로 한 정거장 거리에 있습니다. 또한, 차로 30분 거리에 해동 용궁사가 있습니다.',
#   'HOTEL_REAL_OPTIONS': ['무료 와이파이',
#    '와이파이',
#    '공항 셔틀 제공',
#    '무료 주차 가능',
#    '주차장',
#    '발렛 파킹',
#    '24시간 리셉션',
#    '룸 서비스',
#    '컨시어지',
#    '외국어 구사 직원',
#    '아이 돌봄 서비스',
#    '드라이클리닝',
#    '세탁 서비스',
#    '모닝콜 서비스',
#    '물품보관소',
#    '환전',
#    '구두 광택 서비스',
#    '수영장',
#    '피트니스센터',
#    '자전거 대여',
#    '스파/웰니스 센터',
#    '마사지 샵',
#    '마사지',
#    '사우나',
#    '연회장',
#    '살롱',
#    '바디 트리트먼트',
#    '페이셜 트리트먼트',
#    '레스토랑',
#    '바/라운지',
#    '카페',
#    '비즈니스 센터',
#    '회의실',
#    '컨퍼런스룸',
#    '복사기',
#    '데스크',
#    '엘리베이터',
#    '셀프 세탁실',
#    '연회 시설',
#    '금연실',
#    '에어컨',
#    '헤어드라이어',
#    '커피/차 메이커',
#    '냉장고',
#    '개인 욕실',
#    '욕조',
#    '안전 금고',
#    'TV',
#    '목욕 가운',
#    '스위트룸']},
#  {'BO_TITLE': '라비드아틀란 호텔',
#   'HOTEL_RANK': 4,
#   'HOTEL_ADDRESS': '구남로 37',
#   'HOTEL_LOCAL_CODE': 8,
#   'BO_CONTENT': '라비드 아틀란 호텔은 해운대 지하철역에서 도보 3분, 시내 중심가에서 25분, 김해 국제공항에서 45분 거리에 있으며, 부산 아쿠아리움과 수영만 요트 경기장 등의 레저시설과 벡스코, 센텀 시티를 비롯한 비즈니스 지역에 동시에 인접해 있습니다. 뿐만 아니라 동백섬, 해동 용궁사, 부산 시립 미술관 등의 주변 관광 시설도 함께 즐기실 수 있습니다. 라비드 아틀란 호텔은 총 436객실로 부산 해운대 구남로 중심에 위치하여 볼거리, 먹거리, 놀거리가 모두 어우러진 특별함을 경험하실 수 있으며, 해운대 해수욕장으로부터 도보 2분 거리에 위치하고 있습니다.',
#   'HOTEL_REAL_OPTIONS': ['무료 와이파이',
#    '와이파이',
#    '주차장',
#    '24시간 리셉션',
#    '드라이클리닝',
#    '물품보관소',
#    '익스프레스 체크인/아웃',
#    '피트니스센터',
#    '레스토랑',
#    '엘리베이터',
#    '금연실',
#    '에어컨',
#    '헤어드라이어',
#    '커피/차 메이커',
#    '냉장고',
#    '케이블/위성 TV',
#    '개인 욕실',
#    'TV',
#    '샤워',
#    '스위트룸']},
#  {'BO_TITLE': '시그니엘 부산',
#   'HOTEL_RANK': 4,
#   'HOTEL_ADDRESS': '달맞이길 30',
#   'HOTEL_LOCAL_CODE': 8,
#   'BO_CONTENT': '시그니엘 부산은 엘시티(LCT) 타워 3층에서 19층까지 위치한 럭셔리 호텔입니다. 지하철을 이용하실 시에는 부산 2호선 중동역 7번 출구에서 도보로 약 13분, 2호선 해운대역 1번 출구에서 도보로 약 15분이면 갈 수 있습니다. 차로 이동 시에는 김해공항에서 약 50분이 소요됩니다. 주변 관광지인 해운대 해수욕장은 걸어서 약 10분이 걸립니다. 해운대 달맞이길과 광안대교는 차로 약 10분 이내에 갈 수 있습니다. 이처럼 주요 명소에 인접해 있어 최상의 위치를 자랑합니다.',
#   'HOTEL_REAL_OPTIONS': ['무료 와이파이',
#    '와이파이',
#    '고속 인터넷',
#    '주차장',
#    '발렛 파킹',
#    '24시간 리셉션',
#    '룸 서비스',
#    '외국어 구사 직원',
#    '아이 돌봄 서비스',
#    '드라이클리닝',
#    '세탁 서비스',
#    '모닝콜 서비스',
#    '환전',
#    '구두 광택 서비스',
#    '수영장',
#    '피트니스센터',
#    '스파/웰니스 센터',
#    '마사지 샵',
#    '마사지',
#    '사우나',
#    '연회장',
#    '바/라운지',
#    '카페',
#    '풀사이드 바',
#    '비즈니스 센터',
#    '컨벤션 센터',
#    '엘리베이터',
#    '연회 시설',
#    '금연실',
#    '에어컨',
#    '미니 바',
#    '헤어드라이어',
#    '커피/차 메이커',
#    '냉장고',
#    '개인 욕실',
#    '개별 욕실',
#    '욕조',
#    '안전 금고',
#    'TV',
#    '목욕 가운',
#    '샤워',
#    '스위트룸',
#    '비데',
#    '침구/베개 선택 서비스']},
#  {'BO_TITLE': '베스트웨스턴플러스 부산송도호텔',
#   'HOTEL_RANK': 2,
#   'HOTEL_ADDRESS': '송도해변로 97',
#   'HOTEL_LOCAL_CODE': 8,
#   'BO_CONTENT': '베스트웨스턴플러스 부산송도호텔은 부산역 경부선에서 차로 약 17분, 김해 국제공항에서 차로 약 1시간 거리에 있습니다. 주변 관광지인 송도 해상 케이블카는 도보로 약 10분이면 갈 수 있습니다. 또한, 국제 시장과 남포동 거리는 차로 약 10분 걸립니다.',
#   'HOTEL_REAL_OPTIONS': ['무료 와이파이',
#    '와이파이',
#    '고속 인터넷',
#    '주차장',
#    '24시간 리셉션',
#    '컨시어지',
#    '드라이클리닝',
#    '세탁 서비스',
#    '모닝콜 서비스',
#    '물품보관소',
#    '환전',
#    '투어 데스크',
#    '예매 서비스',
#    '레스토랑',
#    '비즈니스 센터',
#    '데스크',
#    '엘리베이터',
#    '에어컨',
#    '헤어드라이어',
#    '개인 욕실',
#    'TV',
#    '목욕 가운',
#    '샤워',
#    '스위트룸',
#    '비데']},
#  {'BO_TITLE': '베스트웨스턴 해운대 호텔',
#   'HOTEL_RANK': 4,
#   'HOTEL_ADDRESS': '구남로 42',
#   'HOTEL_LOCAL_CODE': 8,
#   'BO_CONTENT': '해운대 백사장이 바라다보이는 베스트웨스턴 해운대 호텔은 부산 2호선 해운대역 5번 출구에서 400m 떨어져 있습니다. 해운대 해수욕장과 아주 가까우며 SEA LIFE 부산 아쿠아리움은 도보 4분 거리에 있습니다. 차로 10분만 가시면 드라이브하기 좋은 해운대 달맞이길까지 가실 수 있습니다.',
#   'HOTEL_REAL_OPTIONS': ['무료 와이파이',
#    '와이파이',
#    '주차장',
#    '24시간 리셉션',
#    '외국어 구사 직원',
#    '드라이클리닝',
#    '세탁 서비스',
#    '물품보관소',
#    '환전',
#    '레스토랑',
#    '비즈니스 센터',
#    '회의실',
#    '복사기',
#    '엘리베이터',
#    '금연실',
#    '에어컨',
#    '헤어드라이어',
#    '커피/차 메이커',
#    '냉장고',
#    '케이블/위성 TV',
#    '개인 욕실',
#    '안전 금고',
#    'TV',
#    '샤워',
#    '스위트룸']},
#  {'BO_TITLE': '센텀프리미어호텔',
#   'HOTEL_RANK': 4,
#   'HOTEL_ADDRESS': '센텀1로 17',
#   'HOTEL_LOCAL_CODE': 8,
#   'BO_CONTENT': '해운대구에 위치한 센텀프리미어호텔은 스파랜드 센텀시티, 신세계백화점 센텀시티점 , 신세계 센텀시티 스파랜드에서 걸어서 5분 거리에 있습니다. 무료 무선 인터넷 및 피트니스센터를 이용하실 수 있습니다. 또한 도보로 10분이면 부산 전시컨벤션센터까지 가실 수 있습니다.',
#   'HOTEL_REAL_OPTIONS': ['무료 와이파이',
#    '와이파이',
#    '무료 주차 가능',
#    '주차장',
#    '24시간 리셉션',
#    '컨시어지',
#    '외국어 구사 직원',
#    '모닝콜 서비스',
#    '물품보관소',
#    '환전',
#    '비즈니스 센터',
#    '회의실',
#    '컨퍼런스룸',
#    '복사기',
#    '데스크',
#    '엘리베이터',
#    '셀프 세탁실',
#    '현금지급기',
#    '금연실',
#    '에어컨',
#    '헤어드라이어',
#    '커피/차 메이커',
#    '냉장고',
#    '케이블/위성 TV',
#    '개별 욕실',
#    '안전 금고',
#    'TV',
#    '목욕 가운',
#    '샤워',
#    '스위트룸',
#    '비데']},
#  {'BO_TITLE': '웨스틴 조선호텔 부산',
#   'HOTEL_RANK': 5,
#   'HOTEL_ADDRESS': '동백로 67',
#   'HOTEL_LOCAL_CODE': 8,
#   'BO_CONTENT': '웨스틴조선호텔 부산 - <5성급:한국관광공사 인증> - 해운대 해수욕장 바로 앞에 있는 웨스틴조선호텔 부산은 부산 2호선 동백역 1번 출구에서 도보로 약 10분 거리에 있습니다. 걸어서 약 10분이면 누리마루 APEC 하우스와 SEA LIFE 부산 아쿠아리움을 갈 수 있습니다.. 지하철로 두 정거장 거리에는 벡스코, 신세계 백화점 센텀시티점, 롯데 백화점 센텀시티점 등이 있으며 약 20분 소요됩니다.',
#   'HOTEL_REAL_OPTIONS': ['무료 와이파이',
#    '와이파이',
#    '무료 주차 가능',
#    '주차장',
#    '발렛 파킹',
#    '24시간 리셉션',
#    '룸 서비스',
#    '컨시어지',
#    '외국어 구사 직원',
#    '장애인 편의 시설',
#    '드라이클리닝',
#    '세탁 서비스',
#    '모닝콜 서비스',
#    '물품보관소',
#    '이그제큐티브 플로어',
#    '환전',
#    '익스프레스 체크인/아웃',
#    '구두 광택 서비스',
#    '장애인 주차 시설',
#    '수영장',
#    '실내 수영장',
#    '어린이 수영장',
#    '피트니스센터',
#    '스파/웰니스 센터',
#    '마사지 샵',
#    '마사지',
#    '상점',
#    '사우나',
#    '연회장',
#    '기념품 가게',
#    '레스토랑',
#    '카페',
#    '비즈니스 센터',
#    '회의실',
#    '컨퍼런스룸',
#    '복사기',
#    '데스크',
#    '엘리베이터',
#    '셀프 세탁실',
#    '현금지급기',
#    '별도 흡연 구역',
#    '연회 시설',
#    '금연실',
#    '에어컨',
#    '미니 바',
#    '케이블/위성 TV',
#    '안전 금고',
#    'TV']},
#  {'BO_TITLE': '농심 호텔',
#   'HOTEL_RANK': 2,
#   'HOTEL_ADDRESS': '금강공원로20번길 23',
#   'HOTEL_LOCAL_CODE': 8,
#   'BO_CONTENT': '농심 호텔 - <5성급:한국관광공사 인증> - 농심 호텔은 부산 1호선 온천장역 1번 출구에서 도보로 10분 거리에 있으며 지하철로 7 정거장 떨어진 거리에 부산 고속 버스터미널이 있습니다. 차로 20분이면 부산 사직 야구장까지 가실 수 있습니다. 부산의 번화가인 서면역은 지하철로 8 정거장 떨어져 있습니다. ',
#   'HOTEL_REAL_OPTIONS': ['고속 인터넷',
#    '무료 주차 가능',
#    '주차장',
#    '24시간 리셉션',
#    '룸 서비스',
#    '컨시어지',
#    '외국어 구사 직원',
#    '드라이클리닝',
#    '세탁 서비스',
#    '물품보관소',
#    '환전',
#    '구두 광택 서비스',
#    '피트니스센터',
#    '스파/웰니스 센터',
#    '마사지 샵',
#    '마사지',
#    '사우나',
#    '연회장',
#    '정원',
#    '레스토랑',
#    '바/라운지',
#    '카페',
#    '펍',
#    '비즈니스 센터',
#    '회의실',
#    '복사기',
#    '데스크',
#    '엘리베이터',
#    '셀프 세탁실',
#    '현금지급기',
#    '별도 흡연 구역',
#    '연회 시설',
#    '금연실',
#    '에어컨',
#    '미니 바',
#    '헤어드라이어',
#    '커피/차 메이커',
#    '냉장고',
#    '케이블/위성 TV',
#    '욕조',
#    '안전 금고',
#    'TV',
#    '샤워',
#    '비데']},
#  {'BO_TITLE': '크라운 하버 호텔 부산',
#   'HOTEL_RANK': 4,
#   'HOTEL_ADDRESS': '중앙대로 114',
#   'HOTEL_LOCAL_CODE': 8,
#   'BO_CONTENT': '왕관 모양을 형상화한 아치형 외관의 크라운 하버 호텔 부산은 부산 1호선 중앙역 14번 출구에서 200m 거리에 있으며 걸어서 15분이면 KTX 부산역까지 가실 수 있습니다. 호텔 주변 관광지로는 BIFF 광장, 자갈치시장, 국제시장 등이 지하철로 단 두 정거장 거리에 있습니다.',
#   'HOTEL_REAL_OPTIONS': ['무료 와이파이',
#    '와이파이',
#    '무료 주차 가능',
#    '주차장',
#    '24시간 리셉션',
#    '컨시어지',
#    '외국어 구사 직원',
#    '드라이클리닝',
#    '세탁 서비스',
#    '모닝콜 서비스',
#    '물품보관소',
#    '환전',
#    '익스프레스 체크인/아웃',
#    '피트니스센터',
#    '레스토랑',
#    '카페',
#    '비즈니스 센터',
#    '회의실',
#    '복사기',
#    '엘리베이터',
#    '금연실',
#    '에어컨',
#    '미니 바',
#    '헤어드라이어',
#    '커피/차 메이커',
#    '냉장고',
#    '케이블/위성 TV',
#    '안전 금고',
#    'TV',
#    '샤워']},
#  {'BO_TITLE': '해운대 씨클라우드 호텔 레지던스',
#   'HOTEL_RANK': 3,
#   'HOTEL_ADDRESS': '해운대해변로 287',
#   'HOTEL_LOCAL_CODE': 8,
#   'BO_CONTENT': '해운대 씨클라우드 호텔 레지던스는 해운대역에서 도보로 약 5분 걸립니다. 주변 명소인 해운대 해수욕장은 걸어서 1분도 채 안 되는 거리에 있습니다. 씨라이프부산 아쿠아리움은 도보로 3분 이내에 있습니다. 동백섬과 동백공원은 도보로 약 15분 걸립니다. 이처럼 필수 관광 명소에 손쉽게 접근할 수 있는 최적의 위치를 자랑합니다.',
#   'HOTEL_REAL_OPTIONS': ['와이파이',
#    '수영장',
#    '피트니스센터',
#    '레스토랑',
#    '카페',
#    '데스크',
#    '금연실',
#    '헤어드라이어',
#    '냉장고',
#    '부엌',
#    'TV']},
#  {'BO_TITLE': '아르반 호텔',
#   'HOTEL_RANK': 5,
#   'HOTEL_ADDRESS': '중앙대로691번길 32',
#   'HOTEL_LOCAL_CODE': 8,
#   'BO_CONTENT': '아르반 호텔은 부산 지하철 1, 2호선 서면역 1번 출구, 7번 출구에서 도보로 약 10분 거리에 위치해 있습니다. 예술의 거리로 유명한 서면 1번가가 걸어서 10분 거리에 있으며 자갈치시장까지는 차로 약 25분이 소요됩니다. 또한, 국제시장이 차로 약 25분, 해운대 해수욕장이 차로 약 35분 거리에 자리하고 있습니다.',
#   'HOTEL_REAL_OPTIONS': ['무료 와이파이',
#    '와이파이',
#    '공항 셔틀 제공',
#    '무료 주차 가능',
#    '주차장',
#    '발렛 파킹',
#    '24시간 리셉션',
#    '컨시어지',
#    '외국어 구사 직원',
#    '드라이클리닝',
#    '세탁 서비스',
#    '모닝콜 서비스',
#    '환전',
#    '예매 서비스',
#    '유아용 식탁 의자',
#    '마사지 샵',
#    '마사지',
#    '정원',
#    '레스토랑',
#    '카페',
#    '비즈니스 센터',
#    '복사기',
#    '데스크',
#    '엘리베이터',
#    '현금지급기',
#    '금연실',
#    '에어컨',
#    '헤어드라이어',
#    '커피/차 메이커',
#    '냉장고',
#    '개인 욕실',
#    '안전 금고',
#    'TV',
#    '목욕 가운',
#    '스위트룸',
#    '비데']},
#  {'BO_TITLE': '펠릭스 호텔 바이 STX',
#   'HOTEL_RANK': 4,
#   'HOTEL_ADDRESS': '해운대로 620',
#   'HOTEL_LOCAL_CODE': 8,
#   'BO_CONTENT': '펠릭스 호텔 바이 STX는 부산 2호선 해운대역과 연결되어있으며 42층 규모의 우뚝 선 건물로 아름다운 해운대 전망을 자랑합니다. 걸어서 약 10분이면 해운대 해수욕장과 SEA LIFE 부산아쿠아리움까지 가실 수 있습니다. 또한 산책하기 좋은 달맞이길은 차로 약 10분 거리에 있습니다.',
#   'HOTEL_REAL_OPTIONS': ['무료 와이파이',
#    '와이파이',
#    '무료 주차 가능',
#    '주차장',
#    '24시간 리셉션',
#    '레스토랑',
#    '데스크',
#    '엘리베이터',
#    '금연실',
#    '에어컨',
#    '헤어드라이어',
#    '커피/차 메이커',
#    '냉장고',
#    '전자레인지',
#    '부엌',
#    'TV']},
#  {'BO_TITLE': '마리안느 호텔',
#   'HOTEL_RANK': 4,
#   'HOTEL_ADDRESS': '해운대해변로 310',
#   'HOTEL_LOCAL_CODE': 8,
#   'BO_CONTENT': '마리안느 호텔 - <3성급:한국관광공사 인증> - 2014년 7월 오픈한 마리안느 호텔은 부산 2호선 해운대역 3번 출구에서 약 770m 거리에 있습니다. 도보 10분 거리에 해운대 해수욕장과 SEA LIFE 부산 아쿠아리움 등이 있습니다. 25분 정도 걸어가시면 누리마루 APEC 하우스가 있는 동백섬까지 가실 수 있으며 차로 20분이면 해동 용궁사에 가실 수 있습니다.',
#   'HOTEL_REAL_OPTIONS': ['무료 와이파이',
#    '와이파이',
#    '무료 주차 가능',
#    '주차장',
#    '24시간 리셉션',
#    '외국어 구사 직원',
#    '모닝콜 서비스',
#    '물품보관소',
#    '레스토랑',
#    '비즈니스 센터',
#    '회의실',
#    '컨퍼런스룸',
#    '복사기',
#    '데스크',
#    '엘리베이터',
#    '별도 흡연 구역',
#    '금연실',
#    '에어컨',
#    '헤어드라이어',
#    '커피/차 메이커',
#    '냉장고',
#    '케이블/위성 TV',
#    'TV',
#    '샤워']},
#  {'BO_TITLE': '라마다 속초 호텔',
#   'HOTEL_RANK': 4,
#   'HOTEL_ADDRESS': '대포항희망길 106',
#   'HOTEL_LOCAL_CODE': 1,
#   'BO_CONTENT': '속초에 위치한 편안하고 아늑한 이 호텔에서는 무료 무선인터넷과 24시간 리셉션 및 회의실 등을 이용하실 수 있습니다. 또한, 무료 구내 전용 주차장, 장애인 주차 시설도 제공하고 있으며, 차로 10분만 가시면 속초 엑스포공원까지 가실 수 있습니다. ',
#   'HOTEL_REAL_OPTIONS': ['무료 와이파이',
#    '와이파이',
#    '무료 주차 가능',
#    '주차장',
#    '24시간 리셉션',
#    '장애인 편의 시설',
#    '모닝콜 서비스',
#    '장애인 주차 시설',
#    '피트니스센터',
#    '스파/웰니스 센터',
#    '정원',
#    '비즈니스 센터',
#    '회의실',
#    '컨퍼런스룸',
#    '복사기',
#    '데스크',
#    '엘리베이터',
#    '별도 흡연 구역',
#    '금연실',
#    '에어컨',
#    '헤어드라이어',
#    '안전 금고',
#    'TV',
#    '목욕 가운']},
#  {'BO_TITLE': '씨크루즈호텔속초',
#   'HOTEL_RANK': 4,
#   'HOTEL_ADDRESS': '청초호반로 273',
#   'HOTEL_LOCAL_CODE': 1,
#   'BO_CONTENT': '속초 청학동에 위치한 씨크루즈호텔속초는 동해바다와 설악산을 포함한 강원도의 주요 명소로의 이동이 용이한 호텔입니다. 호텔에서 10분 정도 걸으시면 속초 중앙시장과 청초호 호수공원에 가실 수 있고 차로 약 10분을 가시면 속초엑스포월드랜드도 둘러보실 수 있습니다. 또한 속초 시외버스터미널과 고속버스터미널은 차로 약 10분 안에, 양양국제공항은 약 30분 안에 가실 수 있습니다.',
#   'HOTEL_REAL_OPTIONS': ['무료 와이파이', '와이파이', '고속 인터넷', '24시간 리셉션']},
#  {'BO_TITLE': '롯데 리조트 속초',
#   'HOTEL_RANK': 4,
#   'HOTEL_ADDRESS': '대포항길 186',
#   'HOTEL_LOCAL_CODE': 1,
#   'BO_CONTENT': '롯데 리조트 속초 - <4성급:한국관광공사 인증> - 롯데 리조트 속초는 속초시외버스터미널에서 차로 약 15분 소요됩니다. 주변 관광지로는 속초 8경 중 하나로 꼽히는 아름다운 영랑호와 시내 풍경과 바다를 한눈에 즐길 수 있는 속초등대전망대가 있으며, 차로 약 15분 거리에 있습니다. 또한, 중앙 시장도 차로 약 15분이면 갈 수 있습니다.',
#   'HOTEL_REAL_OPTIONS': ['무료 와이파이',
#    '와이파이',
#    '무료 주차 가능',
#    '주차장',
#    '24시간 리셉션',
#    '수영장',
#    '어린이 수영장',
#    '피트니스센터',
#    '스파/웰니스 센터',
#    '마사지 샵',
#    '마사지',
#    '상점',
#    '기념품 가게',
#    '정원',
#    '레스토랑',
#    '바/라운지',
#    '카페',
#    '펍',
#    '가라오케',
#    '회의실',
#    '데스크',
#    '엘리베이터',
#    '현금지급기',
#    '호텔 내 상점',
#    '게임 시설',
#    '금연실',
#    '에어컨',
#    '헤어드라이어',
#    '커피/차 메이커',
#    '냉장고',
#    'TV',
#    '샤워',
#    '비데']},
#  None,
#  {'BO_TITLE': '마리나베이 속초',
#   'HOTEL_RANK': 4,
#   'HOTEL_ADDRESS': '청초호반로 28',
#   'HOTEL_LOCAL_CODE': 1,
#   'BO_CONTENT': '편안한 객실과 시설을 제공하는 마리나베이 속초의 경우 여행객과 비즈니스 출장객 모두에게 좋은 숙소입니다. 차량을 가지고 오신 고객님들을 위해 무료 구내 전용 주차장도 제공하고 있습니다. 리셉션은 24시간 열려 있습니다.\r',
#   'HOTEL_REAL_OPTIONS': ['무료 주차 가능',
#    '주차장',
#    '24시간 리셉션',
#    '에어컨',
#    '헤어드라이어',
#    '개인 욕실',
#    'TV',
#    '스위트룸']},
#  {'BO_TITLE': '켄싱턴 호텔 설악',
#   'HOTEL_RANK': 4,
#   'HOTEL_ADDRESS': '설악산로 998',
#   'HOTEL_LOCAL_CODE': 1,
#   'BO_CONTENT': '켄싱턴 호텔 설악 - <4성급:한국관광공사 인증> - 켄싱턴 호텔 설악은 설악산 국립공원 입구에서 차로 단 5분 거리에 있습니다. 또한, 청초호, 속초해수욕장, 대포항 등 속초의 주요 관광지가 차로 약 25분 거리에 있습니다. 또한, 차로 30분 거리의 중앙시장 또는 아바이 마을에서 다양한 먹거리를 즐기실 수 있습니다.',
#   'HOTEL_REAL_OPTIONS': ['무료 와이파이',
#    '와이파이',
#    '무료 주차 가능',
#    '주차장',
#    '24시간 리셉션',
#    '룸 서비스',
#    '컨시어지',
#    '외국어 구사 직원',
#    '장애인 편의 시설',
#    '세탁 서비스',
#    '모닝콜 서비스',
#    '물품보관소',
#    '환전',
#    '익스프레스 체크인/아웃',
#    '장애인 주차 시설',
#    '상점',
#    '연회장',
#    '기념품 가게',
#    '정원',
#    '레스토랑',
#    '카페',
#    '비즈니스 센터',
#    '회의실',
#    '컨퍼런스룸',
#    '엘리베이터',
#    '호텔 내 상점',
#    '연회 시설',
#    '전시 공간',
#    '금연실',
#    '에어컨',
#    '미니 바',
#    '헤어드라이어',
#    '냉장고',
#    '안전 금고',
#    'TV',
#    '목욕 가운']},
#  {'BO_TITLE': '썬라이즈 호텔',
#   'HOTEL_RANK': 4,
#   'HOTEL_ADDRESS': '청초호반로 291',
#   'HOTEL_LOCAL_CODE': 1,
#   'BO_CONTENT': '청초호와 동해의 조망권을 갖춘 썬라이즈호텔은 속초 고속버스터미널에서 차로 약 10분, 양양 국제공항에서 차로 약 35분 걸립니다. 주변 명소인 청초호, 엑스포타워, 영금정은 차로 모두 6분이면 갈 수 있습니다. 이처럼 관광하시기에 좋은 최적의 장소에 위치해있습니다.',
#   'HOTEL_REAL_OPTIONS': ['무료 와이파이',
#    '와이파이',
#    '24시간 리셉션',
#    '상점',
#    '레스토랑',
#    '카페',
#    '펍',
#    '회의실',
#    '엘리베이터',
#    '호텔 내 상점',
#    '금연실',
#    '에어컨',
#    '헤어드라이어',
#    '커피/차 메이커',
#    '냉장고',
#    '전자레인지',
#    '부엌',
#    'TV',
#    '샤워',
#    '비데']},
#  {'BO_TITLE': '속초 마레몬스 호텔',
#   'HOTEL_RANK': 4,
#   'HOTEL_ADDRESS': '동해대로 3705',
#   'HOTEL_LOCAL_CODE': 1,
#   'BO_CONTENT': '속초 마레몬스 호텔 - <4성급:한국관광공사 인증> - 속초 마레몬스 호텔은 속초고속버스터미널에서 차로 15분 거리에 있습니다. 또한, 주변 관광지로는 차로 5분 거리에는 설악해맞이공원과 대포항이 있으며 호텔에서 차로 15분 거리에는 속초해수욕장과 낙산사가 있습니다. 차로 20분만 가시면 중앙시장과 아바이마을에서 다양한 먹거리를 즐기실 수 있습니다.',
#   'HOTEL_REAL_OPTIONS': ['무료 와이파이',
#    '와이파이',
#    '무료 주차 가능',
#    '주차장',
#    '24시간 리셉션',
#    '장애인 편의 시설',
#    '세탁 서비스',
#    '모닝콜 서비스',
#    '물품보관소',
#    '장애인 주차 시설',
#    '피트니스센터',
#    '비즈니스 센터',
#    '회의실',
#    '컨퍼런스룸',
#    '컨벤션 센터',
#    '복사기',
#    '현금지급기',
#    '금연실',
#    '에어컨',
#    '안전 금고']},
#  {'BO_TITLE': '팜파스 리조트',
#   'HOTEL_RANK': 3,
#   'HOTEL_ADDRESS': '동해대로 3964',
#   'HOTEL_LOCAL_CODE': 1,
#   'BO_CONTENT': '최근 리뉴얼을 마친 팜파스 리조트는 속초고속버스터미널에서 도보 5분 거리에 있습니다. 주변 관광지로는 속초 해수욕장이 가까운 도보 거리에 있으며 대포항은 차로 약 10분 거리에 있습니다. 또한, 차로 10분 이내 거리에 있는 중앙시장과 아바이마을에서 다양한 먹거리를 즐기실 수 있습니다.',
#   'HOTEL_REAL_OPTIONS': ['무료 와이파이',
#    '와이파이',
#    '무료 주차 가능',
#    '주차장',
#    '24시간 리셉션',
#    '물품보관소',
#    '피트니스센터',
#    '레스토랑',
#    '카페',
#    '금연실',
#    '에어컨',
#    '커피/차 메이커',
#    '냉장고',
#    '전자레인지',
#    '부엌',
#    '안전 금고']},
#  {'BO_TITLE': '더 블루마크 호텔 속초',
#   'HOTEL_RANK': 4,
#   'HOTEL_ADDRESS': '동해대로 3920',
#   'HOTEL_LOCAL_CODE': 1,
#   'BO_CONTENT': '속초에 위치한 편안하고 아늑한 이 호텔에서는 무선 인터넷과 24시간 리셉션 및 인피니티 풀 등을 이용하실 수 있습니다. 물품 보관소, 엘리베이터 등을 이용하실 수 있고 가까운 도보 거리 내에 외옹치해변, 속초 해수욕장도 있습니다.\r',
#   'HOTEL_REAL_OPTIONS': ['무료 와이파이',
#    '와이파이',
#    '무료 주차 가능',
#    '주차장',
#    '24시간 리셉션',
#    '장애인 편의 시설',
#    '물품보관소',
#    '장애인 주차 시설',
#    '수영장',
#    '레스토랑',
#    '카페',
#    '엘리베이터',
#    '금연실',
#    '에어컨',
#    '헤어드라이어',
#    '냉장고',
#    '개인 욕실',
#    'TV',
#    '목욕 가운',
#    '스위트룸',
#    '비데']},
#  {'BO_TITLE': '한화 리조트 설악 쏘라노',
#   'HOTEL_RANK': 4,
#   'HOTEL_ADDRESS': '미시령로2983번길 111',
#   'HOTEL_LOCAL_CODE': 1,
#   'BO_CONTENT': '설악산과 동해를 바라보며 골프를 즐길 수 있는 플라자CC설악이 있는 한화 리조트 설악 쏘라노는 설악산 국립공원에서 차로 30분 거리에 있습니다. 주변 관광지로는 차로 25분 거리에 있는 중앙시장과 아바이마을에서 다양한 먹거리를 맛보실 수도 있습니다. 또한, 서울-리조트 간 운행하는 정기운행버스가 있습니다.',
#   'HOTEL_REAL_OPTIONS': ['무료 와이파이',
#    '와이파이',
#    '무료 주차 가능',
#    '주차장',
#    '24시간 리셉션',
#    '외국어 구사 직원',
#    '장애인 편의 시설',
#    '물품보관소',
#    '장애인 주차 시설',
#    '수영장',
#    '피트니스센터',
#    '스파/웰니스 센터',
#    '키즈 클럽',
#    '골프 코스',
#    '상점',
#    '사우나',
#    '당구',
#    '정원',
#    '레스토랑',
#    '카페',
#    '가라오케',
#    '회의실',
#    '복사기',
#    '데스크',
#    '엘리베이터',
#    '셀프 세탁실',
#    '별도 흡연 구역',
#    '호텔 내 상점',
#    '게임 시설',
#    '주방',
#    '금연실',
#    '에어컨',
#    '헤어드라이어',
#    '냉장고',
#    '케이블/위성 TV',
#    '개인 욕실',
#    'TV',
#    '샤워',
#    '스위트룸']},
#  {'BO_TITLE': '설악 파인 리조트',
#   'HOTEL_RANK': 4,
#   'HOTEL_ADDRESS': '관광로408번길 14',
#   'HOTEL_LOCAL_CODE': 1,
#   'BO_CONTENT': '설악 파인 리조트에 묵으시면 속초의 명소들을 둘러보시며 맑은 온천수를 자랑하는 노천탕을 즐기실 수 있습니다. 리조트에서 도보로 약 10분 거리에 척산온천휴양촌이 있으며 차로 약 20분만 가시면 속초해수욕장 또는 설악산에 가실 수 있습니다. 리조트는 속초 시외버스터미널 및 고속버스터미널에서는 차로 약 15분 거리, 양양 국제공항에서는 약 40분 거리에 위치해 있습니다.',
#   'HOTEL_REAL_OPTIONS': ['무료 와이파이', '와이파이']},
#  {'BO_TITLE': '델피노 골프 앤 리조트',
#   'HOTEL_RANK': 4,
#   'HOTEL_ADDRESS': '토성면 미시령옛길 1153',
#   'HOTEL_LOCAL_CODE': 1,
#   'BO_CONTENT': '델피노 골프 앤 리조트는 속초시외버스터미널에서 차로 약 30분이면 갈 수 있습니다. 주변 관광지로는 차로 약 35분 거리에 영랑호가 있습니다. 또한, 차로 약 40분 거리에 낙산사, 차로 1시간 거리에 하조대가 있습니다.',
#   'HOTEL_REAL_OPTIONS': ['무료 와이파이',
#    '와이파이',
#    '무료 주차 가능',
#    '주차장',
#    '외국어 구사 직원',
#    '장애인 편의 시설',
#    '물품보관소',
#    '장애인 주차 시설',
#    '수영장',
#    '실내 수영장',
#    '실외 풀',
#    '피트니스센터',
#    '스파/웰니스 센터',
#    '사우나',
#    '레스토랑',
#    '카페',
#    '엘리베이터',
#    '별도 흡연 구역',
#    '금연실',
#    '에어컨',
#    '헤어드라이어',
#    '냉장고',
#    '케이블/위성 TV',
#    '개인 욕실',
#    'TV',
#    '스위트룸']},
#  {'BO_TITLE': '아이파크 콘도',
#   'HOTEL_RANK': 4,
#   'HOTEL_ADDRESS': '토성면 고성대로 75-16',
#   'HOTEL_LOCAL_CODE': 1,
#   'BO_CONTENT': '아이파크콘도는 속초시외버스터미널에서 차로 30분 거리에 있습니다. 주변 관광지로는 청초호가 차로 20분, 속초해수욕장이 차로 25분, 낙산사가 차로 35분 거리에 있습니다.',
#   'HOTEL_REAL_OPTIONS': ['무료 와이파이',
#    '와이파이',
#    '무료 주차 가능',
#    '주차장',
#    '장애인 편의 시설',
#    '장애인 주차 시설',
#    '수영장',
#    '어린이 수영장',
#    '피트니스센터',
#    '스파/웰니스 센터',
#    '상점',
#    '사우나',
#    '연회장',
#    '레스토랑',
#    '카페',
#    '가라오케',
#    '회의실',
#    '컨퍼런스룸',
#    '데스크',
#    '별도 흡연 구역',
#    '호텔 내 상점',
#    '연회 시설',
#    '게임 시설',
#    '피크닉 테이블',
#    '주방',
#    '금연실',
#    '에어컨',
#    '냉장고',
#    '케이블/위성 TV',
#    '욕조',
#    'TV',
#    '샤워']},
#  {'BO_TITLE': '속초 굿모닝 가족호텔',
#   'HOTEL_RANK': 4,
#   'HOTEL_ADDRESS': '해오름로 204',
#   'HOTEL_LOCAL_CODE': 1,
#   'BO_CONTENT': '굿모닝 가족호텔은 속초고속버스터미널에서 단 150m 거리에 있습니다. 주변 관광지로는 200m 떨어져 있는 속초 해수욕장, 차로 5분 거리의 청초호, 차로 10분이면 중앙시장과 아바이 마을 등이 있습니다. 또한, 차로 30분 거리에는 설악산이 있습니다.',
#   'HOTEL_REAL_OPTIONS': ['무료 와이파이',
#    '와이파이',
#    '물품보관소',
#    '가라오케',
#    '비즈니스 센터',
#    '엘리베이터',
#    '에어컨',
#    '미니 바',
#    '헤어드라이어',
#    '냉장고',
#    '케이블/위성 TV',
#    '욕조',
#    '부엌',
#    'TV',
#    '샤워']},
#  {'BO_TITLE': '현대수리조트 속초',
#   'HOTEL_RANK': 4,
#   'HOTEL_ADDRESS': '이목로 153',
#   'HOTEL_LOCAL_CODE': 1,
#   'BO_CONTENT': '현대수리조트 속초는 설악산 국립공원에서 차로 약 20분 거리에 있으며 주변에 여러 골프장이 있어 골프를 즐기기에 좋습니다. 또한, 차로 15분 거리에 청초호와 속초 해수욕장이 있으며 차로 20분 거리에 있는 아바이 마을에서 다양한 먹거리를 맛보실 수도 있습니다.',
#   'HOTEL_REAL_OPTIONS': ['무료 와이파이',
#    '와이파이',
#    '무료 주차 가능',
#    '주차장',
#    '24시간 리셉션',
#    '물품보관소',
#    '피트니스센터',
#    '상점',
#    '기념품 가게',
#    '당구',
#    '볼링장',
#    '레스토랑',
#    '카페',
#    '가라오케',
#    '회의실',
#    '엘리베이터',
#    '호텔 내 상점',
#    '게임 시설',
#    '금연실',
#    '에어컨',
#    '헤어드라이어',
#    '냉장고',
#    '케이블/위성 TV',
#    '욕조',
#    '부엌',
#    'TV',
#    '샤워']},
#  {'BO_TITLE': '금호 설악 리조트',
#   'HOTEL_RANK': 4,
#   'HOTEL_ADDRESS': '사당골길 43',
#   'HOTEL_LOCAL_CODE': 1,
#   'BO_CONTENT': '금호 설악 리조트는 설악산 국립공원에서 차로 단 15분 거리에 있습니다. 또한, 속초의 대표 관광지인 대포항과 속초해수욕장까지 차로 20분이면 도착할 수 있습니다. 차로 15분 거리의 중앙시장 또는 아바이 마을에서 다양한 먹거리를 즐기실 수 있습니다.',
#   'HOTEL_REAL_OPTIONS': ['무료 와이파이',
#    '와이파이',
#    '무료 주차 가능',
#    '주차장',
#    '24시간 리셉션',
#    '피트니스센터',
#    '상점',
#    '사우나',
#    '기념품 가게',
#    '당구',
#    '레스토랑',
#    '가라오케',
#    '회의실',
#    '컨퍼런스룸',
#    '호텔 내 상점',
#    '주방',
#    '금연실',
#    '에어컨',
#    '헤어드라이어',
#    '냉장고',
#    '전자레인지',
#    '개인 욕실',
#    '부엌',
#    'TV',
#    '샤워',
#    '스위트룸']},
#  {'BO_TITLE': '월드스테이트 속초',
#   'HOTEL_RANK': 4,
#   'HOTEL_ADDRESS': '청초호반로 291',
#   'HOTEL_LOCAL_CODE': 1,
#   'BO_CONTENT': '월드스테이트 속초는 속초 시외버스터미널에서 차로 약 5분, 속초 고속버스 터미널에서는 차로 약 10분 소요됩니다. 주변 관광지인 속초 해수욕장과 영금정은 차로 약 7분 걸립니다. 아바이 마을은 차로 약 10분 걸립니다. 이처럼 주요 관광지에 가까이 있어 편리한 위치를 자랑합니다.',
#   'HOTEL_REAL_OPTIONS': ['무료 와이파이',
#    '와이파이',
#    '무료 주차 가능',
#    '주차장',
#    '상점',
#    '호수',
#    '회의실',
#    '호텔 내 상점',
#    '금연실',
#    '에어컨',
#    '미니 바',
#    '헤어드라이어',
#    '냉장고',
#    'TV']},
#  {'BO_TITLE': '위드유 호텔 & 게스트하우스',
#   'HOTEL_RANK': 4,
#   'HOTEL_ADDRESS': '동해대로 3993',
#   'HOTEL_LOCAL_CODE': 1,
#   'BO_CONTENT': '위드유 호텔 & 게스트하우스는 속초시외버스터미널에서 차로 단 10분 거리에 있습니다. 주변 관광지로는 속초 8경 중 하나로 꼽히는 아름다운 영랑호는 차로 10분 거리에 있으며 시내 풍경과 바다를 한눈에 즐길 수 있는 속초등대전망대는 차로 10분 거리에 있습니다. 또한, 차로 5분 거리에 있는 중앙시장과 아바이마을에서 다양한 먹거리를 즐기실 수 있습니다.',
#   'HOTEL_REAL_OPTIONS': ['고속 인터넷',
#    '무료 주차 가능',
#    '주차장',
#    '물품보관소',
#    '투어 데스크',
#    '익스프레스 체크인/아웃',
#    '해양 스포츠',
#    '낚시',
#    '비즈니스 센터',
#    '에어컨',
#    '헤어드라이어',
#    '냉장고',
#    '샤워']},
#  {'BO_TITLE': '속초가족펜션',
#   'HOTEL_RANK': 4,
#   'HOTEL_ADDRESS': '설악산로 468',
#   'HOTEL_LOCAL_CODE': 1,
#   'BO_CONTENT': '속초가족펜션운 속초고속버스터미널에서 차로 약 13분, 속초시외버스터미널에서 차로 약 18분, 양양 국제공항에서 차로 약 30분 거리에 있습니다. 주변 명소로는 설악산 국립공원이 차로 약 10분, 속초 해수욕장이 차로 약 15분 거리에 있습니다.',
#   'HOTEL_REAL_OPTIONS': ['무료 와이파이', '와이파이']},
#  {'BO_TITLE': '라한셀렉트 경주 (구. 호텔현대 경주)',
#   'HOTEL_RANK': 4,
#   'HOTEL_ADDRESS': '보문로 338',
#   'HOTEL_LOCAL_CODE': 4,
#   'BO_CONTENT': '라한셀렉트 경주 (구. 호텔현대 경주) - <5성급:한국관광공사 인증> - 보문호가 내려다보이는 라한셀렉트 경주 (구. 호텔현대 경주)는 보문관광단지에서 약 2km, 경주 세계문화 엑스포공원에서 차로 10분 거리에 있습니다. 신라의 역사가 고스란히 담긴 첨성대, 안압지, 천마총은 차로 20분, 석굴암까지는 차로 35분이 소요됩니다. 또한, 경주고속버스터미널에서 차로 25분, KTX 신경주역은 차로 40분 거리에 있습니다.',
#   'HOTEL_REAL_OPTIONS': ['무료 와이파이',
#    '와이파이',
#    '무료 주차 가능',
#    '주차장',
#    '발렛 파킹',
#    '24시간 리셉션',
#    '룸 서비스',
#    '컨시어지',
#    '외국어 구사 직원',
#    '장애인 편의 시설',
#    '드라이클리닝',
#    '세탁 서비스',
#    '모닝콜 서비스',
#    '물품보관소',
#    '환전',
#    '예매 서비스',
#    '장애인 주차 시설',
#    '수영장',
#    '실내 수영장',
#    '어린이 수영장',
#    '실외 풀',
#    '피트니스센터',
#    '마사지 샵',
#    '마사지',
#    '키즈 클럽',
#    '상점',
#    '사우나',
#    '연회장',
#    '기념품 가게',
#    '다트판',
#    '놀이터',
#    '바디 트리트먼트',
#    '정원',
#    '호수',
#    '레스토랑',
#    '바/라운지',
#    '카페',
#    '비즈니스 센터',
#    '회의실',
#    '복사기',
#    '데스크',
#    '엘리베이터',
#    '셀프 세탁실',
#    '현금지급기',
#    '아이스 머신',
#    '호텔 내 상점',
#    '연회 시설',
#    '금연실',
#    '에어컨',
#    '헤어드라이어',
#    '커피/차 메이커',
#    '냉장고',
#    '케이블/위성 TV',
#    '안전 금고',
#    'TV',
#    '목욕 가운',
#    '샤워',
#    '비데']},
#  {'BO_TITLE': '코모도 호텔 경주',
#   'HOTEL_RANK': 5,
#   'HOTEL_ADDRESS': '보문로 422',
#   'HOTEL_LOCAL_CODE': 4,
#   'BO_CONTENT': '코모도 호텔 경주 - <4성급:한국관광공사 인증> - 보문관광단지 옆에 자리한 코모도 호텔 경주에서 차로 10분이면 경주 타워가 있는 경주 세계문화 엑스포공원까지 가실 수 있습니다. 경주의 대표 관광지인 불국사, 천마총, 첨성대 등은 차로 20분 거리에 있으며 석굴암까지는 차로 30분이 소요됩니다. 또한, 경주고속버스터미널에서 차로 25분, KTX 신경주역은 차로 40분 거리에 있습니다. ',
#   'HOTEL_REAL_OPTIONS': ['고속 인터넷',
#    '주차장',
#    '발렛 파킹',
#    '24시간 리셉션',
#    '룸 서비스',
#    '컨시어지',
#    '세탁 서비스',
#    '모닝콜 서비스',
#    '투어 데스크',
#    '수영장',
#    '실외 풀',
#    '마사지 샵',
#    '마사지',
#    '상점',
#    '사우나',
#    '기념품 가게',
#    '테니스 코트',
#    '정원',
#    '레스토랑',
#    '바/라운지',
#    '가라오케',
#    '비즈니스 센터',
#    '회의실',
#    '컨퍼런스룸',
#    '복사기',
#    '엘리베이터',
#    '별도 흡연 구역',
#    '호텔 내 상점',
#    '에어컨',
#    '미니 바',
#    '헤어드라이어',
#    '커피/차 메이커',
#    '냉장고',
#    '케이블/위성 TV',
#    '개인 욕실',
#    '개별 욕실',
#    '욕조',
#    '안전 금고',
#    'TV',
#    '목욕 가운',
#    '샤워',
#    '스위트룸']},
#  {'BO_TITLE': '켄싱턴 리조트 경주',
#   'HOTEL_RANK': 5,
#   'HOTEL_ADDRESS': '보문로 182-29',
#   'HOTEL_LOCAL_CODE': 4,
#   'BO_CONTENT': '켄싱턴 리조트 경주 주변에는 보문호와 여러 골프장이 있으며 경주 세계문화 엑스포공원이 차로 10분 거리에 있습니다. 주변 관광지로는 첨성대, 천마총 등은 차로 20분, 불국사는 차로 25분, 석굴암까지는 차로 35분이 소요됩니다. 또한, 경주 고속버스터미널에서 차로 20분, KTX 신경주역은 차로 30분 거리에 있습니다.',
#   'HOTEL_REAL_OPTIONS': ['와이파이',
#    '무료 주차 가능',
#    '주차장',
#    '24시간 리셉션',
#    '피트니스센터',
#    '스파/웰니스 센터',
#    '상점',
#    '사우나',
#    '레스토랑',
#    '카페',
#    '비즈니스 센터',
#    '호텔 내 상점',
#    '피크닉 테이블',
#    '주방',
#    '에어컨',
#    '헤어드라이어',
#    '냉장고',
#    '케이블/위성 TV',
#    '개인 욕실',
#    'TV',
#    '스위트룸']},
#  {'BO_TITLE': '힐튼경주',
#   'HOTEL_RANK': 5,
#   'HOTEL_ADDRESS': '보문로 484-7',
#   'HOTEL_LOCAL_CODE': 4,
#   'BO_CONTENT': '힐튼 경주 - <5성급:한국관광공사 인증> - 보문관광단지 옆에 자리한 힐튼 경주는 경주월드와 경주 세계문화 엑스포공원도 도보로 15분 내에 자리하고 있습니다. 경주의 대표 관광지인 불국사는 차로 15분, 안압지, 천마총, 첨성대 등은 차로 20분 거리에 있습니다. 또한, 경주고속버스터미널에서 차로 25분, KTX 신경주역은 차로 40분 거리에 있습니다.',
#   'HOTEL_REAL_OPTIONS': ['와이파이',
#    '고속 인터넷',
#    '주차장',
#    '발렛 파킹',
#    '룸 서비스',
#    '컨시어지',
#    '외국어 구사 직원',
#    '아이 돌봄 서비스',
#    '세탁 서비스',
#    '물품보관소',
#    '환전',
#    '투어 데스크',
#    '예매 서비스',
#    '익스프레스 체크인/아웃',
#    '구두 광택 서비스',
#    '수영장',
#    '실내 수영장',
#    '실외 풀',
#    '피트니스센터',
#    '상점',
#    '사우나',
#    '기념품 가게',
#    '스쿼시 코트',
#    '레스토랑',
#    '바/라운지',
#    '카페',
#    '비즈니스 센터',
#    '회의실',
#    '데스크',
#    '엘리베이터',
#    '현금지급기',
#    '게임 시설',
#    '미니 바',
#    '케이블/위성 TV',
#    'TV',
#    '객실 내 영화 관람',
#    '목욕 가운']},
#  {'BO_TITLE': '경주 라마다호텔&리조트',
#   'HOTEL_RANK': 4,
#   'HOTEL_ADDRESS': '감포읍 동해안로 1819-21',
#   'HOTEL_LOCAL_CODE': 4,
#   'BO_CONTENT': '경주 라마다호텔&리조트에서는 차량을 가지고 오신 고객님들을 위해 장애인 주차 시설을 제공하고 있습니다. 또한 근처에서 낚시 및 자전거 전용도로 등과 같은 다양한 활동을 체험하실 수 있습니다.  ',
#   'HOTEL_REAL_OPTIONS': ['무료 와이파이',
#    '와이파이',
#    '고속 인터넷',
#    '무료 주차 가능',
#    '주차장',
#    '24시간 리셉션',
#    '컨시어지',
#    '외국어 구사 직원',
#    '장애인 편의 시설',
#    '모닝콜 서비스',
#    '물품보관소',
#    '장애인 주차 시설',
#    '자쿠지',
#    '정원',
#    '카페',
#    '비즈니스 센터',
#    '회의실',
#    '컨퍼런스룸',
#    '복사기',
#    '데스크',
#    '현금지급기',
#    '금연실',
#    '에어컨',
#    '헤어드라이어',
#    '커피/차 메이커',
#    '케이블/위성 TV',
#    '개인 욕실',
#    '안전 금고',
#    'TV',
#    '샤워',
#    '스위트룸']},
#  {'BO_TITLE': '더 케이 호텔 경주',
#   'HOTEL_RANK': 4,
#   'HOTEL_ADDRESS': '엑스포로 45',
#   'HOTEL_LOCAL_CODE': 4,
#   'BO_CONTENT': '더 케이 호텔 경주 -<4성급:한국관광공사 인증> -더 케이 호텔 경주는 보문관광단지에서 도보로 단 10분 거리에 있습니다. 경주의 대표 관광지인 불국사는 차로 15분, 석굴암은 차로 30분 거리에 있습니다. 또한, 신라 천 년 역사를 한눈에 볼 수 있는 첨성대, 천마총, 안압지 등은 차로 20분 거리에 있습니다. 호텔에서 경주고속버스터미널까지는 차로 25분, KTX 신경주역까지는 차로 40분이 소요됩니다. 경주에 있는 이 호텔에서는 도보로 10분이면 경주 세계문화 엑스포공원 등과 같은 관광명소까지 가실 수 있습니다. ',
#   'HOTEL_REAL_OPTIONS': ['와이파이',
#    '무료 주차 가능',
#    '주차장',
#    '24시간 리셉션',
#    '컨시어지',
#    '외국어 구사 직원',
#    '장애인 편의 시설',
#    '물품보관소',
#    '장애인 주차 시설',
#    '수영장',
#    '실내 수영장',
#    '실외 풀',
#    '피트니스센터',
#    '스파/웰니스 센터',
#    '마사지 샵',
#    '마사지',
#    '상점',
#    '사우나',
#    '기념품 가게',
#    '바디 트리트먼트',
#    '레스토랑',
#    '카페',
#    '가라오케',
#    '비즈니스 센터',
#    '회의실',
#    '복사기',
#    '데스크',
#    '엘리베이터',
#    '호텔 내 상점',
#    '에어컨',
#    '헤어드라이어',
#    '냉장고',
#    '케이블/위성 TV',
#    'TV',
#    '샤워']},
#  {'BO_TITLE': '경주 지지 관광호텔',
#   'HOTEL_RANK': 5,
#   'HOTEL_ADDRESS': '태종로699번길 3',
#   'HOTEL_LOCAL_CODE': 4,
#   'BO_CONTENT': '경주 지지 관광호텔 - <3성급:한국관광공사 인증> -  경주 유일의 비즈니스 호텔인 경주 지지 관광호텔은 경주고속버스터미널에서 단 130m 거리에 있어 교통이 매우 편리합니다. 신라 천 년 역사를 한눈에 볼 수 있는 첨성대, 천마총, 안압지 등이 차로 약 5분 거리에 있습니다. 뿐만 아니라, 차로 20분 거리에는 KTX 신경주역, 차로 35분 거리에는 불국사가 있습니다.',
#   'HOTEL_REAL_OPTIONS': ['무료 와이파이',
#    '와이파이',
#    '무료 주차 가능',
#    '주차장',
#    '24시간 리셉션',
#    '룸 서비스',
#    '컨시어지',
#    '외국어 구사 직원',
#    '장애인 편의 시설',
#    '드라이클리닝',
#    '세탁 서비스',
#    '모닝콜 서비스',
#    '물품보관소',
#    '환전',
#    '투어 데스크',
#    '예매 서비스',
#    '장애인 주차 시설',
#    '유아용 식탁 의자',
#    '피트니스센터',
#    '스파/웰니스 센터',
#    '사우나',
#    '정원',
#    '비즈니스 센터',
#    '회의실',
#    '컨퍼런스룸',
#    '복사기',
#    '데스크',
#    '엘리베이터',
#    '셀프 세탁실',
#    '별도 흡연 구역',
#    '금연실',
#    '에어컨',
#    '헤어드라이어',
#    '냉장고',
#    '케이블/위성 TV',
#    '안전 금고',
#    'TV',
#    '팩시밀리',
#    '목욕 가운',
#    '비데']},
#  {'BO_TITLE': '경주 코오롱 호텔',
#   'HOTEL_RANK': 4,
#   'HOTEL_ADDRESS': '불국로 289-17',
#   'HOTEL_LOCAL_CODE': 4,
#   'BO_CONTENT': '경주 코오롱 호텔 - <4성급:한국관광공사 인증> - 성곽 모양의 웅장한 외관이 눈에 띄는 경주 코오롱 호텔은 경주의 대표 유적지인 불국사에서 단 1.5km 거리에 있으며 차로 20분이면 석굴암까지 가실 수 있습니다. 또한, 안압지, 첨성대, 교촌한옥마을 등은 차로 30분 거리에 있습니다. 경주고속버스터미널은 차로 35분, KTX 신경주역은 차로 50분 거리에 있습니다.',
#   'HOTEL_REAL_OPTIONS': ['무료 와이파이',
#    '와이파이',
#    '무료 주차 가능',
#    '주차장',
#    '24시간 리셉션',
#    '외국어 구사 직원',
#    '장애인 편의 시설',
#    '물품보관소',
#    '익스프레스 체크인/아웃',
#    '장애인 주차 시설',
#    '수영장',
#    '어린이 수영장',
#    '피트니스센터',
#    '스파/웰니스 센터',
#    '상점',
#    '사우나',
#    '기념품 가게',
#    '미니 골프코스',
#    '정원',
#    '레스토랑',
#    '카페',
#    '비즈니스 센터',
#    '회의실',
#    '컨퍼런스룸',
#    '데스크',
#    '엘리베이터',
#    '현금지급기',
#    '호텔 내 상점',
#    '게임 시설',
#    '금연실',
#    '에어컨',
#    '헤어드라이어',
#    '커피/차 메이커',
#    '냉장고',
#    '케이블/위성 TV',
#    '개인 욕실',
#    'TV',
#    '샤워',
#    '스위트룸']},
#  {'BO_TITLE': '베니키아 스위스로젠 호텔',
#   'HOTEL_RANK': 3,
#   'HOTEL_ADDRESS': '보문로 465-37',
#   'HOTEL_LOCAL_CODE': 4,
#   'BO_CONTENT': '베니키아 스위스로젠 호텔 - <3성급:한국관관공사 인증> - 지중해풍 외관이 눈에 띄는 베니키아 스위스로젠 호텔은 보문관광단지에서 약 700m 거리에 있습니다. 주변 관광지로는 불국사까지는 차로 약 15분, 천마총, 첨성대, 교촌한옥마을 등은 차로 20분 거리에 있습니다. 또한, 경주고속버스터미널에서 차로 25분, KTX 신경주역은 차로 40분 거리에 있습니다.',
#   'HOTEL_REAL_OPTIONS': ['무료 와이파이',
#    '와이파이',
#    '무료 주차 가능',
#    '주차장',
#    '24시간 리셉션',
#    '룸 서비스',
#    '외국어 구사 직원',
#    '장애인 편의 시설',
#    '드라이클리닝',
#    '세탁 서비스',
#    '모닝콜 서비스',
#    '물품보관소',
#    '투어 데스크',
#    '예매 서비스',
#    '장애인 주차 시설',
#    '수영장',
#    '피트니스센터',
#    '스파/웰니스 센터',
#    '당구',
#    '레스토랑',
#    '비즈니스 센터',
#    '회의실',
#    '복사기',
#    '데스크',
#    '엘리베이터',
#    '셀프 세탁실',
#    '금연실',
#    '에어컨',
#    '헤어드라이어',
#    '냉장고',
#    '개인 욕실',
#    '목욕 가운',
#    '샤워',
#    '스위트룸']},
#  {'BO_TITLE': '리버틴호텔 경주',
#   'HOTEL_RANK': 5,
#   'HOTEL_ADDRESS': '태종로685번길 23',
#   'HOTEL_LOCAL_CODE': 4,
#   'BO_CONTENT': '리버틴호텔 경주는 경주 고속버스터미널에서 도보로 약 3분, 경주역 중앙선에서 차로 약 6분 걸립니다. 주변 명소인 황리단길은 걸어서 약 15분, 첨성대는 걸어서 약 30분이면 갈 수 있습니다. 또한, 경주 엑스포공원은 차로 약 20분 걸립니다.',
#   'HOTEL_REAL_OPTIONS': ['무료 와이파이', '와이파이', '익스프레스 체크인/아웃']},
#  {'BO_TITLE': '141 미니 호텔',
#   'HOTEL_RANK': 2,
#   'HOTEL_ADDRESS': '원효로 141',
#   'HOTEL_LOCAL_CODE': 4,
#   'BO_CONTENT': '141 미니 호텔은 경주고속버스터미널에서 차로 약 5분, KTX 신경주역에서 약 20분이 소요됩니다. 주변 관광명소로는 차로 약 2분 거리에 세계문화유산으로 지정된 대릉원과 약 3분 거리에 신라 선덕여왕 때 지어져 동양에서 가장 오래된 석조 구조물인 첨성대가 자리하고 있습니다. 또한, 약 5분 거리에 석빙고와 야경이 아름다운 동궁과월지가 있습니다.',
#   'HOTEL_REAL_OPTIONS': ['와이파이',
#    '무료 주차 가능',
#    '주차장',
#    '사우나',
#    '카페',
#    '비즈니스 센터',
#    '회의실',
#    '금연실',
#    '에어컨',
#    '헤어드라이어',
#    '케이블/위성 TV',
#    'TV']},
#  {'BO_TITLE': '아리수경주호텔',
#   'HOTEL_RANK': 2,
#   'HOTEL_ADDRESS': '영불로 207',
#   'HOTEL_LOCAL_CODE': 4,
#   'BO_CONTENT': '아리수경주호텔 - <2성급:한국관광공사 인증> - 아리수경주호텔은 불국사에서 단 1km 거리에 있어 걸어가실 수 있으며 차로 단 15분 거리에는 석굴암이 있습니다. 신라 천 년 역사를 한눈에 볼 수 있는 첨성대, 천마총, 안압지 등이 차로 약 30분 거리에 있습니다. 뿐만 아니라, 경주고속버스터미널은 차로 30분 거리, KTX 신경주역은 45분 거리에 있습니다.',
#   'HOTEL_REAL_OPTIONS': ['무료 와이파이',
#    '와이파이',
#    '주차장',
#    '장애인 편의 시설',
#    '모닝콜 서비스',
#    '장애인 주차 시설',
#    '상점',
#    '카페',
#    '비즈니스 센터',
#    '회의실',
# ...
#    '안전 금고',
#    '목욕 가운',
#    '샤워',
#    '스위트룸',
#    '비데']},
#  {'BO_TITLE': '세종 필 무인텔',
#   'HOTEL_RANK': None,
#   'HOTEL_ADDRESS': '연동면 샘째길 16-7',
#   'HOTEL_LOCAL_CODE': 10,
#   'BO_CONTENT': '세종에 머무시는 동안 이 모텔에서 아늑한 객실 및 시설을 이용하실 수 있습니다.\r',
#   'HOTEL_REAL_OPTIONS': []},
#  {'BO_TITLE': '로뎀힐',
#   'HOTEL_RANK': None,
#   'HOTEL_ADDRESS': '연서면 안산길 176-30',
#   'HOTEL_LOCAL_CODE': 10,
#   'BO_CONTENT': '세종에 머무시는 동안 이 숙박시설에서 아늑한 객실 및 시설을 이용하실 수 있습니다.\r',
#   'HOTEL_REAL_OPTIONS': []},
#  None,
#  None,
#  {'BO_TITLE': '필사랑 무인텔',
#   'HOTEL_RANK': None,
#   'HOTEL_ADDRESS': '연동면 샘째길 16-9',
#   'HOTEL_LOCAL_CODE': 10,
#   'BO_CONTENT': '청주에 머무시는 동안 이 모텔에서 아늑한 객실 및 시설을 이용하실 수 있습니다.\r',
#   'HOTEL_REAL_OPTIONS': []},
#  {'BO_TITLE': '세종시티 오송호텔',
#   'HOTEL_RANK': 3,
#   'HOTEL_ADDRESS': '오송읍 오송생명로 178',
#   'HOTEL_LOCAL_CODE': 17,
#   'BO_CONTENT': '청주에 자리한 이 호텔에는 공용 지역 무료 무선 인터넷 등이 완비되어 있습니다. 또한 회의실, 24시간 리셉션, 엘리베이터 등도 이용하실 수 있습니다.\r',
#   'HOTEL_REAL_OPTIONS': ['무료 와이파이', '와이파이', '24시간 리셉션', '회의실', '엘리베이터']},
#  {'BO_TITLE': 'H호텔 세종시티',
#   'HOTEL_RANK': 3,
#   'HOTEL_ADDRESS': '오송읍 오송생명로 178',
#   'HOTEL_LOCAL_CODE': 17,
#   'BO_CONTENT': 'H호텔 세종시티는 청주고속버스터미널에서 차로 약 25분 거리에 있으며 청주국제공항까지 차로 약 30분 소요됩니다. 롯데 아울렛이 차로 약 20분이면 갈 수 있어 쇼핑이 편리하고, 대통령 별장 청남대까지 차로 약 40분, 상수허브랜드까지 차로 약 25분 정도 걸립니다. ',
#   'HOTEL_REAL_OPTIONS': ['무료 와이파이',
#    '와이파이',
#    '무료 주차 가능',
#    '주차장',
#    '24시간 리셉션',
#    '외국어 구사 직원',
#    '장애인 편의 시설',
#    '드라이클리닝',
#    '세탁 서비스',
#    '모닝콜 서비스',
#    '장애인 주차 시설',
#    '유아용 식탁 의자',
#    '피트니스센터',
#    '비즈니스 센터',
#    '회의실',
#    '컨퍼런스룸',
#    '컨벤션 센터',
#    '복사기',
#    '데스크',
#    '셀프 세탁실',
#    '커피/차 메이커',
#    '냉장고',
#    '케이블/위성 TV',
#    '욕조',
#    '안전 금고',
#    'TV']},
#  {'BO_TITLE': '호텔 락희 청주',
#   'HOTEL_RANK': 3,
#   'HOTEL_ADDRESS': '대농로 47-2',
#   'HOTEL_LOCAL_CODE': 17,
#   'BO_CONTENT': '2017년 2월 오픈한 호텔 락희 청주는 청주고속버스터미널에서 차로 약 10분 거리에 있으며 청주국제공항까지 차로 약 15분 소요됩니다. 롯데 아울렛이 차로 단 2분이면 갈 수 있어 쇼핑이 편리하고, 대통령 별장 청남대까지 차로 약 35분, 상수허브랜드까지 차로 약 15분 정도 걸립니다.',
#   'HOTEL_REAL_OPTIONS': ['무료 와이파이',
#    '와이파이',
#    '무료 주차 가능',
#    '주차장',
#    '24시간 리셉션',
#    '장애인 편의 시설',
#    '드라이클리닝',
#    '세탁 서비스',
#    '모닝콜 서비스',
#    '물품보관소',
#    '환전',
#    '장애인 주차 시설',
#    '피트니스센터',
#    '상점',
#    '레스토랑',
#    '회의실',
#    '복사기',
#    '데스크',
#    '엘리베이터',
#    '셀프 세탁실',
#    '호텔 내 상점',
#    '금연실',
#    '에어컨',
#    '헤어드라이어',
#    '커피/차 메이커',
#    '냉장고',
#    '개인 욕실',
#    '안전 금고',
#    'TV',
#    '샤워',
#    '스위트룸']},
#  {'BO_TITLE': '호텔 뮤제오',
#   'HOTEL_RANK': 3,
#   'HOTEL_ADDRESS': '가로수로1164번길 41-20',
#   'HOTEL_LOCAL_CODE': 17,
#   'BO_CONTENT': '호텔 뮤제오 - <3성급:한국관광공사 인증> - 청주에 자리한 호텔 뮤제오는 충북대학교에서 차로 10분 거리에 있을 뿐만 아니라 무료 공용 주차장 또한 이용하실 수 있습니다. 또한, 장애인 주차 시설도 완비되어 있으며 차로 약 10분만 가시면 흥덕사지에 도착하실 수 있습니다.',
#   'HOTEL_REAL_OPTIONS': ['무료 와이파이',
#    '와이파이',
#    '무료 주차 가능',
#    '주차장',
#    '24시간 리셉션',
#    '외국어 구사 직원',
#    '장애인 편의 시설',
#    '투어 데스크',
#    '장애인 주차 시설',
#    '수영장',
#    '피트니스센터',
#    '레스토랑',
#    '카페',
#    '비즈니스 센터',
#    '엘리베이터',
#    '별도 흡연 구역',
#    '금연실',
#    '에어컨',
#    '헤어드라이어',
#    '커피/차 메이커',
#    '개인 욕실',
#    '안전 금고',
#    'TV',
#    '스위트룸',
#    '비데']},
#  {'BO_TITLE': '더 마크호텔',
#   'HOTEL_RANK': 3,
#   'HOTEL_ADDRESS': '가로수로1164번길 41-34',
#   'HOTEL_LOCAL_CODE': 17,
#   'BO_CONTENT': '더 마크호텔 - <2성급:한국관광공사 인증> - 더 마크호텔에서 충북대학교까지 쉽게 가실 수 있습니다. 청주 국제공항까지 25분도 채 걸리지 않기 때문에 편하게 이동하실 수 있습니다.',
#   'HOTEL_REAL_OPTIONS': ['24시간 리셉션',
#    '물품보관소',
#    '투어 데스크',
#    '익스프레스 체크인/아웃',
#    '복사기',
#    '엘리베이터',
#    '셀프 세탁실',
#    '에어컨',
#    '헤어드라이어',
#    '냉장고',
#    '케이블/위성 TV',
#    'TV',
#    '목욕 가운',
#    '샤워']},
#  {'BO_TITLE': '소노벨 천안',
#   'HOTEL_RANK': 3,
#   'HOTEL_ADDRESS': '성남면 종합휴양지로 200',
#   'HOTEL_LOCAL_CODE': 16,
#   'BO_CONTENT': '소노벨 천안은 천안아산역(고속철도)에서 차로 약 25분 거리에 있습니다. 주변 관광지는 차로 약 7분 거리에 독립기념관, 차로 약 25분 거리에 천호지와 미나릿길 벽화마을 등이 있습니다.',
#   'HOTEL_REAL_OPTIONS': ['무료 와이파이',
#    '와이파이',
#    '무료 주차 가능',
#    '주차장',
#    '24시간 리셉션',
#    '모닝콜 서비스',
#    '수영장',
#    '실내 수영장',
#    '실외 풀',
#    '피트니스센터',
#    '스파/웰니스 센터',
#    '사우나',
#    '레스토랑',
#    '카페',
#    '엘리베이터',
#    '주방',
#    '금연실',
#    '에어컨',
#    '헤어드라이어',
#    '커피/차 메이커',
#    '냉장고',
#    'TV']},
#  {'BO_TITLE': 'INK 공주 관광 호텔',
#   'HOTEL_RANK': 3,
#   'HOTEL_ADDRESS': '전막2길 10-10',
#   'HOTEL_LOCAL_CODE': 16,
#   'BO_CONTENT': 'INK 공주 관광 호텔은 공주종합터미널에서 도보로 10분 거리에 있습니다. 주변 관광지로는 공산성이 차로 3분 거리에 있으며 공주한옥마을이 차로 10분 이내 거리에 있습니다. 또한, 국립공주박물관까지는 차로 5분 거리에 있습니다.',
#   'HOTEL_REAL_OPTIONS': ['무료 와이파이',
#    '와이파이',
#    '24시간 리셉션',
#    '물품보관소',
#    '투어 데스크',
#    '익스프레스 체크인/아웃',
#    '엘리베이터',
#    '에어컨',
#    '헤어드라이어',
#    '커피/차 메이커',
#    '케이블/위성 TV',
#    'TV',
#    '샤워']},
#  {'BO_TITLE': '청주 메리제인 호텔',
#   'HOTEL_RANK': 3,
#   'HOTEL_ADDRESS': '짐대로72번길 13',
#   'HOTEL_LOCAL_CODE': 17,
#   'BO_CONTENT': '청주 메리제인 호텔은 청주고속버스터미널에서 차로 약 5분 거리에 있으며 청주국제공항까지 차로 약 25분 소요됩니다. 롯데 아울렛이 차로 약 5분이면 갈 수 있어 쇼핑이 편리하고, 대통령 별장 청남대까지 차로 약 40분, 상수허브랜드까지 차로 약 20분 정도 걸립니다. ',
#   'HOTEL_REAL_OPTIONS': ['무료 주차 가능',
#    '주차장',
#    '24시간 리셉션',
#    '레스토랑',
#    '데스크',
#    '엘리베이터',
#    '별도 흡연 구역',
#    '에어컨',
#    '헤어드라이어',
#    '커피/차 메이커',
#    '냉장고',
#    'TV']},
#  {'BO_TITLE': '미니호텔',
#   'HOTEL_RANK': 3,
#   'HOTEL_ADDRESS': '짐대로72번길 10-7',
#   'HOTEL_LOCAL_CODE': 17,
#   'BO_CONTENT': '청주에 위치한 편안하고 아늑한 이 모텔에서는 무선 인터넷과 24시간 리셉션 및 포터 서비스 등을 이용하실 수 있습니다. 뿐만 아니라 엘리베이터도 갖춰져 있습니다.\r',
#   'HOTEL_REAL_OPTIONS': ['무료 와이파이',
#    '와이파이',
#    '24시간 리셉션',
#    '운반 서비스',
#    '복사기',
#    '엘리베이터',
#    '에어컨',
#    '냉장고',
#    '케이블/위성 TV',
#    'TV']},
#  {'BO_TITLE': 'Y호텔',
#   'HOTEL_RANK': 3,
#   'HOTEL_ADDRESS': '풍년로205번길 49',
#   'HOTEL_LOCAL_CODE': 17,
#   'BO_CONTENT': 'Y호텔은 청주 시외버스터미널과 고속버스터미널에서 걸어서 약 5분, 충북선 청주역에서 차로 약 15분, 청주 국제공항에서 차로 약 25분 거리에 있습니다. 주변 명소로는 흥덕사지가 차로 약 15분, 상당산성이 차로 약 35분 거리에 있습니다.',
#   'HOTEL_REAL_OPTIONS': ['무료 와이파이', '와이파이', '24시간 리셉션', '물품보관소', '에어컨']},
#  {'BO_TITLE': '아인하우스 2호점',
#   'HOTEL_RANK': 3,
#   'HOTEL_ADDRESS': '먹자1길 5',
#   'HOTEL_LOCAL_CODE': 16,
#   'BO_CONTENT': '아인하우스 2호점은 공주종합터미널에서 차로 15분 거리에 있습니다. 주변 관광지로는 공산성이 차로 5분 거리에 있으며 공주한옥마을이 차로 10분 거리에 있습니다. 또한, 국립공주박물관까지는 차로 10분 거리에 있습니다.',
#   'HOTEL_REAL_OPTIONS': ['무료 와이파이',
#    '와이파이',
#    '무료 주차 가능',
#    '주차장',
#    '24시간 리셉션',
#    '외국어 구사 직원',
#    '물품보관소',
#    '예매 서비스',
#    '데스크',
#    '셀프 세탁실',
#    '별도 흡연 구역',
#    '피크닉 테이블',
#    '에어컨',
#    '헤어드라이어',
#    '냉장고',
#    '개인 욕실',
#    'TV',
#    '샤워',
#    '스위트룸']},
#  {'BO_TITLE': '호텔공주',
#   'HOTEL_RANK': 3,
#   'HOTEL_ADDRESS': '전막2길 10-6',
#   'HOTEL_LOCAL_CODE': 16,
#   'BO_CONTENT': '공주에 위치한 이 호텔공주은 무령왕릉에서 가까운 거리에 있습니다.\r',
#   'HOTEL_REAL_OPTIONS': ['무료 와이파이', '와이파이', '24시간 리셉션', '엘리베이터']},
#  {'BO_TITLE': '니벨룽겐의 반지 호텔',
#   'HOTEL_RANK': 3,
#   'HOTEL_ADDRESS': '비하로12번길 30',
#   'HOTEL_LOCAL_CODE': 17,
#   'BO_CONTENT': '청주에 머무시는 동안 이 모텔에서 아늑한 객실 및 시설을 이용하실 수 있습니다. 또한 24시간 리셉션, 포터 서비스, 물품 보관소 등도 이용하실 수 있습니다.\r',
#   'HOTEL_REAL_OPTIONS': ['무료 와이파이',
#    '와이파이',
#    '24시간 리셉션',
#    '룸 서비스',
#    '물품보관소',
#    '운반 서비스',
#    '복사기',
#    '엘리베이터',
#    '에어컨']},
#  {'BO_TITLE': '마루 호텔',
#   'HOTEL_RANK': 3,
#   'HOTEL_ADDRESS': '전막2길 16-1',
#   'HOTEL_LOCAL_CODE': 16,
#   'BO_CONTENT': '마루 호텔은 공주 종합버스터미널에서 걸어서 약 10분 거리에 있습니다. 주변 관광지인 산성 시장은 차로 약 5분 걸립니다. 충청남도 역사박물관과 중동성당은 차로 약 8분이면 갈 수 있습니다. 이처럼 주요 명소와 가까운 거리에 있어 교통이 편리합니다.',
#   'HOTEL_REAL_OPTIONS': ['무료 와이파이',
#    '와이파이',
#    '무료 주차 가능',
#    '주차장',
#    '물품보관소',
#    '엘리베이터',
#    '에어컨']},
#  {'BO_TITLE': '맨하탄 호텔',
#   'HOTEL_RANK': 3,
#   'HOTEL_ADDRESS': '풍년로193번길 6',
#   'HOTEL_LOCAL_CODE': 17,
#   'BO_CONTENT': '청주에 위치한 편안하고 아늑한 이 모텔에서는 무선 인터넷과 24시간 리셉션 및 엘리베이터 등을 이용하실 수 있습니다.\r',
#   'HOTEL_REAL_OPTIONS': ['무료 와이파이', '와이파이', '24시간 리셉션', '엘리베이터']},
#  {'BO_TITLE': '세종시티 오송호텔',
#   'HOTEL_RANK': 3,
#   'HOTEL_ADDRESS': '오송읍 오송생명로 178',
#   'HOTEL_LOCAL_CODE': 17,
#   'BO_CONTENT': '청주에 자리한 이 호텔에는 공용 지역 무료 무선 인터넷 등이 완비되어 있습니다. 또한 회의실, 24시간 리셉션, 엘리베이터 등도 이용하실 수 있습니다.\r',
#   'HOTEL_REAL_OPTIONS': ['무료 와이파이', '와이파이', '24시간 리셉션', '회의실', '엘리베이터']},
#  {'BO_TITLE': '그랜드 플라자 청주 호텔',
#   'HOTEL_RANK': 3,
#   'HOTEL_ADDRESS': '충청대로 114',
#   'HOTEL_LOCAL_CODE': 17,
#   'BO_CONTENT': '그랜드 플라자 청주 호텔 - <5성급:한국관광공사 인증> - 그랜드 플라자 청주 호텔은 오근장역에서 차로 15분 거리에 있으며 청주공항까지도 차로 20분이면 가실 수 있습니다. 주변 관광지로는 차로 15분 거리에 수암골 벽화마을, 차로 40분 거리에 대통령의 옛별장인 청남대 등이 있습니다.',
#   'HOTEL_REAL_OPTIONS': ['고속 인터넷',
#    '공항 셔틀 제공',
#    '주차장',
#    '발렛 파킹',
#    '24시간 리셉션',
#    '룸 서비스',
#    '컨시어지',
#    '외국어 구사 직원',
#    '드라이클리닝',
#    '세탁 서비스',
#    '모닝콜 서비스',
#    '이그제큐티브 플로어',
#    '투어 데스크',
#    '익스프레스 체크인/아웃',
#    '수영장',
#    '실내 수영장',
#    '피트니스센터',
#    '상점',
#    '사우나',
#    '정원',
#    '레스토랑',
#    '바/라운지',
#    '카페',
#    '비즈니스 센터',
#    '회의실',
#    '컨퍼런스룸',
#    '엘리베이터',
#    '셀프 세탁실',
#    '별도 흡연 구역',
#    '호텔 내 상점',
#    '에어컨',
#    '미니 바',
#    '헤어드라이어',
#    '커피/차 메이커',
#    '냉장고',
#    '케이블/위성 TV',
#    '욕조',
#    '안전 금고',
#    'TV',
#    '목욕 가운',
#    '샤워']},
#  {'BO_TITLE': '호텔 락희 청주',
#   'HOTEL_RANK': 3,
#   'HOTEL_ADDRESS': '대농로 47-2',
#   'HOTEL_LOCAL_CODE': 17,
#   'BO_CONTENT': '2017년 2월 오픈한 호텔 락희 청주는 청주고속버스터미널에서 차로 약 10분 거리에 있으며 청주국제공항까지 차로 약 15분 소요됩니다. 롯데 아울렛이 차로 단 2분이면 갈 수 있어 쇼핑이 편리하고, 대통령 별장 청남대까지 차로 약 35분, 상수허브랜드까지 차로 약 15분 정도 걸립니다.',
#   'HOTEL_REAL_OPTIONS': ['무료 와이파이',
#    '와이파이',
#    '무료 주차 가능',
#    '주차장',
#    '24시간 리셉션',
#    '장애인 편의 시설',
#    '드라이클리닝',
#    '세탁 서비스',
#    '모닝콜 서비스',
#    '물품보관소',
#    '환전',
#    '장애인 주차 시설',
#    '피트니스센터',
#    '상점',
#    '레스토랑',
#    '회의실',
#    '복사기',
#    '데스크',
#    '엘리베이터',
#    '셀프 세탁실',
#    '호텔 내 상점',
#    '금연실',
#    '에어컨',
#    '헤어드라이어',
#    '커피/차 메이커',
#    '냉장고',
#    '개인 욕실',
#    '안전 금고',
#    'TV',
#    '샤워',
#    '스위트룸']},
#  {'BO_TITLE': '호텔 뮤제오',
#   'HOTEL_RANK': 3,
#   'HOTEL_ADDRESS': '가로수로1164번길 41-20',
#   'HOTEL_LOCAL_CODE': 17,
#   'BO_CONTENT': '호텔 뮤제오 - <3성급:한국관광공사 인증> - 청주에 자리한 호텔 뮤제오는 충북대학교에서 차로 10분 거리에 있을 뿐만 아니라 무료 공용 주차장 또한 이용하실 수 있습니다. 또한, 장애인 주차 시설도 완비되어 있으며 차로 약 10분만 가시면 흥덕사지에 도착하실 수 있습니다.',
#   'HOTEL_REAL_OPTIONS': ['무료 와이파이',
#    '와이파이',
#    '무료 주차 가능',
#    '주차장',
#    '24시간 리셉션',
#    '외국어 구사 직원',
#    '장애인 편의 시설',
#    '투어 데스크',
#    '장애인 주차 시설',
#    '수영장',
#    '피트니스센터',
#    '레스토랑',
#    '카페',
#    '비즈니스 센터',
#    '엘리베이터',
#    '별도 흡연 구역',
#    '금연실',
#    '에어컨',
#    '헤어드라이어',
#    '커피/차 메이커',
#    '개인 욕실',
#    '안전 금고',
#    'TV',
#    '스위트룸',
#    '비데']},
#  {'BO_TITLE': 'H호텔 세종시티',
#   'HOTEL_RANK': 3,
#   'HOTEL_ADDRESS': '오송읍 오송생명로 178',
#   'HOTEL_LOCAL_CODE': 17,
#   'BO_CONTENT': 'H호텔 세종시티는 청주고속버스터미널에서 차로 약 25분 거리에 있으며 청주국제공항까지 차로 약 30분 소요됩니다. 롯데 아울렛이 차로 약 20분이면 갈 수 있어 쇼핑이 편리하고, 대통령 별장 청남대까지 차로 약 40분, 상수허브랜드까지 차로 약 25분 정도 걸립니다. ',
#   'HOTEL_REAL_OPTIONS': ['무료 와이파이',
#    '와이파이',
#    '무료 주차 가능',
#    '주차장',
#    '24시간 리셉션',
#    '외국어 구사 직원',
#    '장애인 편의 시설',
#    '드라이클리닝',
#    '세탁 서비스',
#    '모닝콜 서비스',
#    '장애인 주차 시설',
#    '유아용 식탁 의자',
#    '피트니스센터',
#    '비즈니스 센터',
#    '회의실',
#    '컨퍼런스룸',
#    '컨벤션 센터',
#    '복사기',
#    '데스크',
#    '셀프 세탁실',
#    '커피/차 메이커',
#    '냉장고',
#    '케이블/위성 TV',
#    '욕조',
#    '안전 금고',
#    'TV']},
#  {'BO_TITLE': '더 마크호텔',
#   'HOTEL_RANK': 3,
#   'HOTEL_ADDRESS': '가로수로1164번길 41-34',
#   'HOTEL_LOCAL_CODE': 17,
#   'BO_CONTENT': '더 마크호텔 - <2성급:한국관광공사 인증> - 더 마크호텔에서 충북대학교까지 쉽게 가실 수 있습니다. 청주 국제공항까지 25분도 채 걸리지 않기 때문에 편하게 이동하실 수 있습니다.',
#   'HOTEL_REAL_OPTIONS': ['24시간 리셉션',
#    '물품보관소',
#    '투어 데스크',
#    '익스프레스 체크인/아웃',
#    '복사기',
#    '엘리베이터',
#    '셀프 세탁실',
#    '에어컨',
#    '헤어드라이어',
#    '냉장고',
#    '케이블/위성 TV',
#    'TV',
#    '목욕 가운',
#    '샤워']},
#  {'BO_TITLE': '청주 나무 호텔',
#   'HOTEL_RANK': 2,
#   'HOTEL_ADDRESS': '명암로293번길 45',
#   'HOTEL_LOCAL_CODE': 17,
#   'BO_CONTENT': '청주 나무 호텔 - <2성급:한국관광공사 인증> - 청주 나무 호텔은 오근장역에서 차로 20분 거리에 있으며 청주공항까지도 차로 25분이면 가실 수 있습니다. 주변 관광지로는 차로 10분 거리에 수암골 벽화마을, 차로 40분 거리에 대통령의 옛별장인 청남대 등이 있습니다.충북대학교, 청주종합운동장 야구장까지는 운전해서 약 20분이 소요됩니다.',
#   'HOTEL_REAL_OPTIONS': ['무료 와이파이',
#    '와이파이',
#    '무료 주차 가능',
#    '주차장',
#    '24시간 리셉션',
#    '외국어 구사 직원',
#    '세탁 서비스',
#    '물품보관소',
#    '레스토랑',
#    '비즈니스 센터',
#    '데스크',
#    '셀프 세탁실',
#    '현금지급기',
#    '별도 흡연 구역',
#    '금연실',
#    '에어컨',
#    '헤어드라이어',
#    '커피/차 메이커',
#    '냉장고',
#    '케이블/위성 TV',
#    'TV',
#    '샤워']},
#  {'BO_TITLE': '제이원호텔',
#   'HOTEL_RANK': 5,
#   'HOTEL_ADDRESS': '오창읍 중부로 806',
#   'HOTEL_LOCAL_CODE': 17,
#   'BO_CONTENT': '제이원호텔은 청주 국제공항에서 차로 약 10분 걸리며, 고속철도 오송역에서는 차로 약 25분 걸립니다. 주변 명소인 오창호수공원과 호암 저수지는 차로 약 8분이면 갈 수 있습니다. 국립현대미술관은 차로 약 20분 소요됩니다.',
#   'HOTEL_REAL_OPTIONS': ['무료 와이파이',
#    '와이파이',
#    '무료 주차 가능',
#    '주차장',
#    '24시간 리셉션',
#    '피트니스센터',
#    '연회장',
#    '레스토랑',
#    '회의실',
#    '데스크',
#    '엘리베이터',
#    '연회 시설',
#    '금연실',
#    '에어컨',
#    '헤어드라이어',
#    '커피/차 메이커',
#    '냉장고',
#    '케이블/위성 TV',
#    '전자레인지',
#    '욕조',
#    '부엌',
#    '안전 금고',
#    'TV',
#    '목욕 가운',
#    '샤워',
#    '비데']},
#  {'BO_TITLE': '청주 메리제인 호텔',
#   'HOTEL_RANK': 3,
#   'HOTEL_ADDRESS': '짐대로72번길 13',
#   'HOTEL_LOCAL_CODE': 17,
#   'BO_CONTENT': '청주 메리제인 호텔은 청주고속버스터미널에서 차로 약 5분 거리에 있으며 청주국제공항까지 차로 약 25분 소요됩니다. 롯데 아울렛이 차로 약 5분이면 갈 수 있어 쇼핑이 편리하고, 대통령 별장 청남대까지 차로 약 40분, 상수허브랜드까지 차로 약 20분 정도 걸립니다. ',
#   'HOTEL_REAL_OPTIONS': ['무료 주차 가능',
#    '주차장',
#    '24시간 리셉션',
#    '레스토랑',
#    '데스크',
#    '엘리베이터',
#    '별도 흡연 구역',
#    '에어컨',
#    '헤어드라이어',
#    '커피/차 메이커',
#    '냉장고',
#    'TV']},
#  {'BO_TITLE': '미니호텔',
#   'HOTEL_RANK': 3,
#   'HOTEL_ADDRESS': '짐대로72번길 10-7',
#   'HOTEL_LOCAL_CODE': 17,
#   'BO_CONTENT': '청주에 위치한 편안하고 아늑한 이 모텔에서는 무선 인터넷과 24시간 리셉션 및 포터 서비스 등을 이용하실 수 있습니다. 뿐만 아니라 엘리베이터도 갖춰져 있습니다.\r',
#   'HOTEL_REAL_OPTIONS': ['무료 와이파이',
#    '와이파이',
#    '24시간 리셉션',
#    '운반 서비스',
#    '복사기',
#    '엘리베이터',
#    '에어컨',
#    '냉장고',
#    '케이블/위성 TV',
#    'TV']},
#  {'BO_TITLE': 'Y호텔',
#   'HOTEL_RANK': 3,
#   'HOTEL_ADDRESS': '풍년로205번길 49',
#   'HOTEL_LOCAL_CODE': 17,
#   'BO_CONTENT': 'Y호텔은 청주 시외버스터미널과 고속버스터미널에서 걸어서 약 5분, 충북선 청주역에서 차로 약 15분, 청주 국제공항에서 차로 약 25분 거리에 있습니다. 주변 명소로는 흥덕사지가 차로 약 15분, 상당산성이 차로 약 35분 거리에 있습니다.',
#   'HOTEL_REAL_OPTIONS': ['무료 와이파이', '와이파이', '24시간 리셉션', '물품보관소', '에어컨']},
#  {'BO_TITLE': '호텔야자 서문점',
#   'HOTEL_RANK': 2,
#   'HOTEL_ADDRESS': '남사로89번길 26',
#   'HOTEL_LOCAL_CODE': 17,
#   'BO_CONTENT': '호텔야자 서문점은 청주 국제공항에서 차로 약 30분 걸립니다. 주변 관광지인 수암골 벽화마을과 전망대는 차로 약 10분 소요됩니다. 또한, 청남대는 차로 약 40분이면 갈 수 있습니다.',
#   'HOTEL_REAL_OPTIONS': ['무료 와이파이', '와이파이', '물품보관소', '자쿠지', '엘리베이터']},
#  {'BO_TITLE': '세종 스파텔',
#   'HOTEL_RANK': 5,
#   'HOTEL_ADDRESS': '내수읍 신기초정로 699',
#   'HOTEL_LOCAL_CODE': 17,
#   'BO_CONTENT': '세종 스파텔은 충북선 증평역과 청주 국제공항에서 차로 약 20분 거리에 위치하고 있습니다. 주변 관광지로는 좌구산자연휴양림이 차로 약 15분, 청주랜드가 차로 약 20분, 청주백제유물전시관이 차로 약 30분가량 소요됩니다. ',
#   'HOTEL_REAL_OPTIONS': ['무료 와이파이',
#    '와이파이',
#    '24시간 리셉션',
#    '외국어 구사 직원',
#    '투어 데스크',
#    '당구',
#    '엘리베이터',
#    '에어컨',
#    '헤어드라이어',
#    '커피/차 메이커',
#    '냉장고',
#    '안전 금고',
#    'TV',
#    '목욕 가운',
#    '샤워']},
#  {'BO_TITLE': '니벨룽겐의 반지 호텔',
#   'HOTEL_RANK': 3,
#   'HOTEL_ADDRESS': '비하로12번길 30',
#   'HOTEL_LOCAL_CODE': 17,
#   'BO_CONTENT': '청주에 머무시는 동안 이 모텔에서 아늑한 객실 및 시설을 이용하실 수 있습니다. 또한 24시간 리셉션, 포터 서비스, 물품 보관소 등도 이용하실 수 있습니다.\r',
#   'HOTEL_REAL_OPTIONS': ['무료 와이파이',
#    '와이파이',
#    '24시간 리셉션',
#    '룸 서비스',
#    '물품보관소',
#    '운반 서비스',
#    '복사기',
#    '엘리베이터',
#    '에어컨']},
#  {'BO_TITLE': '브라운도트 호텔 청주점',
#   'HOTEL_RANK': 2,
#   'HOTEL_ADDRESS': '교서로32번길 32-2',
#   'HOTEL_LOCAL_CODE': 17,
#   'BO_CONTENT': '브라운도트 호텔 청주점은 청주고속버스터미널에서 차로 25분 거리에 있으며 청주국제공항까지 차로 약 25분 소요됩니다. 롯데 아울렛이 차로 약 20분이면 갈 수 있어 쇼핑이 편리하고, 대통령 별장 청남대까지 차로 약 50분, 상수허브랜드까지 차로 약 25분 정도 걸립니다. ',
#   'HOTEL_REAL_OPTIONS': ['무료 와이파이',
#    '와이파이',
#    '주차장',
#    '24시간 리셉션',
#    '룸 서비스',
#    '물품보관소',
#    '데스크',
#    '셀프 세탁실',
#    '에어컨',
#    '헤어드라이어',
#    '냉장고',
#    '케이블/위성 TV',
#    '개인 욕실',
#    'TV',
#    '목욕 가운',
#    '스위트룸']},
#  {'BO_TITLE': '맨하탄 호텔',
#   'HOTEL_RANK': 3,
#   'HOTEL_ADDRESS': '풍년로193번길 6',
#   'HOTEL_LOCAL_CODE': 17,
#   'BO_CONTENT': '청주에 위치한 편안하고 아늑한 이 모텔에서는 무선 인터넷과 24시간 리셉션 및 엘리베이터 등을 이용하실 수 있습니다.\r',
#   'HOTEL_REAL_OPTIONS': ['무료 와이파이', '와이파이', '24시간 리셉션', '엘리베이터']},
#  {'BO_TITLE': '금관숲강변별장펜션',
#   'HOTEL_RANK': 2,
#   'HOTEL_ADDRESS': '미원면 운암계원로 614-8',
#   'HOTEL_LOCAL_CODE': 17,
#   'BO_CONTENT': '청주에 머무시는 동안 이 숙박시설에서 아늑한 객실 및 시설을 이용하실 수 있습니다.\r',
#   'HOTEL_REAL_OPTIONS': []},
#  {'BO_TITLE': '루체 호텔',
#   'HOTEL_RANK': 3,
#   'HOTEL_ADDRESS': '풍년로205번길 39',
#   'HOTEL_LOCAL_CODE': 17,
#   'BO_CONTENT': '몽 호텔은 청주고속버스터미널에서 차로 단 3분 거리에 있습니다. 주변 관광지로는 차로 25분 거리에 수암골 벽화마을, 차로 40분 거리에 대통령의 옛별장인 청남대 등이 있습니다. ',
#   'HOTEL_REAL_OPTIONS': ['무료 와이파이',
#    '와이파이',
#    '주차장',
#    '24시간 리셉션',
#    '드라이클리닝',
#    '세탁 서비스',
#    '데스크',
#    '엘리베이터',
#    '셀프 세탁실',
#    '에어컨',
#    '헤어드라이어',
#    '냉장고',
#    '케이블/위성 TV',
#    '개인 욕실',
#    'TV',
#    '스위트룸']},
#  {'BO_TITLE': '시안호텔',
#   'HOTEL_RANK': 3,
#   'HOTEL_ADDRESS': '경산로5번길 11',
#   'HOTEL_LOCAL_CODE': 17,
#   'BO_CONTENT': '청주에 위치한 이 시안호텔은 충북대학교에서 가까운 거리에 있습니다. 무료 와이파이(Wi-Fi), 24시간 비지니스 센터 및 24시간 리셉션도 제공하고 있습니다.\r',
#   'HOTEL_REAL_OPTIONS': ['무료 와이파이', '와이파이', '24시간 리셉션', '비즈니스 센터']},
#  {'BO_TITLE': '호텔 본',
#   'HOTEL_RANK': 5,
#   'HOTEL_ADDRESS': '향군로15번길 10',
#   'HOTEL_LOCAL_CODE': 17,
#   'BO_CONTENT': '본호텔은 청주시외버스터미널에서 차로 약 25분 소요됩니다. 주변 관광지인 문암 생태공원와 청주랜드는 차로 약 12분이면 갈 수 있습니다. 상수허브랜드는 차로 약 30분 걸립니다.',
#   'HOTEL_REAL_OPTIONS': ['24시간 리셉션',
#    '물품보관소',
#    '익스프레스 체크인/아웃',
#    '가라오케',
#    '엘리베이터',
#    '셀프 세탁실']}]

# %%
len(hotels)
# Out:
# 420
